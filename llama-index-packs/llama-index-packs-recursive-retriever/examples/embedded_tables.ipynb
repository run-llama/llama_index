# %% [markdown]
# # Embedded Tables Pack
#
# This LlamaPack provides an example of our embedded-tables pack (with recursive retrieval + Unstructured.io).

# %%
# %pip install llama-index-packs-recursive-retriever

# %%
# !pip install llama-index llama-hub unstructured==0.10.18 lxml

# %%
import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# ### Setup Data

# %%
# !wget "https://www.dropbox.com/scl/fi/mlaymdy1ni1ovyeykhhuk/tesla_2021_10k.htm?rlkey=qf9k4zn0ejrbm716j0gg7r802&dl=1" -O tesla_2021_10k.htm

# %% [markdown]
# ### Download and Initialize Pack
#
# Note that this pack directly takes in the html file, no need to load it beforehand.

# %%
from llama_index.core.llama_pack import download_llama_pack

EmbeddedTablesUnstructuredRetrieverPack = download_llama_pack(
    "EmbeddedTablesUnstructuredRetrieverPack",
    "./embedded_tables_unstructured_pack",
    # leave the below commented out (was for testing purposes)
    # llama_hub_url="https://raw.githubusercontent.com/run-llama/llama-hub/jerry/add_llama_packs/llama_hub",
)

# %%
# TMP
from llama_index.packs.recursive_retriever import (
    EmbeddedTablesUnstructuredRetrieverPack,
)

embedded_tables_unstructured_pack = EmbeddedTablesUnstructuredRetrieverPack(
    "tesla_2021_10k.htm", nodes_save_path="2021_nodes.pkl"
)

# %% [markdown]
# ### Run Pack

# %%
# this will run the full pack
response = embedded_tables_unstructured_pack.run("What was the revenue in 2020?")
# Out:
# Retrieving with query id None: What was the revenue in 2020?
# Retrieved node with id, entering: id_478_table
# Retrieving with query id id_478_table: What was the revenue in 2020?

# %%
print(str(response))
# Out:
# The revenue in 2020 was $31,536 million.

# %%
len(response.source_nodes)
# Out:
# 1

# %% [markdown]
# ### Inspect Modules

# %%
modules = embedded_tables_unstructured_pack.get_modules()
display(modules)
# Out:
# {'node_parser': UnstructuredElementNodeParser(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x1270b7100>, llm=None, summary_query_str='What is this table about? Give a very concise summary (imagine you are adding a caption), and also output whether or not the table should be kept.'),
#  'recursive_retriever': <llama_index.core.retrievers.recursive_retriever.RecursiveRetriever at 0x1270b7a00>,
#  'query_engine': <llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine at 0x2b2830400>}
