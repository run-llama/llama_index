# %% [markdown]
# # MAXIA AI Marketplace Tools
# Demo of LlamaIndex tools for MAXIA.

# %%
from llama_index.tools.maxia import MaxiaToolSpec
spec = MaxiaToolSpec()
tools = spec.to_tool_list()
for t in tools:
    print(t.metadata.name)
