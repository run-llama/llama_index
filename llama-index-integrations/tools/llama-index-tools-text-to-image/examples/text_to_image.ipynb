# %%
import openai

openai.api_key = "sk-your-key"
from llama_index.agent import OpenAIAgent

# %%
# Import and initialize our tool spec
from llama_index.tools.text_to_image.base import TextToImageToolSpec

text_to_image_spec = TextToImageToolSpec()
tools = text_to_image_spec.to_tool_list()
# Create the Agent with our tools
agent = OpenAIAgent.from_tools(tools, verbose=True)

# %%
print(agent.chat("show 2 images of a beautiful beach with a palm tree at sunset"))
# Out:
# === Calling Function ===
# Calling function: generate_images with args: {
#   "prompt": "beautiful beach with a palm tree at sunset",
#   "n": 2
# }
# Got output: ['https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-JgjhcmOzST64BmMKP8DGUDR2.png?st=2023-07-20T12%3A22%3A33Z&se=2023-07-20T14%3A22%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A05%3A31Z&ske=2023-07-20T20%3A05%3A31Z&sks=b&skv=2021-08-06&sig=Uy9rV/sEF2lQXXg0xR4Lp5EEDbwfoJKPKYD9OPPsUVI%3D', 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-L1atXiGhgbK8W6S7z5kGnGIM.png?st=2023-07-20T12%3A22%3A33Z&se=2023-07-20T14%3A22%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A05%3A31Z&ske=2023-07-20T20%3A05%3A31Z&sks=b&skv=2021-08-06&sig=4OKJXTGcH5cI0LLuZehRdeJIAmjhLHfRFEmGb3Eo/9Q%3D']
# ========================
# === Calling Function ===
# Calling function: show_images with args: {
#   "urls": [
#     "https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-JgjhcmOzST64BmMKP8DGUDR2.png?st=2023-07-20T12%3A22%3A33Z&se=2023-07-20T14%3A22%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A05%3A31Z&ske=2023-07-20T20%3A05%3A31Z&sks=b&skv=2021-08-06&sig=Uy9rV/sEF2lQXXg0xR4Lp5EEDbwfoJKPKYD9OPPsUVI%3D",
#     "https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-L1atXiGhgbK8W6S7z5kGnGIM.png?st=2023-07-20T12%3A22%3A33Z&se=2023-07-20T14%3A22%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A05%3A31Z&ske=2023-07-20T20%3A05%3A31Z&sks=b&skv=2021-08-06&sig=4OKJXTGcH5cI0LLuZehRdeJIAmjhLHfRFEmGb3Eo/9Q%3D"
#   ]
# }
# Got output: images rendered successfully
# ========================
# Here are 2 images of a beautiful beach with a palm tree at sunset:
#
# ![Image 1](https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-JgjhcmOzST64BmMKP8DGUDR2.png?st=2023-07-20T12%3A22%3A33Z&se=2023-07-20T14%3A22%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A05%3A31Z&ske=2023-07-20T20%3A05%3A31Z&sks=b&skv=2021-08-06&sig=Uy9rV/sEF2lQXXg0xR4Lp5EEDbwfoJKPKYD9OPPsUVI%3D)
#
# ![Image 2](https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-L1atXiGhgbK8W6S7z5kGnGIM.png?st=2023-07-20T12%3A22%3A33Z&se=2023-07-20T14%3A22%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A05%3A31Z&ske=2023-07-20T20%3A05%3A31Z&sks=b&skv=2021-08-06&sig=4OKJXTGcH5cI0LLuZehRdeJIAmjhLHfRFEmGb3Eo/9Q%3D)

# %%
print(agent.chat("make the second image higher quality"))
# Out:
# === Calling Function ===
# Calling function: generate_image_variation with args: {
#   "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-L1atXiGhgbK8W6S7z5kGnGIM.png?st=2023-07-20T12%3A22%3A33Z&se=2023-07-20T14%3A22%3A33Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A05%3A31Z&ske=2023-07-20T20%3A05%3A31Z&sks=b&skv=2021-08-06&sig=4OKJXTGcH5cI0LLuZehRdeJIAmjhLHfRFEmGb3Eo/9Q%3D",
#   "n": 1,
#   "size": "1024x1024"
# }
# Got output: ['https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-ONW3c1BS1q7T99gPXgYNAzC4.png?st=2023-07-20T12%3A23%3A46Z&se=2023-07-20T14%3A23%3A46Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A06%3A58Z&ske=2023-07-20T20%3A06%3A58Z&sks=b&skv=2021-08-06&sig=a08FVG2YDeAFolnNV9LeChV6xhqbsL7s6kNaAnE8i2Y%3D']
# ========================
# === Calling Function ===
# Calling function: show_images with args: {
#   "urls": [
#     "https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-ONW3c1BS1q7T99gPXgYNAzC4.png?st=2023-07-20T12%3A23%3A46Z&se=2023-07-20T14%3A23%3A46Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A06%3A58Z&ske=2023-07-20T20%3A06%3A58Z&sks=b&skv=2021-08-06&sig=a08FVG2YDeAFolnNV9LeChV6xhqbsL7s6kNaAnE8i2Y%3D"
#   ]
# }
# Got output: images rendered successfully
# ========================
# Here is the second image of a beautiful beach with a palm tree at sunset in higher quality:
#
# ![Image](https://oaidalleapiprodscus.blob.core.windows.net/private/org-D4kvRqOfNVMbFy4TwSTUcPol/user-37dlqn4L8GErLv6SnH4LJw2N/img-ONW3c1BS1q7T99gPXgYNAzC4.png?st=2023-07-20T12%3A23%3A46Z&se=2023-07-20T14%3A23%3A46Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-19T20%3A06%3A58Z&ske=2023-07-20T20%3A06%3A58Z&sks=b&skv=2021-08-06&sig=a08FVG2YDeAFolnNV9LeChV6xhqbsL7s6kNaAnE8i2Y%3D)
