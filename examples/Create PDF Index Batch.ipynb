# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
import sys, os

print(f"Installing packages into environment {sys.executable}")
# Out:
# Installing packages into environment c:\anaconda3\envs\cogsearch02\python.exe

# %%
# !{sys.executable} -m pip install llama-index openai langchain azure-identity

# %% [markdown]
# # End to end process to create a download and index a single document

# %%
import logging

logger = logging.getLogger(__name__)

# %%
# get_token()

# %%
from llama_index import download_loader
from langchain.llms import AzureOpenAI
from llama_index import LLMPredictor
from langchain.embeddings import OpenAIEmbeddings
from llama_index import LangchainEmbedding
from azure.search.documents import SearchClient 
from azure.core.credentials import AzureKeyCredential  
from llama_index.vector_stores import CognitiveSearchVectorStore
from llama_index import VectorStoreIndex, StorageContext, ServiceContext
from llama_index import load_index_from_storage
from typing import Dict, Any 
import re
import base64 
import os
from azure.identity import DefaultAzureCredential
from pypdf import PdfReader, PdfWriter
from azure.storage.blob import BlobServiceClient
import io
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# NumExpr defaulting to 8 threads.

# %%
storage_account_url = "https://aoaist002.blob.core.windows.net"
loader_hub_fork_url = "https://raw.githubusercontent.com/rivms/llama-hub/azblobmetadata/llama_hub"

# aoai_base = "https://demoaoai002.openai.azure.com/"
aoai_base = "https://demofcaoai004.openai.azure.com/"
azure_kwargs={"api_type": "azure_ad", "api_version": "2023-03-15-preview", "api_base": aoai_base}

# %%
# Search Client Parameters
key = "2UCPzVfO4hVvxvRFFTbreE6MFSUTEmSgWYGpniC6pXAzSeBiVDiN"
credential = AzureKeyCredential(key)

service_endpoint = "https://gptkb-gdm7wgiiihc5y.search.windows.net"


#index_name = "aoaientsearch-bhp"

#index_name = "aoaientsearchsynergy"
index_name = "aoaientsearchinpex"

# %%
AzStorageBlobReader = download_loader("AzStorageBlobReader", loader_hub_fork_url, refresh_cache = True)

# %%
def load_documents(container_name: str, 
                blob: str,
                account_url: str,
                loader_hub_url: str): 
    default_credential = DefaultAzureCredential()

    loader = AzStorageBlobReader(container_name=container_name, 
        blob=blob,
        account_url=account_url, 
        credential=default_credential, 
        loader_hub_url=loader_hub_url) #, num_files_limit = 1)

    documents = loader.load_data()

    return documents


def index_document(documents: Any,
                azure_kwargs: Any,
                service_endpoint: str,
                index_name: str,
                persist_dir: str,
                credential: AzureKeyCredential
                ):
    
    default_credential = DefaultAzureCredential()
    token = default_credential.get_token("https://cognitiveservices.azure.com/.default")

    logger.info('Number of documents: {}'.format(len(documents)))


    llm_predictor = get_llm(openai_api_version=azure_kwargs["api_version"], 
                        openai_api_key=token.token, 
                        model_kwargs=azure_kwargs) 

    embeddings = get_embedding(openai_api_key=token.token, model_kwargs=azure_kwargs)


    vector_store = get_vector_store(service_endpoint, index_name, credential)

    service_context = ServiceContext.from_defaults(llm_predictor=llm_predictor, embed_model=embeddings) # using default chunk limit

    try:
        logger.info(f"Loading storage context from {persist_dir}")
        storage_context = StorageContext.from_defaults(persist_dir=persist_dir, vector_store=vector_store)
    except FileNotFoundError as e:
        logger.info(f"Failed to load storage context from {persist_dir}, create default")
        storage_context = StorageContext.from_defaults(vector_store=vector_store)


    logger.info(f"Parsing nodes")
    nodes = service_context.node_parser.get_nodes_from_documents(documents)
    try:
        logger.info(f"Trying to load index from storage")
        cog_index = load_index_from_storage(storage_context=storage_context, service_context = service_context)
        cog_index.insert_nodes(nodes)
    except ValueError as e:
        logger.info(f"Creating a new index")
        cog_index = VectorStoreIndex(
        nodes=nodes, storage_context=storage_context, service_context=service_context)

    logger.info(f"Saving storage context to {persist_dir}")
    storage_context.persist(persist_dir=persist_dir)

# %%
def get_token():
    # Request credential
    default_credential = DefaultAzureCredential()
    token = default_credential.get_token("https://cognitiveservices.azure.com/.default")
    return token.token

def get_vector_store(service_endpoint: str, index_name: str, credential: Any) -> CognitiveSearchVectorStore:
    search_client = SearchClient(service_endpoint, index_name, credential=credential) 
    vector_store = CognitiveSearchVectorStore(search_client,
                                          id_field_key = "li_id",
                                          chunk_field_key= "content",
                                          embedding_field_key = "embedding",
                                          metadata_field_key= "li_jsonMetadata",
                                          doc_id_field_key = "li_doc_id",
                                          index_mapping = cogsearch_ent_index_mapping
    )
    return vector_store

def get_llm(openai_api_version: str, openai_api_key: str, model_kwargs: Any) -> LLMPredictor:
    llm = AzureOpenAI(temperature=0.9, 
                  deployment_name="text-davinci-003", 
                  model_name="text-davinci-003", 
                  openai_api_version= openai_api_version, 
                  openai_api_key=openai_api_key, 
                  model_kwargs=model_kwargs)

    # define LLM
    llm_predictor = LLMPredictor(llm)   
    return llm_predictor


def get_embedding(openai_api_key: str, model_kwargs: Any) -> LangchainEmbedding:
    # load in AOAI embedding model from langchain
    oai_embeddings = OpenAIEmbeddings(model="text-embedding-ada-002",
                              deployment="text-embedding-ada-002",
                              openai_api_key=openai_api_key,
                              openai_api_base=model_kwargs["api_base"],
                              openai_api_type=model_kwargs["api_type"],
                              openai_api_version=model_kwargs["api_version"],
                              chunk_size=1)
    embeddings = LangchainEmbedding(oai_embeddings)
    return embeddings


def filename_to_id(filename):
    filename_ascii = re.sub("[^0-9a-zA-Z_-]", "_", filename)
    filename_hash = base64.b16encode(filename.encode('utf-8')).decode('ascii')
    return f"file-{filename_ascii}-{filename_hash}"

def blob_name_from_file_page(filename, page = 0):
    if os.path.splitext(filename)[1].lower() == ".pdf":
        return os.path.splitext(os.path.basename(filename))[0] + f"-{page}" + ".pdf"
    else:
        return os.path.basename(filename)

def cogsearch_ent_index_mapping(
        enriched_doc: Dict[str, str], metadata: Dict[str, Any]
    ) -> Dict[str, str]:
        index_doc: Dict[str, str] = {}
        field_mapping = { "id": "id", "chunk": "content", "embedding": "contentVector", "doc_id": "document_id", "metadata": "jsonMetadata"}

        page = metadata.get("page_number", 0)
        sourcefile = metadata["file_name"]
        file_id = filename_to_id(sourcefile)
        # id, content, embedding, sourcepage, sourcefile

        index_doc["id"] = f"{file_id}-page-{page}"
        index_doc["content"] = enriched_doc["chunk"]
        index_doc["embedding"] = enriched_doc["embedding"]
        index_doc["sourcepage"] = blob_name_from_file_page(sourcefile, page)
        index_doc["sourcefile"] = sourcefile
        index_doc["li_id"] = enriched_doc["id"]
        index_doc["li_jsonMetadata"] = enriched_doc["metadata"]
        index_doc["li_doc_id"] = enriched_doc["doc_id"]

        return index_doc

def upload_blobs(filename,split_pdf_storage_account, split_pdf_container):
    default_credential = DefaultAzureCredential()
    print(f"Starting upload: {filename}")
    blob_service = BlobServiceClient(account_url=f"https://{split_pdf_storage_account}.blob.core.windows.net", credential=default_credential)
    print(f"Starting upload: {filename}")
    blob_container = blob_service.get_container_client(split_pdf_container)
    if not blob_container.exists():
        blob_container.create_container()

    # if file is PDF split into pages and upload each page as a separate blob
    if os.path.splitext(filename)[1].lower() == ".pdf":
        logger.info(f"Processing pdf")
        reader = PdfReader(filename)
        pages = reader.pages
        logger.info(f"Processing {len(pages)} pages")
        for i in range(len(pages)):
            blob_name = blob_name_from_file_page(filename, i)
            logger.info(f"Creating blob for page {i} -> {blob_name}")
            f = io.BytesIO()
            writer = PdfWriter()
            writer.add_page(pages[i])
            writer.write(f)
            f.seek(0)
            logger.info(f"Uploading blob for page {i} of {len(pages)} -> {blob_name}")
            blob_container.upload_blob(blob_name, f, overwrite=True)
            logger.info(f"Upload complete for page {i} of {len(pages)}-> {blob_name}")
    else:
        logger.info(f"Not a pdf")
        blob_name = blob_name_from_file_page(filename)
        with open(filename,"rb") as data:
            blob_container.upload_blob(blob_name, data, overwrite=True)

# %%
annual_reports = ["200915_BHPAnnualReport2020.pdf", "210914_bhpannualreport2021.pdf",
                "220906_bhpannualreport2022.pdf", "bhpannualreport2017.pdf",
                "bhpannualreport2018.pdf", "bhpannualreport2019.pdf",
                "bhpBillitonAnnualReport2010.pdf", "BHPBillitonAnnualReport2013.pdf",
                "BHPBillitonAnnualReport2014_interactive.pdf", "bhpbillitonannualreport2015.pdf",
                "bhpbillitonannualreport2016.pdf", "BHPBillitonAnnualReport2011.pdf",
                "BHPBillitonAnnualReport2012.pdf", "annualReport2009.pdf"]

# %%
annual_reports_inpex = ["inpex_single_annualreport202112_en.pdf", "inpex_annualreport202112_en.pdf",
                  "inpex_annualreport202012_en.pdf", "inpex_annualreport2018_en.pdf"]
persist_dir = "./llama_store_synergy"
split_pdf_storage_account = "stgdm7wgiiihc5y"
split_pdf_container = "aoaientsearchinpex"

# %%
annual_reports_synergy = ["Synergy 2020 Annual Report.pdf", "Synergy 2021 Annual Report.pdf", "Synergy 2022 Annual Report.pdf"]
persist_dir = "./llama_store_synergy"
split_pdf_storage_account = "stgdm7wgiiihc5y"
split_pdf_container = "aoaientsearchsynergy"

# %%
persist_dir = "./llama_store_bhp"
split_pdf_storage_account = "stgdm7wgiiihc5y"
split_pdf_container = "aoaientsearchbhp"

# %%
logger.setLevel(logging.INFO)

# %%
pdf = annual_reports_inpex[3]

documents = load_documents(container_name='annualreportsinpex', blob=pdf, account_url=storage_account_url,
            loader_hub_url=loader_hub_fork_url)
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# ManagedIdentityCredential will use IMDS
# INFO:custom_loader:Adding metadata for C:\Users\rijumna\AppData\Local\Temp\tmpa7rxo96k\mxuecv4n.pdf
# Adding metadata for C:\Users\rijumna\AppData\Local\Temp\tmpa7rxo96k\mxuecv4n.pdf
# INFO:custom_loader:Start download of inpex_annualreport2018_en.pdf
# Start download of inpex_annualreport2018_en.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.14.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# No body was attached to the request
# Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.14.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://aoaist002.blob.core.windows.net/annualreportsinpex/inpex_annualreport2018_en.pdf'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'ae67f207-415d-11ee-b2c9-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# Request URL: 'https://aoaist002.blob.core.windows.net/annualreportsinpex/inpex_annualreport2018_en.pdf'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'ae67f207-415d-11ee-b2c9-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 206
# Response headers:
#     'Content-Length': '8652121'
#     'Content-Type': 'application/pdf'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:16:15 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DBA37EEDC109E9"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'e952cc15-101e-0023-7b6a-d5486c000000'
#     'x-ms-client-request-id': 'ae67f207-415d-11ee-b2c9-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:35:14 GMT'
# Response status: 206
# Response headers:
#     'Content-Length': '8652121'
#     'Content-Type': 'application/pdf'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:16:15 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DBA37EEDC109E9"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'e952cc15-101e-0023-7b6a-d5486c000000'
#     'x-ms-client-request-id': 'ae67f207-415d-11ee-b2c9-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:35:14 GMT'
# INFO:custom_loader:inpex_annualreport2018_en.pdf downloaded in 8.773078680038452 seconds.
# inpex_annualreport2018_en.pdf downloaded in 8.773078680038452 seconds.
# INFO:custom_loader:Downloading completed in approximately 0min 9s.
# Downloading completed in approximately 0min 9s.
# INFO:custom_loader:Document creation starting
# Document creation starting
# INFO:custom_loader:Loading SimpleDirectoryReader from forked url: https://raw.githubusercontent.com/rivms/llama-hub/azblobmetadata/llama_hub
# Loading SimpleDirectoryReader from forked url: https://raw.githubusercontent.com/rivms/llama-hub/azblobmetadata/llama_hub
# INFO:custom_loader:Loading PDFReader from forked url: https://raw.githubusercontent.com/rivms/llama-hub/azblobmetadata/llama_hub
# Loading PDFReader from forked url: https://raw.githubusercontent.com/rivms/llama-hub/azblobmetadata/llama_hub

# %%
len(documents)
# Out:
# 98

# %%
documents[0]
# Out:
# Document(id_='738481fa-3ee8-4e31-879c-64b2d86a01fe', embedding=None, metadata={'page_label': '1', 'file_name': 'inpex_annualreport2018_en.pdf', 'page_number': 0}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='0f5ad843995bff169e4a864bb0450c4b722e9bfe6fcd4de4d6faed7cb4e5a58a', text='Annual Report 2018\nYear ended March 31, 2018\nAkasaka Biz Tower \n5-3-1 Akasaka, Minato-ku, Tokyo 107-6332, JapanPhone: +81-3-5572-0200\nhttps://www.inpex.co.jp/english', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %%
index_document(documents,
            azure_kwargs,
            service_endpoint,
            index_name,
            persist_dir,
            credential)
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.14.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# No body was attached to the request
# Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.14.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:__main__:Number of documents: 98
# Number of documents: 98
# INFO:__main__:Loading storage context from ./llama_store_synergy
# Loading storage context from ./llama_store_synergy
# INFO:__main__:Parsing nodes
# Parsing nodes
# INFO:__main__:Trying to load index from storage
# Trying to load index from storage
# INFO:llama_index.indices.loading:Loading all indices.
# Loading all indices.
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 10 of 197
# Uploading batch of size 10, current progress 10 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '385783'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f0161fc2-415d-11ee-8a1a-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '385783'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f0161fc2-415d-11ee-8a1a-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f0161fc2-415d-11ee-8a1a-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:05 GMT'
#     'Content-Length': '320'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f0161fc2-415d-11ee-8a1a-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:05 GMT'
#     'Content-Length': '320'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 20 of 197
# Uploading batch of size 10, current progress 20 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '404636'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f29c827b-415d-11ee-9783-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '404636'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f29c827b-415d-11ee-9783-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f29c827b-415d-11ee-9783-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:06 GMT'
#     'Content-Length': '323'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f29c827b-415d-11ee-9783-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:06 GMT'
#     'Content-Length': '323'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 30 of 197
# Uploading batch of size 10, current progress 30 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '402642'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f3a1e46c-415d-11ee-9eb7-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '402642'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f3a1e46c-415d-11ee-9eb7-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f3a1e46c-415d-11ee-9eb7-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:09 GMT'
#     'Content-Length': '325'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f3a1e46c-415d-11ee-9eb7-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:09 GMT'
#     'Content-Length': '325'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 40 of 197
# Uploading batch of size 10, current progress 40 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '396603'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f4c94169-415d-11ee-81de-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '396603'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f4c94169-415d-11ee-81de-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f4c94169-415d-11ee-81de-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:10 GMT'
#     'Content-Length': '323'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f4c94169-415d-11ee-81de-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:10 GMT'
#     'Content-Length': '323'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 50 of 197
# Uploading batch of size 10, current progress 50 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '391250'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f5ca28b4-415d-11ee-a8b2-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '391250'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f5ca28b4-415d-11ee-a8b2-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f5ca28b4-415d-11ee-a8b2-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:12 GMT'
#     'Content-Length': '330'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f5ca28b4-415d-11ee-a8b2-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:12 GMT'
#     'Content-Length': '330'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 60 of 197
# Uploading batch of size 10, current progress 60 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '387549'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f6b609c1-415d-11ee-85dc-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '387549'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f6b609c1-415d-11ee-85dc-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f6b609c1-415d-11ee-85dc-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:13 GMT'
#     'Content-Length': '333'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f6b609c1-415d-11ee-85dc-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:13 GMT'
#     'Content-Length': '333'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 70 of 197
# Uploading batch of size 10, current progress 70 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '389108'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f79e085a-415d-11ee-bb72-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '389108'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f79e085a-415d-11ee-bb72-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f79e085a-415d-11ee-bb72-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:15 GMT'
#     'Content-Length': '340'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f79e085a-415d-11ee-bb72-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:15 GMT'
#     'Content-Length': '340'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 80 of 197
# Uploading batch of size 10, current progress 80 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '387910'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f8644d2f-415d-11ee-9346-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '387910'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f8644d2f-415d-11ee-9346-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f8644d2f-415d-11ee-9346-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:16 GMT'
#     'Content-Length': '340'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f8644d2f-415d-11ee-9346-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:16 GMT'
#     'Content-Length': '340'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 90 of 197
# Uploading batch of size 10, current progress 90 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '406851'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f924ef1d-415d-11ee-a8aa-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '406851'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'f924ef1d-415d-11ee-a8aa-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f924ef1d-415d-11ee-a8aa-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:17 GMT'
#     'Content-Length': '337'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'f924ef1d-415d-11ee-a8aa-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:17 GMT'
#     'Content-Length': '337'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 100 of 197
# Uploading batch of size 10, current progress 100 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '404133'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fa11780b-415d-11ee-83fa-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '404133'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fa11780b-415d-11ee-83fa-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fa11780b-415d-11ee-83fa-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:19 GMT'
#     'Content-Length': '327'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fa11780b-415d-11ee-83fa-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:19 GMT'
#     'Content-Length': '327'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 110 of 197
# Uploading batch of size 10, current progress 110 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '404575'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fad618ec-415d-11ee-ab27-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '404575'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fad618ec-415d-11ee-ab27-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fad618ec-415d-11ee-ab27-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:20 GMT'
#     'Content-Length': '334'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fad618ec-415d-11ee-ab27-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:20 GMT'
#     'Content-Length': '334'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 120 of 197
# Uploading batch of size 10, current progress 120 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '401169'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fba16831-415d-11ee-88db-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '401169'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fba16831-415d-11ee-88db-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fba16831-415d-11ee-88db-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:21 GMT'
#     'Content-Length': '313'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fba16831-415d-11ee-88db-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:21 GMT'
#     'Content-Length': '313'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 130 of 197
# Uploading batch of size 10, current progress 130 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '393121'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fc6c4bfd-415d-11ee-93d2-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '393121'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fc6c4bfd-415d-11ee-93d2-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fc6c4bfd-415d-11ee-93d2-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:22 GMT'
#     'Content-Length': '333'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fc6c4bfd-415d-11ee-93d2-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:22 GMT'
#     'Content-Length': '333'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 140 of 197
# Uploading batch of size 10, current progress 140 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '389165'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fd35378d-415d-11ee-a7dc-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '389165'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fd35378d-415d-11ee-a7dc-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fd35378d-415d-11ee-a7dc-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:24 GMT'
#     'Content-Length': '337'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fd35378d-415d-11ee-a7dc-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:24 GMT'
#     'Content-Length': '337'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 150 of 197
# Uploading batch of size 10, current progress 150 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '393671'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fdf63e1e-415d-11ee-8f0b-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '393671'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fdf63e1e-415d-11ee-8f0b-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fdf63e1e-415d-11ee-8f0b-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:25 GMT'
#     'Content-Length': '333'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fdf63e1e-415d-11ee-8f0b-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:25 GMT'
#     'Content-Length': '333'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 160 of 197
# Uploading batch of size 10, current progress 160 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '385283'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fee0c318-415d-11ee-921f-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '385283'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'fee0c318-415d-11ee-921f-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fee0c318-415d-11ee-921f-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:27 GMT'
#     'Content-Length': '327'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'fee0c318-415d-11ee-921f-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:27 GMT'
#     'Content-Length': '327'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 170 of 197
# Uploading batch of size 10, current progress 170 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '387315'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'ffc557ba-415d-11ee-a91f-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '387315'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': 'ffc557ba-415d-11ee-a91f-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'ffc557ba-415d-11ee-a91f-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:28 GMT'
#     'Content-Length': '334'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': 'ffc557ba-415d-11ee-a91f-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:28 GMT'
#     'Content-Length': '334'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 180 of 197
# Uploading batch of size 10, current progress 180 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '397360'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': '008adc1d-415e-11ee-bfc5-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '397360'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': '008adc1d-415e-11ee-bfc5-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': '008adc1d-415e-11ee-bfc5-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:30 GMT'
#     'Content-Length': '337'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': '008adc1d-415e-11ee-bfc5-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:30 GMT'
#     'Content-Length': '337'
# INFO:llama_index.vector_stores.cogsearch:Uploading batch of size 10, current progress 190 of 197
# Uploading batch of size 10, current progress 190 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '393497'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': '0168f4db-415e-11ee-b14d-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '393497'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': '0168f4db-415e-11ee-b14d-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': '0168f4db-415e-11ee-b14d-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:31 GMT'
#     'Content-Length': '334'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': '0168f4db-415e-11ee-b14d-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:31 GMT'
#     'Content-Length': '334'
# INFO:llama_index.vector_stores.cogsearch:Uploading remaining batch of size 7, current progress 197 of 197
# Uploading remaining batch of size 7, current progress 197 of 197
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '265593'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': '022a72ee-415e-11ee-a121-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# Request URL: 'https://gptkb-gdm7wgiiihc5y.search.windows.net/indexes('aoaientsearchinpex')/docs/search.index?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '265593'
#     'api-key': 'REDACTED'
#     'Accept': 'application/json;odata.metadata=none'
#     'x-ms-client-request-id': '022a72ee-415e-11ee-a121-bc091bdb04fb'
#     'User-Agent': 'azsdk-python-search-documents/11.4.0b8 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': '022a72ee-415e-11ee-a121-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:32 GMT'
#     'Content-Length': '316'
# Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; odata.metadata=none'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'request-id': '022a72ee-415e-11ee-a121-bc091bdb04fb'
#     'elapsed-time': 'REDACTED'
#     'OData-Version': 'REDACTED'
#     'Preference-Applied': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:37:32 GMT'
#     'Content-Length': '316'
# INFO:__main__:Saving storage context to ./llama_store_synergy
# Saving storage context to ./llama_store_synergy

# %%
index_name

# %%
pdf = annual_reports_synergy[2]

documents = load_documents(container_name='aoaientsearchsynergy', blob=pdf, account_url=storage_account_url,
            loader_hub_url=loader_hub_fork_url)

# %%
len(documents)

# %%
documents[5]

# %%
index_document(documents,
            azure_kwargs,
            service_endpoint,
            index_name,
            persist_dir,
            credential)

# %%
local_base_dir = "C:\\Users\\rijumna\\Downloads\\"

# %%
split_pdf_container
# Out:
# 'aoaientsearchinpex'

# %%
report = annual_reports_inpex[3]
logger.info(f"Uploading report {report}")
upload_blobs(local_base_dir + report, split_pdf_storage_account, split_pdf_container)
# Out:
# INFO:__main__:Uploading report inpex_annualreport2018_en.pdf
# Uploading report inpex_annualreport2018_en.pdf
# INFO:azure.identity._credentials.environment:No environment configuration found.
# No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# ManagedIdentityCredential will use IMDS
# Starting upload: C:\Users\rijumna\Downloads\inpex_annualreport2018_en.pdf
# Starting upload: C:\Users\rijumna\Downloads\inpex_annualreport2018_en.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.14.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# No body was attached to the request
# Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.14.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureCliCredential
# DefaultAzureCredential acquired a token from AzureCliCredential
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex?restype=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '15553163-415f-11ee-a0db-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex?restype=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '15553163-415f-11ee-a0db-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Content-Length': '0'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:13:32 GMT'
#     'ETag': '"0x8DBA37E8CCD8CB5"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022a901-101e-0017-4c6b-d5cf20000000'
#     'x-ms-client-request-id': '15553163-415f-11ee-a0db-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-has-immutability-policy': 'REDACTED'
#     'x-ms-has-legal-hold': 'REDACTED'
#     'x-ms-immutable-storage-with-versioning-enabled': 'REDACTED'
#     'x-ms-default-encryption-scope': 'REDACTED'
#     'x-ms-deny-encryption-scope-override': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:17 GMT'
# Response status: 200
# Response headers:
#     'Content-Length': '0'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:13:32 GMT'
#     'ETag': '"0x8DBA37E8CCD8CB5"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022a901-101e-0017-4c6b-d5cf20000000'
#     'x-ms-client-request-id': '15553163-415f-11ee-a0db-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-has-immutability-policy': 'REDACTED'
#     'x-ms-has-legal-hold': 'REDACTED'
#     'x-ms-immutable-storage-with-versioning-enabled': 'REDACTED'
#     'x-ms-default-encryption-scope': 'REDACTED'
#     'x-ms-deny-encryption-scope-override': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:17 GMT'
# INFO:__main__:Processing pdf
# Processing pdf
# INFO:__main__:Processing 98 pages
# Processing 98 pages
# INFO:__main__:Creating blob for page 0 -> inpex_annualreport2018_en-0.pdf
# Creating blob for page 0 -> inpex_annualreport2018_en-0.pdf
# INFO:__main__:Uploading blob for page 0 of 98 -> inpex_annualreport2018_en-0.pdf
# Uploading blob for page 0 of 98 -> inpex_annualreport2018_en-0.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-0.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '237358'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1876d054-415f-11ee-80a1-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-0.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '237358'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1876d054-415f-11ee-80a1-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:21 GMT'
#     'ETag': '"0x8DBA382FE5E6B5F"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022a9e3-101e-0017-126b-d5cf20000000'
#     'x-ms-client-request-id': '1876d054-415f-11ee-80a1-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:20 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:21 GMT'
#     'ETag': '"0x8DBA382FE5E6B5F"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022a9e3-101e-0017-126b-d5cf20000000'
#     'x-ms-client-request-id': '1876d054-415f-11ee-80a1-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:20 GMT'
# INFO:__main__:Upload complete for page 0 of 98-> inpex_annualreport2018_en-0.pdf
# Upload complete for page 0 of 98-> inpex_annualreport2018_en-0.pdf
# INFO:__main__:Creating blob for page 1 -> inpex_annualreport2018_en-1.pdf
# Creating blob for page 1 -> inpex_annualreport2018_en-1.pdf
# INFO:__main__:Uploading blob for page 1 of 98 -> inpex_annualreport2018_en-1.pdf
# Uploading blob for page 1 of 98 -> inpex_annualreport2018_en-1.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-1.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '198999'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1a19eb03-415f-11ee-894d-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-1.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '198999'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1a19eb03-415f-11ee-894d-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:23 GMT'
#     'ETag': '"0x8DBA382FF83ED69"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022af42-101e-0017-4b6b-d5cf20000000'
#     'x-ms-client-request-id': '1a19eb03-415f-11ee-894d-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:22 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:23 GMT'
#     'ETag': '"0x8DBA382FF83ED69"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022af42-101e-0017-4b6b-d5cf20000000'
#     'x-ms-client-request-id': '1a19eb03-415f-11ee-894d-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:22 GMT'
# INFO:__main__:Upload complete for page 1 of 98-> inpex_annualreport2018_en-1.pdf
# Upload complete for page 1 of 98-> inpex_annualreport2018_en-1.pdf
# INFO:__main__:Creating blob for page 2 -> inpex_annualreport2018_en-2.pdf
# Creating blob for page 2 -> inpex_annualreport2018_en-2.pdf
# INFO:__main__:Uploading blob for page 2 of 98 -> inpex_annualreport2018_en-2.pdf
# Uploading blob for page 2 of 98 -> inpex_annualreport2018_en-2.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-2.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '206105'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1b408bd0-415f-11ee-a18e-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-2.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '206105'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1b408bd0-415f-11ee-a18e-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:24 GMT'
#     'ETag': '"0x8DBA38300834DC7"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022b396-101e-0017-136b-d5cf20000000'
#     'x-ms-client-request-id': '1b408bd0-415f-11ee-a18e-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:24 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:24 GMT'
#     'ETag': '"0x8DBA38300834DC7"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022b396-101e-0017-136b-d5cf20000000'
#     'x-ms-client-request-id': '1b408bd0-415f-11ee-a18e-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:24 GMT'
# INFO:__main__:Upload complete for page 2 of 98-> inpex_annualreport2018_en-2.pdf
# Upload complete for page 2 of 98-> inpex_annualreport2018_en-2.pdf
# INFO:__main__:Creating blob for page 3 -> inpex_annualreport2018_en-3.pdf
# Creating blob for page 3 -> inpex_annualreport2018_en-3.pdf
# INFO:__main__:Uploading blob for page 3 of 98 -> inpex_annualreport2018_en-3.pdf
# Uploading blob for page 3 of 98 -> inpex_annualreport2018_en-3.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-3.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '298287'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1c3e6058-415f-11ee-88f5-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-3.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '298287'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1c3e6058-415f-11ee-88f5-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:26 GMT'
#     'ETag': '"0x8DBA383018B3012"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022b73d-101e-0017-626b-d5cf20000000'
#     'x-ms-client-request-id': '1c3e6058-415f-11ee-88f5-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:25 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:26 GMT'
#     'ETag': '"0x8DBA383018B3012"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022b73d-101e-0017-626b-d5cf20000000'
#     'x-ms-client-request-id': '1c3e6058-415f-11ee-88f5-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:25 GMT'
# INFO:__main__:Upload complete for page 3 of 98-> inpex_annualreport2018_en-3.pdf
# Upload complete for page 3 of 98-> inpex_annualreport2018_en-3.pdf
# INFO:__main__:Creating blob for page 4 -> inpex_annualreport2018_en-4.pdf
# Creating blob for page 4 -> inpex_annualreport2018_en-4.pdf
# INFO:__main__:Uploading blob for page 4 of 98 -> inpex_annualreport2018_en-4.pdf
# Uploading blob for page 4 of 98 -> inpex_annualreport2018_en-4.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-4.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '298590'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1d460cee-415f-11ee-b446-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-4.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '298590'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1d460cee-415f-11ee-b446-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:27 GMT'
#     'ETag': '"0x8DBA38302401FAF"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022bac5-101e-0017-2b6b-d5cf20000000'
#     'x-ms-client-request-id': '1d460cee-415f-11ee-b446-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:26 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:27 GMT'
#     'ETag': '"0x8DBA38302401FAF"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022bac5-101e-0017-2b6b-d5cf20000000'
#     'x-ms-client-request-id': '1d460cee-415f-11ee-b446-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:26 GMT'
# INFO:__main__:Upload complete for page 4 of 98-> inpex_annualreport2018_en-4.pdf
# Upload complete for page 4 of 98-> inpex_annualreport2018_en-4.pdf
# INFO:__main__:Creating blob for page 5 -> inpex_annualreport2018_en-5.pdf
# Creating blob for page 5 -> inpex_annualreport2018_en-5.pdf
# INFO:__main__:Uploading blob for page 5 of 98 -> inpex_annualreport2018_en-5.pdf
# Uploading blob for page 5 of 98 -> inpex_annualreport2018_en-5.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-5.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '321657'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1dfe989e-415f-11ee-be23-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-5.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '321657'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1dfe989e-415f-11ee-be23-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:28 GMT'
#     'ETag': '"0x8DBA38302D63856"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022bd7f-101e-0017-3c6b-d5cf20000000'
#     'x-ms-client-request-id': '1dfe989e-415f-11ee-be23-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:27 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:28 GMT'
#     'ETag': '"0x8DBA38302D63856"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022bd7f-101e-0017-3c6b-d5cf20000000'
#     'x-ms-client-request-id': '1dfe989e-415f-11ee-be23-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:27 GMT'
# INFO:__main__:Upload complete for page 5 of 98-> inpex_annualreport2018_en-5.pdf
# Upload complete for page 5 of 98-> inpex_annualreport2018_en-5.pdf
# INFO:__main__:Creating blob for page 6 -> inpex_annualreport2018_en-6.pdf
# Creating blob for page 6 -> inpex_annualreport2018_en-6.pdf
# INFO:__main__:Uploading blob for page 6 of 98 -> inpex_annualreport2018_en-6.pdf
# Uploading blob for page 6 of 98 -> inpex_annualreport2018_en-6.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-6.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '848575'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1e91da8b-415f-11ee-8734-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-6.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '848575'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1e91da8b-415f-11ee-8734-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:30 GMT'
#     'ETag': '"0x8DBA38303C42038"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022bf61-101e-0017-7e6b-d5cf20000000'
#     'x-ms-client-request-id': '1e91da8b-415f-11ee-8734-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:29 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:30 GMT'
#     'ETag': '"0x8DBA38303C42038"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022bf61-101e-0017-7e6b-d5cf20000000'
#     'x-ms-client-request-id': '1e91da8b-415f-11ee-8734-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:29 GMT'
# INFO:__main__:Upload complete for page 6 of 98-> inpex_annualreport2018_en-6.pdf
# Upload complete for page 6 of 98-> inpex_annualreport2018_en-6.pdf
# INFO:__main__:Creating blob for page 7 -> inpex_annualreport2018_en-7.pdf
# Creating blob for page 7 -> inpex_annualreport2018_en-7.pdf
# INFO:__main__:Uploading blob for page 7 of 98 -> inpex_annualreport2018_en-7.pdf
# Uploading blob for page 7 of 98 -> inpex_annualreport2018_en-7.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-7.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '143907'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1f800ff4-415f-11ee-830d-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-7.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '143907'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '1f800ff4-415f-11ee-830d-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:31 GMT'
#     'ETag': '"0x8DBA38304473B74"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c277-101e-0017-526b-d5cf20000000'
#     'x-ms-client-request-id': '1f800ff4-415f-11ee-830d-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:30 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:31 GMT'
#     'ETag': '"0x8DBA38304473B74"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c277-101e-0017-526b-d5cf20000000'
#     'x-ms-client-request-id': '1f800ff4-415f-11ee-830d-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:30 GMT'
# INFO:__main__:Upload complete for page 7 of 98-> inpex_annualreport2018_en-7.pdf
# Upload complete for page 7 of 98-> inpex_annualreport2018_en-7.pdf
# INFO:__main__:Creating blob for page 8 -> inpex_annualreport2018_en-8.pdf
# Creating blob for page 8 -> inpex_annualreport2018_en-8.pdf
# INFO:__main__:Uploading blob for page 8 of 98 -> inpex_annualreport2018_en-8.pdf
# Uploading blob for page 8 of 98 -> inpex_annualreport2018_en-8.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-8.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '146527'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '200403a0-415f-11ee-b41b-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-8.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '146527'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '200403a0-415f-11ee-b41b-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:31 GMT'
#     'ETag': '"0x8DBA38304B33F38"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c409-101e-0017-3f6b-d5cf20000000'
#     'x-ms-client-request-id': '200403a0-415f-11ee-b41b-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:31 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:31 GMT'
#     'ETag': '"0x8DBA38304B33F38"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c409-101e-0017-3f6b-d5cf20000000'
#     'x-ms-client-request-id': '200403a0-415f-11ee-b41b-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:31 GMT'
# INFO:__main__:Upload complete for page 8 of 98-> inpex_annualreport2018_en-8.pdf
# Upload complete for page 8 of 98-> inpex_annualreport2018_en-8.pdf
# INFO:__main__:Creating blob for page 9 -> inpex_annualreport2018_en-9.pdf
# Creating blob for page 9 -> inpex_annualreport2018_en-9.pdf
# INFO:__main__:Uploading blob for page 9 of 98 -> inpex_annualreport2018_en-9.pdf
# Uploading blob for page 9 of 98 -> inpex_annualreport2018_en-9.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-9.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '151275'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '20704f24-415f-11ee-81bd-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-9.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '151275'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '20704f24-415f-11ee-81bd-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:32 GMT'
#     'ETag': '"0x8DBA383050E8D04"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c538-101e-0017-5e6b-d5cf20000000'
#     'x-ms-client-request-id': '20704f24-415f-11ee-81bd-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:31 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:32 GMT'
#     'ETag': '"0x8DBA383050E8D04"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c538-101e-0017-5e6b-d5cf20000000'
#     'x-ms-client-request-id': '20704f24-415f-11ee-81bd-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:31 GMT'
# INFO:__main__:Upload complete for page 9 of 98-> inpex_annualreport2018_en-9.pdf
# Upload complete for page 9 of 98-> inpex_annualreport2018_en-9.pdf
# INFO:__main__:Creating blob for page 10 -> inpex_annualreport2018_en-10.pdf
# Creating blob for page 10 -> inpex_annualreport2018_en-10.pdf
# INFO:__main__:Uploading blob for page 10 of 98 -> inpex_annualreport2018_en-10.pdf
# Uploading blob for page 10 of 98 -> inpex_annualreport2018_en-10.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-10.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '40309'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '20c9c52a-415f-11ee-9ae8-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-10.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '40309'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '20c9c52a-415f-11ee-9ae8-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:32 GMT'
#     'ETag': '"0x8DBA383053EDC61"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c656-101e-0017-5f6b-d5cf20000000'
#     'x-ms-client-request-id': '20c9c52a-415f-11ee-9ae8-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:31 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:32 GMT'
#     'ETag': '"0x8DBA383053EDC61"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c656-101e-0017-5f6b-d5cf20000000'
#     'x-ms-client-request-id': '20c9c52a-415f-11ee-9ae8-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:31 GMT'
# INFO:__main__:Upload complete for page 10 of 98-> inpex_annualreport2018_en-10.pdf
# Upload complete for page 10 of 98-> inpex_annualreport2018_en-10.pdf
# INFO:__main__:Creating blob for page 11 -> inpex_annualreport2018_en-11.pdf
# Creating blob for page 11 -> inpex_annualreport2018_en-11.pdf
# INFO:__main__:Uploading blob for page 11 of 98 -> inpex_annualreport2018_en-11.pdf
# Uploading blob for page 11 of 98 -> inpex_annualreport2018_en-11.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-11.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '137173'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '20f94d01-415f-11ee-9b8a-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-11.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '137173'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '20f94d01-415f-11ee-9b8a-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:33 GMT'
#     'ETag': '"0x8DBA38305957472"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c6dd-101e-0017-626b-d5cf20000000'
#     'x-ms-client-request-id': '20f94d01-415f-11ee-9b8a-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:32 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:33 GMT'
#     'ETag': '"0x8DBA38305957472"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c6dd-101e-0017-626b-d5cf20000000'
#     'x-ms-client-request-id': '20f94d01-415f-11ee-9b8a-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:32 GMT'
# INFO:__main__:Upload complete for page 11 of 98-> inpex_annualreport2018_en-11.pdf
# Upload complete for page 11 of 98-> inpex_annualreport2018_en-11.pdf
# INFO:__main__:Creating blob for page 12 -> inpex_annualreport2018_en-12.pdf
# Creating blob for page 12 -> inpex_annualreport2018_en-12.pdf
# INFO:__main__:Uploading blob for page 12 of 98 -> inpex_annualreport2018_en-12.pdf
# Uploading blob for page 12 of 98 -> inpex_annualreport2018_en-12.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-12.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '93718'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '2152c9cb-415f-11ee-9cd7-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-12.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '93718'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '2152c9cb-415f-11ee-9cd7-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:33 GMT'
#     'ETag': '"0x8DBA38305CC7320"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c7c6-101e-0017-396b-d5cf20000000'
#     'x-ms-client-request-id': '2152c9cb-415f-11ee-9cd7-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:32 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:33 GMT'
#     'ETag': '"0x8DBA38305CC7320"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c7c6-101e-0017-396b-d5cf20000000'
#     'x-ms-client-request-id': '2152c9cb-415f-11ee-9cd7-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:32 GMT'
# INFO:__main__:Upload complete for page 12 of 98-> inpex_annualreport2018_en-12.pdf
# Upload complete for page 12 of 98-> inpex_annualreport2018_en-12.pdf
# INFO:__main__:Creating blob for page 13 -> inpex_annualreport2018_en-13.pdf
# Creating blob for page 13 -> inpex_annualreport2018_en-13.pdf
# INFO:__main__:Uploading blob for page 13 of 98 -> inpex_annualreport2018_en-13.pdf
# Uploading blob for page 13 of 98 -> inpex_annualreport2018_en-13.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-13.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '45533'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '218a1f6c-415f-11ee-a85a-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-13.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '45533'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '218a1f6c-415f-11ee-a85a-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:33 GMT'
#     'ETag': '"0x8DBA38305FD3740"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c85b-101e-0017-496b-d5cf20000000'
#     'x-ms-client-request-id': '218a1f6c-415f-11ee-a85a-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:33 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:33 GMT'
#     'ETag': '"0x8DBA38305FD3740"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c85b-101e-0017-496b-d5cf20000000'
#     'x-ms-client-request-id': '218a1f6c-415f-11ee-a85a-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:33 GMT'
# INFO:__main__:Upload complete for page 13 of 98-> inpex_annualreport2018_en-13.pdf
# Upload complete for page 13 of 98-> inpex_annualreport2018_en-13.pdf
# INFO:__main__:Creating blob for page 14 -> inpex_annualreport2018_en-14.pdf
# Creating blob for page 14 -> inpex_annualreport2018_en-14.pdf
# INFO:__main__:Uploading blob for page 14 of 98 -> inpex_annualreport2018_en-14.pdf
# Uploading blob for page 14 of 98 -> inpex_annualreport2018_en-14.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-14.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '49610'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '21ba58c2-415f-11ee-99c3-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-14.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '49610'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '21ba58c2-415f-11ee-99c3-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:34 GMT'
#     'ETag': '"0x8DBA383062DFB5F"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c924-101e-0017-6f6b-d5cf20000000'
#     'x-ms-client-request-id': '21ba58c2-415f-11ee-99c3-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:33 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:34 GMT'
#     'ETag': '"0x8DBA383062DFB5F"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c924-101e-0017-6f6b-d5cf20000000'
#     'x-ms-client-request-id': '21ba58c2-415f-11ee-99c3-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:33 GMT'
# INFO:__main__:Upload complete for page 14 of 98-> inpex_annualreport2018_en-14.pdf
# Upload complete for page 14 of 98-> inpex_annualreport2018_en-14.pdf
# INFO:__main__:Creating blob for page 15 -> inpex_annualreport2018_en-15.pdf
# Creating blob for page 15 -> inpex_annualreport2018_en-15.pdf
# INFO:__main__:Uploading blob for page 15 of 98 -> inpex_annualreport2018_en-15.pdf
# Uploading blob for page 15 of 98 -> inpex_annualreport2018_en-15.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-15.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '70012'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '21ed9b49-415f-11ee-a489-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-15.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '70012'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '21ed9b49-415f-11ee-a489-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:34 GMT'
#     'ETag': '"0x8DBA3830662B2AA"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c9c4-101e-0017-096b-d5cf20000000'
#     'x-ms-client-request-id': '21ed9b49-415f-11ee-a489-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:45:33 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:45:34 GMT'
#     'ETag': '"0x8DBA3830662B2AA"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1022c9c4-101e-0017-096b-d5cf20000000'
#     'x-ms-client-request-id': '21ed9b49-415f-11ee-a489-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
# ...
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '40d1e5d6-415f-11ee-9630-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-92.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '58824'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '40d1e5d6-415f-11ee-9630-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:26 GMT'
#     'ETag': '"0x8DBA383255020CA"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233a68-101e-0017-1f6c-d5cf20000000'
#     'x-ms-client-request-id': '40d1e5d6-415f-11ee-9630-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:25 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:26 GMT'
#     'ETag': '"0x8DBA383255020CA"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233a68-101e-0017-1f6c-d5cf20000000'
#     'x-ms-client-request-id': '40d1e5d6-415f-11ee-9630-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:25 GMT'
# INFO:__main__:Upload complete for page 92 of 98-> inpex_annualreport2018_en-92.pdf
# Upload complete for page 92 of 98-> inpex_annualreport2018_en-92.pdf
# INFO:__main__:Creating blob for page 93 -> inpex_annualreport2018_en-93.pdf
# Creating blob for page 93 -> inpex_annualreport2018_en-93.pdf
# INFO:__main__:Uploading blob for page 93 of 98 -> inpex_annualreport2018_en-93.pdf
# Uploading blob for page 93 of 98 -> inpex_annualreport2018_en-93.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-93.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '58655'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '412de813-415f-11ee-9075-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-93.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '58655'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '412de813-415f-11ee-9075-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:27 GMT'
#     'ETag': '"0x8DBA38325B30709"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233ba0-101e-0017-4c6c-d5cf20000000'
#     'x-ms-client-request-id': '412de813-415f-11ee-9075-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:26 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:27 GMT'
#     'ETag': '"0x8DBA38325B30709"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233ba0-101e-0017-4c6c-d5cf20000000'
#     'x-ms-client-request-id': '412de813-415f-11ee-9075-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:26 GMT'
# INFO:__main__:Upload complete for page 93 of 98-> inpex_annualreport2018_en-93.pdf
# Upload complete for page 93 of 98-> inpex_annualreport2018_en-93.pdf
# INFO:__main__:Creating blob for page 94 -> inpex_annualreport2018_en-94.pdf
# Creating blob for page 94 -> inpex_annualreport2018_en-94.pdf
# INFO:__main__:Uploading blob for page 94 of 98 -> inpex_annualreport2018_en-94.pdf
# Uploading blob for page 94 of 98 -> inpex_annualreport2018_en-94.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-94.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '52500'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '418fc926-415f-11ee-a8af-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-94.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '52500'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '418fc926-415f-11ee-a8af-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:27 GMT'
#     'ETag': '"0x8DBA3832611FA27"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233cde-101e-0017-706c-d5cf20000000'
#     'x-ms-client-request-id': '418fc926-415f-11ee-a8af-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:26 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:27 GMT'
#     'ETag': '"0x8DBA3832611FA27"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233cde-101e-0017-706c-d5cf20000000'
#     'x-ms-client-request-id': '418fc926-415f-11ee-a8af-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:26 GMT'
# INFO:__main__:Upload complete for page 94 of 98-> inpex_annualreport2018_en-94.pdf
# Upload complete for page 94 of 98-> inpex_annualreport2018_en-94.pdf
# INFO:__main__:Creating blob for page 95 -> inpex_annualreport2018_en-95.pdf
# Creating blob for page 95 -> inpex_annualreport2018_en-95.pdf
# INFO:__main__:Uploading blob for page 95 of 98 -> inpex_annualreport2018_en-95.pdf
# Uploading blob for page 95 of 98 -> inpex_annualreport2018_en-95.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-95.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '45439'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '41d00a56-415f-11ee-8de4-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-95.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '45439'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '41d00a56-415f-11ee-8de4-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:28 GMT'
#     'ETag': '"0x8DBA38326441C43"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233d9e-101e-0017-236c-d5cf20000000'
#     'x-ms-client-request-id': '41d00a56-415f-11ee-8de4-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:27 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:28 GMT'
#     'ETag': '"0x8DBA38326441C43"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233d9e-101e-0017-236c-d5cf20000000'
#     'x-ms-client-request-id': '41d00a56-415f-11ee-8de4-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:27 GMT'
# INFO:__main__:Upload complete for page 95 of 98-> inpex_annualreport2018_en-95.pdf
# Upload complete for page 95 of 98-> inpex_annualreport2018_en-95.pdf
# INFO:__main__:Creating blob for page 96 -> inpex_annualreport2018_en-96.pdf
# Creating blob for page 96 -> inpex_annualreport2018_en-96.pdf
# INFO:__main__:Uploading blob for page 96 of 98 -> inpex_annualreport2018_en-96.pdf
# Uploading blob for page 96 of 98 -> inpex_annualreport2018_en-96.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-96.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '34994'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '4201d751-415f-11ee-96d7-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-96.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '34994'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '4201d751-415f-11ee-96d7-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:28 GMT'
#     'ETag': '"0x8DBA383267727C5"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233e47-101e-0017-416c-d5cf20000000'
#     'x-ms-client-request-id': '4201d751-415f-11ee-96d7-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:27 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:28 GMT'
#     'ETag': '"0x8DBA383267727C5"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233e47-101e-0017-416c-d5cf20000000'
#     'x-ms-client-request-id': '4201d751-415f-11ee-96d7-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:27 GMT'
# INFO:__main__:Upload complete for page 96 of 98-> inpex_annualreport2018_en-96.pdf
# Upload complete for page 96 of 98-> inpex_annualreport2018_en-96.pdf
# INFO:__main__:Creating blob for page 97 -> inpex_annualreport2018_en-97.pdf
# Creating blob for page 97 -> inpex_annualreport2018_en-97.pdf
# INFO:__main__:Uploading blob for page 97 of 98 -> inpex_annualreport2018_en-97.pdf
# Uploading blob for page 97 of 98 -> inpex_annualreport2018_en-97.pdf
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-97.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '267803'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '42322823-415f-11ee-bed5-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# Request URL: 'https://stgdm7wgiiihc5y.blob.core.windows.net/aoaientsearchinpex/inpex_annualreport2018_en-97.pdf'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '267803'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.17.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '42322823-415f-11ee-bed5-bc091bdb04fb'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:29 GMT'
#     'ETag': '"0x8DBA38326EB8693"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233ef2-101e-0017-626c-d5cf20000000'
#     'x-ms-client-request-id': '42322823-415f-11ee-bed5-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:28 GMT'
# Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Wed, 23 Aug 2023 02:46:29 GMT'
#     'ETag': '"0x8DBA38326EB8693"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '10233ef2-101e-0017-626c-d5cf20000000'
#     'x-ms-client-request-id': '42322823-415f-11ee-bed5-bc091bdb04fb'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Wed, 23 Aug 2023 02:46:28 GMT'
# INFO:__main__:Upload complete for page 97 of 98-> inpex_annualreport2018_en-97.pdf
# Upload complete for page 97 of 98-> inpex_annualreport2018_en-97.pdf

# %%
upload_blobs(local_base_dir + annual_reports[4], split_pdf_storage_account, split_pdf_container)

# %%
upload_blobs(local_base_dir + annual_reports[12], split_pdf_storage_account, split_pdf_container)
