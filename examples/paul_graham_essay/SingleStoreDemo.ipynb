# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader, Document
from llama_index.vector_stores import SingleStoreVectorStore
import textwrap

# %%
import openai

openai.api_key = "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"

# %%
# load documents
# load documents
import os
from llama_index import SimpleDirectoryReader
from llama_index.node_parser import SimpleNodeParser

data_dir = "../paul_graham_essay/data/"
documents = SimpleDirectoryReader(data_dir).load_data()
parser = SimpleNodeParser.from_defaults(chunk_size=200, chunk_overlap=20)

nodes = parser.get_nodes_from_documents(documents)
print("Document ID:", documents[0].doc_id)
# Out:
# DEBUG:llama_index.readers.file.base:> [SimpleDirectoryReader] Total files added: 1
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: What I Worked On
#
# February 2021
#
# Before college...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: It was like a mini Bond villain's lair down the...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: The only other option was to do things that did...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: [1]
#
# The first of my friends to get a microcomp...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: Though I liked programming, I didn't plan to st...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: So I decided to switch to AI.
#
# AI was in the ai...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: Which meant learning Lisp, since in those days ...
# DEBUG:llama_index.node_parser.node_utils:> Adding chunk: My God did I love working on that program. It w...
# ...

# %%
# Create an index over the documnts
from llama_index.storage.storage_context import StorageContext
import os

os.environ["SINGLESTOREDB_URL"] = "admin:auzyivMpXbND0vJpjKNiA0cT2fCBoVI9@svc-e6090846-4556-4e7f-b98b-28ae9c6aec5f-dml.aws-oregon-3.svc.singlestore.com:3306/demo"
vector_store = SingleStoreVectorStore().delete("5fa904a3-2d30-4835-ba76-bff1fd027f39")
# storage_context = StorageContext.from_defaults(vector_store=vector_store)
# index = VectorStoreIndex(nodes, storage_context=storage_context)

# %%
query_engine = index.as_query_engine()
response = query_engine.query("What did the author learn?")
print(response)
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What did the author learn?"], "model": "text-embedding-ada-002", "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/embeddings processing_ms=44 request_id=9569f43c4dd199c1063c3b128564ad95 response_code=200
# ...

# %%
response = query_engine.query("What happened with the author's mom?")
print(response)
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What happened with the author\'s mom?"], "model": "text-embedding-ada-002", "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/embeddings processing_ms=41 request_id=5dfdbacda056648d8667eba68a6bf8c4 response_code=200
# ...
