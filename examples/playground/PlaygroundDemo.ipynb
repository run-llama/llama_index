# %%
# My OpenAI Key
import os
os.environ['OPENAI_API_KEY'] = "INSERT OPENAI KEY"

# %%
# Hide INFO logs regarding token usage, etc
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %% [markdown]
# ## Setup
#
# ### Generate some example Documents

# %%
from llama_index import download_loader
from llama_index.indices.vector_store import GPTSimpleVectorIndex
from llama_index.indices.tree.base import GPTTreeIndex

WikipediaReader = download_loader("WikipediaReader")

loader = WikipediaReader()
documents = loader.load_data(pages=['Berlin'])

# %% [markdown]
# ### Create a list of any sort of indices (custom LLMs, custom embeddings, etc)

# %%
indices = [GPTSimpleVectorIndex(documents), GPTTreeIndex(documents)]

# save indices to disk for later use
indices[0].save_to_disk("simple_vector_index.json")
indices[1].save_to_disk("tree_index.json")

# %% [markdown]
# ## Using the Playground
#
#
# ### Initialize with indices

# %%
# load from disk
indices = [GPTSimpleVectorIndex.load_from_disk('simple_vector_index.json'), GPTTreeIndex.load_from_disk('tree_index.json')]
from gpt_index.playground import Playground

playground = Playground(indices=indices)

# %%
from gpt_index.optimzation.optimizer import Optimizer
# playground.compare("What is the population of Berlin?")
playground.compare_with_optimizer("What is the population of Berlin?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the population of Berlin?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.util.retry:Converted retries value: 2 -> Retry(total=2, connect=None, read=None, redirect=None, status=None)
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.openai.com:443
# Query:
# What is the population of Berlin?
#
# Trying 10 combinations...
#
#
# GPTSimpleVectorIndex, mode = default
# Without optimization
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 8417
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=11238 request_id=e8474a8bcde1face097989528e0dd8df response_code=200
# DEBUG:gpt_index.indices.utils:> Top 1 nodes:
# > [Node d5697215-97ee-419e-924a-03e4b6b1c1c5] [Similarity score:             0.865199] Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen)) is the capital and largest city of Germany by bot...
# DEBUG:root:> Searching in chunk: Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen))...
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# DEBUG:openai:api_version=None data='{"prompt": ["Context information is below. \\n---------------------\\nBerlin ( bur-LIN, German: [b\\u025b\\u0250\\u032f\\u02c8li\\u02d0n] (listen)) is the capital and largest city of Germany by both area and population. Its 3.7 million inhabitants make it the European Union\'s most populous city, according to population within city limits. One of Germany\'s sixteen constituent states, Berlin is surrounded by the State of Brandenburg and contiguous with Potsdam, Brandenburg\'s capital. Berlin\'s urban area, which has a population of around 4.5 million, is the second most populous urban area in Germany after the Ruhr. The Berlin-Brandenburg capital region has around 6.2 million inhabitants and is Germany\'s third-largest metropolitan region after the Rhine-Ruhr and Rhine-Main regions.Berlin straddles the banks of the Spree, which flows into the Havel (a tributary of the Elbe) in the western borough of Spandau. Among the city\'s main topographical features are the many lakes in the western and southeastern boroughs formed by the Spree, Havel and Dahme, the largest of which is Lake M\\u00fcggelsee. Due to its location in the European Plain, Berlin is influenced by a temperate seasonal climate. About one-third of the city\'s area is composed of forests, parks, gardens, rivers, canals, and lakes. The city lies in the Central German dialect area, the Berlin dialect being a variant of the Lusatian-New Marchian dialects.\\nFirst documented in the 13th century and at the crossing of two important historic trade routes, Berlin became the capital of the Margraviate of Brandenburg (1417\\u20131701), Kingdom of Prussia (1701\\u20131918), German Empire (1871\\u20131918), Weimar Republic (1919\\u20131933), and Nazi Germany (1933\\u20131945). Berlin has served as a scientific, artistic and philosophical hub of the Enlightenment, Neoclassicism, and liberal revolution. The Gr\\u00fcnderzeitcode: deu promoted to code: de  era\'s \\nindustrialization-induced economic boom multiplied Berlin\'s population rapidly. Berlin in the roaring 1920s was the third-largest city in the world by population.After World War II and its subsequent occupation by the victorious countries, the devastated city was divided; West Berlin became a de facto exclave of West Germany, surrounded by the Berlin Wall (from August 1961 to November 1989) and East German territory. East Berlin was declared capital of East Germany, while Bonn became the West German capital. Following German reunification in 1990, Berlin once again became the capital of all of Germany.\\nBerlin is a world city of culture, politics, media and science. Its economy is based on high-tech firms and the service sector, encompassing a diverse range of creative industries, startup companies, research facilities, media corporations, and convention venues. Berlin serves as a continental hub for air and rail traffic and has a highly complex public transportation network. The metropolis is a popular tourist destination. Significant industries also include information technology, healthcare, biomedical engineering, biotechnology, automotive, construction, electronics, social economy and clean tech.\\nBerlin is home to world-renowned universities such as the Humboldt University, Technical University, Free University, University of the Arts, ESMT Berlin, Hertie School, and Bard College Berlin. Its Zoological Garden is the most visited zoo in Europe and one of the most popular worldwide. With Babelsberg being the world\'s first large-scale movie studio complex, Berlin is an increasingly popular location for international film productions. The city is well known for its festivals, diverse architecture, nightlife, contemporary arts, and a very high quality of life.Berlin is also home to three World Heritage Sites: Museum Island; the Palaces and Parks of Potsdam and Berlin; and the Modernism Housing Estates. Other landmarks include the Brandenburg Gate, Reichstag building, Potsdamer P ...
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/completions HTTP/1.1" 200 334
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=1213 request_id=390f20452a9882f32c166acc8e13791f response_code=200
# DEBUG:root:
# The population of Berlin is approximately 3.7 million inhabitants.
# DEBUG:root:> Initial response:
# The population of Berlin is approximately 3.7 million inhabitants.
# DEBUG:root:> Refine context: the Western Allies extended the currency reform...
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# DEBUG:openai:api_version=None data='{"prompt": ["The original question is as follows: What is the population of Berlin?\\nWe have provided an existing answer: \\nThe population of Berlin is approximately 3.7 million inhabitants.\\nWe have the opportunity to refine the existing answer (only if needed) with some more context below.\\n------------\\nthe Western Allies extended the currency reform in the Western zones of Germany to the three western sectors of Berlin, the Soviet Union imposed a blockade on the access routes to and from West Berlin, which lay entirely inside Soviet-controlled territory. The Berlin airlift, conducted by the three western Allies, overcame this blockade by supplying food and other supplies to the city from June 1948 to May 1949. In 1949, the Federal Republic of Germany was founded in West Germany and eventually included all of the American, British and French zones, excluding those three countries\' zones in Berlin, while the Marxist-Leninist German Democratic Republic was proclaimed in East Germany. West Berlin officially remained an occupied city, but it politically was aligned with the Federal Republic of Germany despite West Berlin\'s geographic isolation. Airline service to West Berlin was granted only to American, British\\n------------\\nGiven the new context, refine the original answer to better answer the question. If the context isn\'t useful, return the original answer."], "model": "text-davinci-003", "temperature": 0.0, "max_tokens": 256, "top_p": 1, "frequency_penalty": 0, "presence_penalty": 0, "n": 1, "best_of": 1, "logit_bias": {}}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/completions HTTP/1.1" 200 535
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=1523 request_id=5daf07d8295f6016a488d3c67c508c4d response_code=200
# DEBUG:root:
# The population of Berlin is approximately 3.7 million inhabitants, with the city divided into East and West Berlin during the Cold War. West Berlin was politically aligned with the Federal Republic of Germany, while East Berlin was part of the German Democratic Republic.
# DEBUG:root:> Refined response:
# The population of Berlin is approximately 3.7 million inhabitants, with the city divided into East and West Berlin during the Cold War. West Berlin was politically aligned with the Federal Republic of Germany, while East Berlin was part of the German Democratic Republic.
# INFO:root:> [query] Total LLM token usage: 3467 tokens
# INFO:root:> [query] Total embedding token usage: 7 tokens
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the population of Berlin?"], "encoding_format": "base64"}' message='Post details'
# The population of Berlin is approximately 3.7 million inhabitants, with the city divided into East and West Berlin during the Cold War. West Berlin was politically aligned with the Federal Republic of Germany, while East Berlin was part of the German Democratic Republic.
#
# With optimization
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 8417
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=1468 request_id=9d3f8976889d486800473ba62eed2a1f response_code=200
# DEBUG:gpt_index.indices.utils:> Top 1 nodes:
# > [Node d5697215-97ee-419e-924a-03e4b6b1c1c5] [Similarity score:             0.865203] Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen)) is the capital and largest city of Germany by bot...
# DEBUG:root:> Searching in chunk: Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen))...
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the population of Berlin?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 8417
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=753 request_id=8a044fa5d71532c40db81ba4c263d462 response_code=200
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["Berlin ( bur-LIN, German: [b\\u025b\\u0250\\u032f\\u02c8li\\u02d0n] (listen)) is the capital and largest city of Germany by both area and population.", "Its 3.7 million inhabitants make it the European Union\'s most populous city, according to population within city limits.", "One of Germany\'s sixteen constituent states, Berlin is surrounded by the State of Brandenburg and contiguous with Potsdam, Brandenburg\'s capital.", "Berlin\'s urban area, which has a population of around 4.5 million, is the second most populous urban area in Germany after the Ruhr.", "The Berlin-Brandenburg capital region has around 6.2 million inhabitants and is Germany\'s third-largest metropolitan region after the Rhine-Ruhr and Rhine-Main regions.Berlin straddles the banks of the Spree, which flows into the Havel (a tributary of the Elbe) in the western borough of Spandau.", "Among the city\'s main topographical features are the many lakes in the western and southeastern boroughs formed by the Spree, Havel and Dahme, the largest of which is Lake M\\u00fcggelsee.", "Due to its location in the European Plain, Berlin is influenced by a temperate seasonal climate.", "About one-third of the city\'s area is composed of forests, parks, gardens, rivers, canals, and lakes.", "The city lies in the Central German dialect area, the Berlin dialect being a variant of the Lusatian-New Marchian dialects.", "First documented in the 13th century and at the crossing of two important historic trade routes, Berlin became the capital of the Margraviate of Brandenburg (1417\\u20131701), Kingdom of Prussia (1701\\u20131918), German Empire (1871\\u20131918), Weimar Republic (1919\\u20131933), and Nazi Germany (1933\\u20131945).", "Berlin has served as a scientific, artistic and philosophical hub of the Enlightenment, Neoclassicism, and liberal revolution.", "The Gr\\u00fcnderzeitcode: deu promoted to code: de  era\'s  industrialization-induced economic boom multiplied Berlin\'s population rapidly.", "Berlin in the roaring 1920s was the third-largest city in the world by population.After World War II and its subsequent occupation by the victorious countries, the devastated city was divided; West Berlin became a de facto exclave of West Germany, surrounded by the Berlin Wall (from August 1961 to November 1989) and East German territory.", "East Berlin was declared capital of East Germany, while Bonn became the West German capital.", "Following German reunification in 1990, Berlin once again became the capital of all of Germany.", "Berlin is a world city of culture, politics, media and science.", "Its economy is based on high-tech firms and the service sector, encompassing a diverse range of creative industries, startup companies, research facilities, media corporations, and convention venues.", "Berlin serves as a continental hub for air and rail traffic and has a highly complex public transportation network.", "The metropolis is a popular tourist destination.", "Significant industries also include information technology, healthcare, biomedical engineering, biotechnology, automotive, construction, electronics, social economy and clean tech.", "Berlin is home to world-renowned universities such as the Humboldt University, Technical University, Free University, University of the Arts, ESMT Berlin, Hertie School, and Bard College Berlin.", "Its Zoological Garden is the most visited zoo in Europe and one of the most popular worldwide.", "With Babelsberg being the world\'s first large-scale movie studio complex, Berlin is an increasingly popular location for international film productions.", "The city is well known for its festivals, diverse architecture, nightlife, contemporary arts, and a very high quality of life.Berlin is also home to three World Heritage Sites: Museum Island; the Palaces and Parks of Potsdam and Berlin; and the Modernism Housing Estates.", "Other landmarks include the Brandenburg Gate, Reichstag building, Potsd ...
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 811089
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=536 request_id=51cb51a2d6abfcea7e6572bc9d4ba5c6 response_code=200
# DEBUG:root:> Top 49 sentences with scores:
#
# DEBUG:root:0. Berlin's urban area, which has a population of around 4.5 million, is the second most populous urban area in Germany after the Ruhr. (0.905468048028269)
# DEBUG:root:1. The population almost doubled, and Berlin had a population of around four million. (0.8966914162322519)
# DEBUG:root:2. The Berlin-Brandenburg capital region has around 6.2 million inhabitants and is Germany's third-largest metropolitan region after the Rhine-Ruhr and Rhine-Main regions.Berlin straddles the banks of the Spree, which flows into the Havel (a tributary of the Elbe) in the western borough of Spandau. (0.8862610504325337)
# DEBUG:root:3. Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen)) is the capital and largest city of Germany by both area and population. (0.8742966730860877)
# DEBUG:root:4. Berlin is a world city of culture, politics, media and science. (0.8584479889329382)
# DEBUG:root:5. Berlin in the roaring 1920s was the third-largest city in the world by population.After World War II and its subsequent occupation by the victorious countries, the devastated city was divided; West Berlin became a de facto exclave of West Germany, surrounded by the Berlin Wall (from August 1961 to November 1989) and East German territory. (0.8547518402640698)
# DEBUG:root:6. One of Germany's sixteen constituent states, Berlin is surrounded by the State of Brandenburg and contiguous with Potsdam, Brandenburg's capital. (0.8529926982988663)
# DEBUG:root:7. Additional suburbs soon developed and increased the area and population of Berlin. (0.8525451004037792)
# DEBUG:root:8. Its 3.7 million inhabitants make it the European Union's most populous city, according to population within city limits. (0.8476876409655044)
# DEBUG:root:9. The act increased the area of Berlin from 66 to 883 km2 (25 to 341 sq mi). (0.8451865707372916)
# DEBUG:root:10. In 1920, the Greater Berlin Act incorporated dozens of suburban cities, villages, and estates around Berlin into an expanded city. (0.8394191022367227)
# DEBUG:root:11. The first written records of towns in the area of present-day Berlin date from the late 12th century. (0.8376022085753964)
# DEBUG:root:12. The central part of Berlin can be traced back to two towns. (0.8370235574542222)
# DEBUG:root:13. First documented in the 13th century and at the crossing of two important historic trade routes, Berlin became the capital of the Margraviate of Brandenburg (1417–1701), Kingdom of Prussia (1701–1918), German Empire (1871–1918), Weimar Republic (1919–1933), and Nazi Germany (1933–1945). (0.8368380852457892)
# DEBUG:root:14. Berlin serves as a continental hub for air and rail traffic and has a highly complex public transportation network. (0.8343606583073834)
# DEBUG:root:15. In 1709, Berlin merged with the four cities of Cölln, Friedrichswerder, Friedrichstadt and Dorotheenstadt under the name Berlin, "Haupt- und Residenzstadt Berlin".In 1740, Frederick II, known as Frederick the Great (1740–1786), came to power. (0.8335824429169714)
# DEBUG:root:16. NSDAP rule diminished Berlin's Jewish community from 160,000 (one-third of all Jews in the country) to about 80,000 due to emigration between 1933 and 1939. (0.8306621389726212)
# DEBUG:root:17. After the end of the war in Europe in May 1945, Berlin received large numbers of refugees from the Eastern provinces. (0.8305148675419999)
# DEBUG:root:18. In 1871, Berlin became capital of the newly founded German Empire. (0.8304767992762997)
# DEBUG:root:19. In 1815, the city became part of the new Province of Brandenburg.The Industrial Revolution transformed Berlin during the 19th century; the city's economy and population expanded dramatically, and it became the main railway hub and economic center of Germany. (0.8288733561705633)
# DEBUG:root:20. With Babelsberg being the world's first large-scale movie studio complex, Berlin is an increasingly popular location for international film productions. (0.8278860231895937)
# DEBUG:root:21. In 1861, neighboring suburbs including Wedding, Moabit and several others were incorporated into Berlin. (0.8277336897008359)
# DEBUG:root:22. Berlin has numerous museums, galleries, libraries, orchestras, and sporting events including Museum Island, the German Historical Museum, Jewish Museum, Natural History Museum, State Library, State Opera, Philharmonic, and the Berlin Marathon. (0.8276489172876222)
# DEBUG:root:23. Due to its location in the European Plain, Berlin is influenced by a temperate seasonal climate. (0.8263385194094418)
# DEBUG:root:24. The city is well known for its festivals, diverse architecture, nightlife, contemporary arts, and a very high quality of life.Berlin is also home to three World Heritage Sites: Museum Island; the Palaces and Parks of Potsdam and Berlin; and the Modernism Housing Estates. (0.8243493737851311)
# DEBUG:root:25. Of Berlin's twelve boroughs, five bear a (partly) Slavic-derived name: Pankow (the most populous), Steglitz-Zehlendorf, Marzahn-Hellersdorf, Treptow-Köpenick and Spandau (named Spandow until 1878). (0.8240106264811907)
# DEBUG:root:26. The Gründerzeitcode: deu promoted to code: de  era's
# industrialization-induced economic boom multiplied Berlin's population rapidly. (0.823208572380861)
# DEBUG:root:27. Berlin is home to world-renowned universities such as the Humboldt University, Technical University, Free University, University of the Arts, ESMT Berlin, Hertie School, and Bard College Berlin. (0.8230041001312838)
# DEBUG:root:28. The city lies in the Central German dialect area, the Berlin dialect being a variant of the Lusatian-New Marchian dialects. (0.8229906044125586)
# DEBUG:root:29. === 12th to 16th centuries ===
#
# The earliest evidence of settlements in the area of today's Berlin are remnants of a house foundation dated to 1174, found in excavations in Berlin Mitte, and a wooden beam dated from approximately 1192. (0.8221457041695548)
# DEBUG:root:30. The name Berlin has its roots in the language of West Slavic inhabitants of the area of today's Berlin, and may be related to the Old Polabian stem berl-/birl- ("swamp"). (0.8218297339120743)
# DEBUG:root:31. During the 15th century, his successors established Berlin-Cölln as capital of the margraviate, and subsequent members of the Hohenzollern family ruled in Berlin until 1918, first as electors of Brandenburg, then as kings of Prussia, and eventually as German emperors. (0.819973870366658)
# DEBUG:root:32. Officially, the Berlin-Cölln palace became permanent residence of the Brandenburg electors of the Hohenzollerns from 1486, when John Cicero came to power. (0.8199595479630087)
# DEBUG:root:33. Under the rule of Frederick II, Berlin became a center of the Enlightenment, but also, was briefly occupied during the Seven Years' War by the Russian army. (0.8185616649524953)
# DEBUG:root:34. During World War II, large parts of Berlin were destroyed during 1943–45 Allied air raids and the 1945 Battle of Berlin. (0.8185375440579566)
# DEBUG:root:35. === 17th to 19th centuries ===
# The Thirty Years' War between 1618 and 1648 devastated Berlin. (0.8158099939536066)
# DEBUG:root:36. West Berlin officially remained an occupied city, but it politically was aligned with the Federal Republic of Germany despite West Berlin's geographic isolation. (0.8153363368080105)
# DEBUG:root:37. The protests of the town citizens against the building culminated in 1448, in the "Berlin Indignation" ("Berliner Unwille"). (0.814235936108053)
# DEBUG:root:38. Berlin has served as a scientific, artistic and philosophical hub of the Enlightenment, Neoclassicism, and liberal revolution. (0.8133774479264102)
# DEBUG:root:39. Following German reunification in 1990, Berlin once again became the capital of all of Germany. (0.8130702312089726)
# DEBUG:root:40. Cölln on the Fischerinsel is first mentioned in a 1237 document, and Berlin, across the Spree in what is now called the Nikolaiviertel, is referenced in a document from 1244. (0.8121118967231779)
# DEBUG:root:41. During the Weimar era, Berlin underwent political unrest due to economic uncertainties but also became a renowned center of the Roaring Twenties. (0.8112515852378542)
# DEBUG:root:42. Berlin became the capital of the new Kingdom, replacing Königsberg. (0.811145276317934)
# DEBUG:root:43. Hitler envisioned Berlin's renewal projects were to turn the city into the new capital of the Greater Germanic Reich. (0.8108706967437798)
# DEBUG:root:44. East Berlin was declared capital of East Germany, while Bonn became the West German capital. (0.8095993835977328)
# DEBUG:root:45. == History ==
#
#
# === Etymology ===
# Berlin lies in northeastern Germany, east of the River Elbe, that once constituted, together with the River (Saxon or Thuringian) Saale (from their confluence at Barby onwards), the eastern border of the Frankish Realm. (0.8088291404147929)
# DEBUG:root:46. === 20th to 21st centuries ===
#
# In the early 20th century, Berlin had become a fertile ground for the German Expressionist movement. (0.8081626441471931)
# DEBUG:root:47. From 1470, with the new elector Albrecht III Achilles, Berlin-Cölln became the new royal residence. (0.8081443021412632)
# DEBUG:root:48. Other landmarks include the Brandenburg Gate, Reichstag building, Potsdamer Platz, Memorial to the Murdered Jews of Europe, Berlin Wall Memorial, East Side Gallery, Berlin Victory Column, Berlin Cathedral, and Berlin Television Tower, the tallest structure in Germany. (0.8079595247921458)
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# DEBUG:openai:api_version=None data='{"prompt": ["Context information is below. \\n---------------------\\nBerlin\'s urban area, which has a population of around 4.5 million, is the second most populous urban area in Germany after the Ruhr. The population almost doubled, and Berlin had a population of around four million. The Berlin-Brandenburg capital region has around 6.2 million inhabitants and is Germany\'s third-largest metropolitan region after the Rhine-Ruhr and Rhine-Main regions.Berlin straddles the banks of the Spree, which flows into the Havel (a tributary of the Elbe) in the western borough of Spandau. Berlin ( bur-LIN, German: [b\\u025b\\u0250\\u032f\\u02c8li\\u02d0n] (listen)) is the capital and largest city of Germany by both area and population. Berlin is a world city of culture, politics, media and science. Berlin in the roaring 1920s was the third-largest city in the world by population.After World War II and its subsequent occupation by the victorious countries, the devastated city was divided; West Berlin became a de facto exclave of West Germany, surrounded by the Berlin Wall (from August 1961 to November 1989) and East German territory. One of Germany\'s sixteen constituent states, Berlin is surrounded by the State of Brandenburg and contiguous with Potsdam, Brandenburg\'s capital. Additional suburbs soon developed and increased the area and population of Berlin. Its 3.7 million inhabitants make it the European Union\'s most populous city, according to population within city limits. The act increased the area of Berlin from 66 to 883 km2 (25 to 341 sq mi). In 1920, the Greater Berlin Act incorporated dozens of suburban cities, villages, and estates around Berlin into an expanded city. The first written records of towns in the area of present-day Berlin date from the late 12th century. The central part of Berlin can be traced back to two towns. First documented in the 13th century and at the crossing of two important historic trade routes, Berlin became the capital of the Margraviate of Brandenburg (1417\\u20131701), Kingdom of Prussia (1701\\u20131918), German Empire (1871\\u20131918), Weimar Republic (1919\\u20131933), and Nazi Germany (1933\\u20131945). Berlin serves as a continental hub for air and rail traffic and has a highly complex public transportation network. In 1709, Berlin merged with the four cities of C\\u00f6lln, Friedrichswerder, Friedrichstadt and Dorotheenstadt under the name Berlin, \\"Haupt- und Residenzstadt Berlin\\".In 1740, Frederick II, known as Frederick the Great (1740\\u20131786), came to power. NSDAP rule diminished Berlin\'s Jewish community from 160,000 (one-third of all Jews in the country) to about 80,000 due to emigration between 1933 and 1939. After the end of the war in Europe in May 1945, Berlin received large numbers of refugees from the Eastern provinces. In 1871, Berlin became capital of the newly founded German Empire. In 1815, the city became part of the new Province of Brandenburg.The Industrial Revolution transformed Berlin during the 19th century; the city\'s economy and population expanded dramatically, and it became the main railway hub and economic center of Germany. With Babelsberg being the world\'s first large-scale movie studio complex, Berlin is an increasingly popular location for international film productions. In 1861, neighboring suburbs including Wedding, Moabit and several others were incorporated into Berlin. Berlin has numerous museums, galleries, libraries, orchestras, and sporting events including Museum Island, the German Historical Museum, Jewish Museum, Natural History Museum, State Library, State Opera, Philharmonic, and the Berlin Marathon. Due to its location in the European Plain, Berlin is influenced by a temperate seasonal climate. The city is well known for its festivals, diverse architecture, nightlife, contemporary arts, and a very high quality of life.Berlin is also home to three World Heritage Sites: Museum Island; the Palaces and ...
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/completions HTTP/1.1" 200 315
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=902 request_id=c37fea915f6bd5cd3322c38f38ea598f response_code=200
# DEBUG:root:
# The population of Berlin is around 4.5 million.
# DEBUG:root:> Initial response:
# The population of Berlin is around 4.5 million.
# INFO:root:> [query] Total LLM token usage: 1739 tokens
# INFO:root:> [query] Total embedding token usage: 7 tokens
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the population of Berlin?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 8417
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=123 request_id=7819c9ea1d78d9e5b4726e2228a2e798 response_code=200
# DEBUG:gpt_index.indices.utils:> Top 1 nodes:
# > [Node d5697215-97ee-419e-924a-03e4b6b1c1c5] [Similarity score:             0.865203] Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen)) is the capital and largest city of Germany by bot...
# DEBUG:root:> Searching in chunk: Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen))...
# The population of Berlin is around 4.5 million.
#
# GPTSimpleVectorIndex, mode = embedding
# Without optimization
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# DEBUG:openai:api_version=None data='{"prompt": ["Context information is below. \\n---------------------\\nBerlin ( bur-LIN, German: [b\\u025b\\u0250\\u032f\\u02c8li\\u02d0n] (listen)) is the capital and largest city of Germany by both area and population. Its 3.7 million inhabitants make it the European Union\'s most populous city, according to population within city limits. One of Germany\'s sixteen constituent states, Berlin is surrounded by the State of Brandenburg and contiguous with Potsdam, Brandenburg\'s capital. Berlin\'s urban area, which has a population of around 4.5 million, is the second most populous urban area in Germany after the Ruhr. The Berlin-Brandenburg capital region has around 6.2 million inhabitants and is Germany\'s third-largest metropolitan region after the Rhine-Ruhr and Rhine-Main regions.Berlin straddles the banks of the Spree, which flows into the Havel (a tributary of the Elbe) in the western borough of Spandau. Among the city\'s main topographical features are the many lakes in the western and southeastern boroughs formed by the Spree, Havel and Dahme, the largest of which is Lake M\\u00fcggelsee. Due to its location in the European Plain, Berlin is influenced by a temperate seasonal climate. About one-third of the city\'s area is composed of forests, parks, gardens, rivers, canals, and lakes. The city lies in the Central German dialect area, the Berlin dialect being a variant of the Lusatian-New Marchian dialects.\\nFirst documented in the 13th century and at the crossing of two important historic trade routes, Berlin became the capital of the Margraviate of Brandenburg (1417\\u20131701), Kingdom of Prussia (1701\\u20131918), German Empire (1871\\u20131918), Weimar Republic (1919\\u20131933), and Nazi Germany (1933\\u20131945). Berlin has served as a scientific, artistic and philosophical hub of the Enlightenment, Neoclassicism, and liberal revolution. The Gr\\u00fcnderzeitcode: deu promoted to code: de  era\'s \\nindustrialization-induced economic boom multiplied Berlin\'s population rapidly. Berlin in the roaring 1920s was the third-largest city in the world by population.After World War II and its subsequent occupation by the victorious countries, the devastated city was divided; West Berlin became a de facto exclave of West Germany, surrounded by the Berlin Wall (from August 1961 to November 1989) and East German territory. East Berlin was declared capital of East Germany, while Bonn became the West German capital. Following German reunification in 1990, Berlin once again became the capital of all of Germany.\\nBerlin is a world city of culture, politics, media and science. Its economy is based on high-tech firms and the service sector, encompassing a diverse range of creative industries, startup companies, research facilities, media corporations, and convention venues. Berlin serves as a continental hub for air and rail traffic and has a highly complex public transportation network. The metropolis is a popular tourist destination. Significant industries also include information technology, healthcare, biomedical engineering, biotechnology, automotive, construction, electronics, social economy and clean tech.\\nBerlin is home to world-renowned universities such as the Humboldt University, Technical University, Free University, University of the Arts, ESMT Berlin, Hertie School, and Bard College Berlin. Its Zoological Garden is the most visited zoo in Europe and one of the most popular worldwide. With Babelsberg being the world\'s first large-scale movie studio complex, Berlin is an increasingly popular location for international film productions. The city is well known for its festivals, diverse architecture, nightlife, contemporary arts, and a very high quality of life.Berlin is also home to three World Heritage Sites: Museum Island; the Palaces and Parks of Potsdam and Berlin; and the Modernism Housing Estates. Other landmarks include the Brandenburg Gate, Reichstag building, Potsdamer P ...
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/completions HTTP/1.1" 200 334
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=1009 request_id=61bb2a24f62e08149131662e91e58a1e response_code=200
# DEBUG:root:
# The population of Berlin is approximately 3.7 million inhabitants.
# DEBUG:root:> Initial response:
# The population of Berlin is approximately 3.7 million inhabitants.
# DEBUG:root:> Refine context: the Western Allies extended the currency reform...
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# DEBUG:openai:api_version=None data='{"prompt": ["The original question is as follows: What is the population of Berlin?\\nWe have provided an existing answer: \\nThe population of Berlin is approximately 3.7 million inhabitants.\\nWe have the opportunity to refine the existing answer (only if needed) with some more context below.\\n------------\\nthe Western Allies extended the currency reform in the Western zones of Germany to the three western sectors of Berlin, the Soviet Union imposed a blockade on the access routes to and from West Berlin, which lay entirely inside Soviet-controlled territory. The Berlin airlift, conducted by the three western Allies, overcame this blockade by supplying food and other supplies to the city from June 1948 to May 1949. In 1949, the Federal Republic of Germany was founded in West Germany and eventually included all of the American, British and French zones, excluding those three countries\' zones in Berlin, while the Marxist-Leninist German Democratic Republic was proclaimed in East Germany. West Berlin officially remained an occupied city, but it politically was aligned with the Federal Republic of Germany despite West Berlin\'s geographic isolation. Airline service to West Berlin was granted only to American, British\\n------------\\nGiven the new context, refine the original answer to better answer the question. If the context isn\'t useful, return the original answer."], "model": "text-davinci-003", "temperature": 0.0, "max_tokens": 256, "top_p": 1, "frequency_penalty": 0, "presence_penalty": 0, "n": 1, "best_of": 1, "logit_bias": {}}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/completions HTTP/1.1" 200 535
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=1757 request_id=cc57d5cb472cd21f0f1d6d0a7719e762 response_code=200
# DEBUG:root:
# The population of Berlin is approximately 3.7 million inhabitants, with the city divided into East and West Berlin during the Cold War. West Berlin was politically aligned with the Federal Republic of Germany, while East Berlin was part of the German Democratic Republic.
# DEBUG:root:> Refined response:
# The population of Berlin is approximately 3.7 million inhabitants, with the city divided into East and West Berlin during the Cold War. West Berlin was politically aligned with the Federal Republic of Germany, while East Berlin was part of the German Democratic Republic.
# INFO:root:> [query] Total LLM token usage: 3467 tokens
# INFO:root:> [query] Total embedding token usage: 7 tokens
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the population of Berlin?"], "encoding_format": "base64"}' message='Post details'
# The population of Berlin is approximately 3.7 million inhabitants, with the city divided into East and West Berlin during the Cold War. West Berlin was politically aligned with the Federal Republic of Germany, while East Berlin was part of the German Democratic Republic.
#
# With optimization
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 8417
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=53 request_id=2a37853ab7c6b82cc17d88c8c91d734e response_code=200
# DEBUG:gpt_index.indices.utils:> Top 1 nodes:
# > [Node d5697215-97ee-419e-924a-03e4b6b1c1c5] [Similarity score:             0.865245] Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen)) is the capital and largest city of Germany by bot...
# DEBUG:root:> Searching in chunk: Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen))...
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the population of Berlin?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 8417
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=28 request_id=70506fa74456b88df9eea0c3870450e0 response_code=200
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["Berlin ( bur-LIN, German: [b\\u025b\\u0250\\u032f\\u02c8li\\u02d0n] (listen)) is the capital and largest city of Germany by both area and population.", "Its 3.7 million inhabitants make it the European Union\'s most populous city, according to population within city limits.", "One of Germany\'s sixteen constituent states, Berlin is surrounded by the State of Brandenburg and contiguous with Potsdam, Brandenburg\'s capital.", "Berlin\'s urban area, which has a population of around 4.5 million, is the second most populous urban area in Germany after the Ruhr.", "The Berlin-Brandenburg capital region has around 6.2 million inhabitants and is Germany\'s third-largest metropolitan region after the Rhine-Ruhr and Rhine-Main regions.Berlin straddles the banks of the Spree, which flows into the Havel (a tributary of the Elbe) in the western borough of Spandau.", "Among the city\'s main topographical features are the many lakes in the western and southeastern boroughs formed by the Spree, Havel and Dahme, the largest of which is Lake M\\u00fcggelsee.", "Due to its location in the European Plain, Berlin is influenced by a temperate seasonal climate.", "About one-third of the city\'s area is composed of forests, parks, gardens, rivers, canals, and lakes.", "The city lies in the Central German dialect area, the Berlin dialect being a variant of the Lusatian-New Marchian dialects.", "First documented in the 13th century and at the crossing of two important historic trade routes, Berlin became the capital of the Margraviate of Brandenburg (1417\\u20131701), Kingdom of Prussia (1701\\u20131918), German Empire (1871\\u20131918), Weimar Republic (1919\\u20131933), and Nazi Germany (1933\\u20131945).", "Berlin has served as a scientific, artistic and philosophical hub of the Enlightenment, Neoclassicism, and liberal revolution.", "The Gr\\u00fcnderzeitcode: deu promoted to code: de  era\'s  industrialization-induced economic boom multiplied Berlin\'s population rapidly.", "Berlin in the roaring 1920s was the third-largest city in the world by population.After World War II and its subsequent occupation by the victorious countries, the devastated city was divided; West Berlin became a de facto exclave of West Germany, surrounded by the Berlin Wall (from August 1961 to November 1989) and East German territory.", "East Berlin was declared capital of East Germany, while Bonn became the West German capital.", "Following German reunification in 1990, Berlin once again became the capital of all of Germany.", "Berlin is a world city of culture, politics, media and science.", "Its economy is based on high-tech firms and the service sector, encompassing a diverse range of creative industries, startup companies, research facilities, media corporations, and convention venues.", "Berlin serves as a continental hub for air and rail traffic and has a highly complex public transportation network.", "The metropolis is a popular tourist destination.", "Significant industries also include information technology, healthcare, biomedical engineering, biotechnology, automotive, construction, electronics, social economy and clean tech.", "Berlin is home to world-renowned universities such as the Humboldt University, Technical University, Free University, University of the Arts, ESMT Berlin, Hertie School, and Bard College Berlin.", "Its Zoological Garden is the most visited zoo in Europe and one of the most popular worldwide.", "With Babelsberg being the world\'s first large-scale movie studio complex, Berlin is an increasingly popular location for international film productions.", "The city is well known for its festivals, diverse architecture, nightlife, contemporary arts, and a very high quality of life.Berlin is also home to three World Heritage Sites: Museum Island; the Palaces and Parks of Potsdam and Berlin; and the Modernism Housing Estates.", "Other landmarks include the Brandenburg Gate, Reichstag building, Potsd ...
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 811089
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=229 request_id=eefc950a772283080f750d1be0c58594 response_code=200
# DEBUG:root:> Top 49 sentences with scores:
#
# DEBUG:root:0. Berlin's urban area, which has a population of around 4.5 million, is the second most populous urban area in Germany after the Ruhr. (0.9053729938955482)
# DEBUG:root:1. The population almost doubled, and Berlin had a population of around four million. (0.8967248570795152)
# DEBUG:root:2. The Berlin-Brandenburg capital region has around 6.2 million inhabitants and is Germany's third-largest metropolitan region after the Rhine-Ruhr and Rhine-Main regions.Berlin straddles the banks of the Spree, which flows into the Havel (a tributary of the Elbe) in the western borough of Spandau. (0.8861866177405743)
# DEBUG:root:3. Berlin ( bur-LIN, German: [bɛɐ̯ˈliːn] (listen)) is the capital and largest city of Germany by both area and population. (0.8742496628731337)
# DEBUG:root:4. Berlin is a world city of culture, politics, media and science. (0.8584499926039996)
# DEBUG:root:5. Berlin in the roaring 1920s was the third-largest city in the world by population.After World War II and its subsequent occupation by the victorious countries, the devastated city was divided; West Berlin became a de facto exclave of West Germany, surrounded by the Berlin Wall (from August 1961 to November 1989) and East German territory. (0.8546178135508616)
# DEBUG:root:6. One of Germany's sixteen constituent states, Berlin is surrounded by the State of Brandenburg and contiguous with Potsdam, Brandenburg's capital. (0.853006222517444)
# DEBUG:root:7. Additional suburbs soon developed and increased the area and population of Berlin. (0.8525565119068865)
# DEBUG:root:8. Its 3.7 million inhabitants make it the European Union's most populous city, according to population within city limits. (0.8475571102872597)
# DEBUG:root:9. The act increased the area of Berlin from 66 to 883 km2 (25 to 341 sq mi). (0.8451758780295022)
# DEBUG:root:10. In 1920, the Greater Berlin Act incorporated dozens of suburban cities, villages, and estates around Berlin into an expanded city. (0.8394477027535817)
# DEBUG:root:11. The first written records of towns in the area of present-day Berlin date from the late 12th century. (0.8376447573906604)
# DEBUG:root:12. The central part of Berlin can be traced back to two towns. (0.8370296733107023)
# DEBUG:root:13. First documented in the 13th century and at the crossing of two important historic trade routes, Berlin became the capital of the Margraviate of Brandenburg (1417–1701), Kingdom of Prussia (1701–1918), German Empire (1871–1918), Weimar Republic (1919–1933), and Nazi Germany (1933–1945). (0.8368710083477021)
# DEBUG:root:14. Berlin serves as a continental hub for air and rail traffic and has a highly complex public transportation network. (0.8343787144379614)
# DEBUG:root:15. In 1709, Berlin merged with the four cities of Cölln, Friedrichswerder, Friedrichstadt and Dorotheenstadt under the name Berlin, "Haupt- und Residenzstadt Berlin".In 1740, Frederick II, known as Frederick the Great (1740–1786), came to power. (0.8336050779096793)
# DEBUG:root:16. NSDAP rule diminished Berlin's Jewish community from 160,000 (one-third of all Jews in the country) to about 80,000 due to emigration between 1933 and 1939. (0.8306729938063658)
# DEBUG:root:17. After the end of the war in Europe in May 1945, Berlin received large numbers of refugees from the Eastern provinces. (0.8305507148520634)
# DEBUG:root:18. In 1871, Berlin became capital of the newly founded German Empire. (0.8304924834084375)
# DEBUG:root:19. In 1815, the city became part of the new Province of Brandenburg.The Industrial Revolution transformed Berlin during the 19th century; the city's economy and population expanded dramatically, and it became the main railway hub and economic center of Germany. (0.8289057208747809)
# DEBUG:root:20. With Babelsberg being the world's first large-scale movie studio complex, Berlin is an increasingly popular location for international film productions. (0.8278918892328513)
# DEBUG:root:21. In 1861, neighboring suburbs including Wedding, Moabit and several others were incorporated into Berlin. (0.8277490596359317)
# DEBUG:root:22. Berlin has numerous museums, galleries, libraries, orchestras, and sporting events including Museum Island, the German Historical Museum, Jewish Museum, Natural History Museum, State Library, State Opera, Philharmonic, and the Berlin Marathon. (0.8277009989673818)
# DEBUG:root:23. Due to its location in the European Plain, Berlin is influenced by a temperate seasonal climate. (0.8263175719389735)
# ...
# As of 2019, the population of Berlin was approximately 4.5 million people.
#
# GPTTreeIndex, mode = retrieve
# Without optimization
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/completions HTTP/1.1" 200 332
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=668 request_id=5d74fae32daea5d888bf68ef8d0e90ab response_code=200
# DEBUG:root:
# The population of Berlin is 3.75 million registered inhabitants.
# DEBUG:root:> Initial response:
# The population of Berlin is 3.75 million registered inhabitants.
# INFO:root:> [query] Total LLM token usage: 1180 tokens
# INFO:root:> [query] Total embedding token usage: 0 tokens
# INFO:root:> Starting query: What is the population of Berlin?
# DEBUG:root:> Searching in chunk: Berlin is the capital and largest city of Germa...
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the population of Berlin?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 8417
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=93 request_id=857eebb82a2ec6ed77c44fe6f74ee68e response_code=200
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["Berlin is the capital and largest city of Germany, with a population of 3.7 million.", "It is the European Union\'s most populous city and is surrounded by the State of Brandenburg.", "Berlin has a temperate seasonal climate and is home to many lakes, parks, gardens, rivers, canals, and forests.", "It is a world city of culture, politics, media, and science, and is known for its festivals, diverse architecture, nightlife, contemporary arts, and high quality of life.", "Berlin has a long history, first documented in the 13th century, and has served as a hub of the Enlightenment, Neoclassicism, and liberal revolution.", "It has been the capital of the Margraviate of Brandenburg, Kingdom of Prussia, German Empire, Weimar Republic, and Nazi Germany.", "Berlin is home to world-renowned universities, museums, galleries, libraries, orchestras, and sporting events, and is a popular tourist destination.", "It has been divided into four sectors since 1945, with the Western Allies forming West Berlin and the Soviet sector forming East Berlin.", "Berlin is a city with a unique legal status, located in northeastern Germany.", "It has an oceanic climate with moderate summer temperatures and cold winters.", "The city\'s appearance has been shaped by its key role in Germany\'s history during the 20th century, with each government initiating ambitious reconstruction programs.", "Berlin has five of the top 50 tallest buildings in Germany, and over one-third of the city area consists of green space, woodlands, and water.", "Famous streets include Unter den Linden and Friedrichstra\\u00dfe in the city\'s historic heart, and Kurf\\u00fcrstendamm and Kantstra\\u00dfe in City West.", "The Fernsehturm (TV tower) at Alexanderplatz is among the tallest structures in the European Union, and the Brandenburg Gate is an iconic landmark of Berlin and Germany.", "The East Side Gallery is an open-air exhibition of art painted directly on the last existing portions of the Berlin Wall.", "In 1996, there was an unsuccessful attempt of unifying the states of Berlin and Brandenburg.", "Berlin is the capital of Germany and the most populous city in the European Union.", "It is a city-state with a population of 3.75 million registered inhabitants in an area of 891.1 km2 (344.1 sq mi).", "The city\'s population density is 4,206 inhabitants per km2.", "Berlin is home to people from about 190 countries, with Turkish, Polish, English, Persian, Arabic, Italian, Bulgarian, Russian, Romanian, Kurdish, Serbo-Croatian, French, Spanish and Vietnamese being the most commonly spoken foreign languages.", "The largest religious denomination is the Protestant regional church body\\u2014the Evangelical Church of Berlin-Brandenburg-Silesian Upper Lusatia (EKBO)\\u2014a united church.", "Approximately 249,000 Muslims were reported by the Office of Statistics to be members of mosques and Islamic religious organizations in Berlin in 2009, while in 2016, the newspaper Der Tagesspiegel estimated that about 350,000 Muslims observed Ramadan in Berlin.", "Berlin is governed by the Senate of Berlin, which consists of the Governing Mayor and up to ten senators holding ministerial positions.", "The city is divided into 12 boroughs, each of which is made up of several subdistricts or neighborhoods.", "Berlin is the capital of the Federal Republic of Germany and is home to many government departments, embassies, think tanks, trade unions, and professional associations.", "It is a major center of business relocation and international investments, and its economy is dominated by the service sector.", "Tourism is a major industry, with many popular attractions and events.", "The creative arts and entertainment business is also an important part of Berlin\'s economy, and the city is home to many magazine, newspaper, book, and scientific/academic publishers.", "Berlin is ranked 13th in the Quality of living city ranking and 6th-most-livable city in the  ...
# The population of Berlin is 3.75 million registered inhabitants.
#
# With optimization
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 347689
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=474 request_id=8fa81a0b1c53194e3b8c7ffba3ea1429 response_code=200
# DEBUG:root:> Top 21 sentences with scores:
#
# DEBUG:root:0. Berlin is the capital and largest city of Germany, with a population of 3.7 million. (0.916645867921962)
# DEBUG:root:1. Berlin is the capital of Germany and the most populous city in the European Union. (0.8808276490024004)
# DEBUG:root:2. Approximately 249,000 Muslims were reported by the Office of Statistics to be members of mosques and Islamic religious organizations in Berlin in 2009, while in 2016, the newspaper Der Tagesspiegel estimated that about 350,000 Muslims observed Ramadan in Berlin. (0.8678210163586473)
# DEBUG:root:3. Berlin is a vibrant city with a rich history and culture. (0.8656564387350475)
# DEBUG:root:4. Berlin is ranked 13th in the Quality of living city ranking and 6th-most-livable city in the world. (0.8540120465790311)
# DEBUG:root:5. Berlin is a city with a unique legal status, located in northeastern Germany. (0.8536041446219546)
# DEBUG:root:6. Berlin has five of the top 50 tallest buildings in Germany, and over one-third of the city area consists of green space, woodlands, and water. (0.8532327614335693)
# DEBUG:root:7. It is the European Union's most populous city and is surrounded by the State of Brandenburg. (0.8523064763586065)
# DEBUG:root:8. Berlin is the capital of the Federal Republic of Germany and is home to many government departments, embassies, think tanks, trade unions, and professional associations. (0.8522761981197248)
# DEBUG:root:9. Berlin is home to people from about 190 countries, with Turkish, Polish, English, Persian, Arabic, Italian, Bulgarian, Russian, Romanian, Kurdish, Serbo-Croatian, French, Spanish and Vietnamese being the most commonly spoken foreign languages. (0.8516441635653532)
# DEBUG:root:10. Berlin is a major hub for public transport, airports, cycling, and telecommunication. (0.8508399892452583)
# DEBUG:root:11. Berlin is a popular destination for international sporting events, and is home to many professional sports teams. (0.8487002096321168)
# DEBUG:root:12. Berlin is governed by the Senate of Berlin, which consists of the Governing Mayor and up to ten senators holding ministerial positions. (0.8483580741154105)
# DEBUG:root:13. Berlin is a city of many attractions, from its cultural offerings to its recreational activities. (0.8456259765613474)
# DEBUG:root:14. Berlin is home to world-renowned universities, museums, galleries, libraries, orchestras, and sporting events, and is a popular tourist destination. (0.84378308916404)
# DEBUG:root:15. It is a city-state with a population of 3.75 million registered inhabitants in an area of 891.1 km2 (344.1 sq mi). (0.8377440637133277)
# DEBUG:root:16. Berlin has a long history, first documented in the 13th century, and has served as a hub of the Enlightenment, Neoclassicism, and liberal revolution. (0.8323525251813496)
# DEBUG:root:17. The creative arts and entertainment business is also an important part of Berlin's economy, and the city is home to many magazine, newspaper, book, and scientific/academic publishers. (0.8285951496802748)
# DEBUG:root:18. Berlin has a temperate seasonal climate and is home to many lakes, parks, gardens, rivers, canals, and forests. (0.8243235556288611)
# DEBUG:root:19. Berlin is also home to several research institutions, such as the Fraunhofer Society, the Leibniz Association, the Helmholtz Association, and the Max Planck Society. (0.8195229593462534)
# DEBUG:root:20. The Fernsehturm (TV tower) at Alexanderplatz is among the tallest structures in the European Union, and the Brandenburg Gate is an iconic landmark of Berlin and Germany. (0.8137908757984084)
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/completions
# DEBUG:openai:api_version=None data='{"prompt": ["Context information is below. \\n---------------------\\nBerlin is the capital and largest city of Germany, with a population of 3.7 million. Berlin is the capital of Germany and the most populous city in the European Union. Approximately 249,000 Muslims were reported by the Office of Statistics to be members of mosques and Islamic religious organizations in Berlin in 2009, while in 2016, the newspaper Der Tagesspiegel estimated that about 350,000 Muslims observed Ramadan in Berlin. Berlin is a vibrant city with a rich history and culture. Berlin is ranked 13th in the Quality of living city ranking and 6th-most-livable city in the world. Berlin is a city with a unique legal status, located in northeastern Germany. Berlin has five of the top 50 tallest buildings in Germany, and over one-third of the city area consists of green space, woodlands, and water. It is the European Union\'s most populous city and is surrounded by the State of Brandenburg. Berlin is the capital of the Federal Republic of Germany and is home to many government departments, embassies, think tanks, trade unions, and professional associations. Berlin is home to people from about 190 countries, with Turkish, Polish, English, Persian, Arabic, Italian, Bulgarian, Russian, Romanian, Kurdish, Serbo-Croatian, French, Spanish and Vietnamese being the most commonly spoken foreign languages. Berlin is a major hub for public transport, airports, cycling, and telecommunication. Berlin is a popular destination for international sporting events, and is home to many professional sports teams. Berlin is governed by the Senate of Berlin, which consists of the Governing Mayor and up to ten senators holding ministerial positions. Berlin is a city of many attractions, from its cultural offerings to its recreational activities. Berlin is home to world-renowned universities, museums, galleries, libraries, orchestras, and sporting events, and is a popular tourist destination. It is a city-state with a population of 3.75 million registered inhabitants in an area of 891.1 km2 (344.1 sq mi). Berlin has a long history, first documented in the 13th century, and has served as a hub of the Enlightenment, Neoclassicism, and liberal revolution. The creative arts and entertainment business is also an important part of Berlin\'s economy, and the city is home to many magazine, newspaper, book, and scientific/academic publishers. Berlin has a temperate seasonal climate and is home to many lakes, parks, gardens, rivers, canals, and forests. Berlin is also home to several research institutions, such as the Fraunhofer Society, the Leibniz Association, the Helmholtz Association, and the Max Planck Society. The Fernsehturm (TV tower) at Alexanderplatz is among the tallest structures in the European Union, and the Brandenburg Gate is an iconic landmark of Berlin and Germany.\\n---------------------\\nGiven the context information and not prior knowledge, answer the question: What is the population of Berlin?\\n"], "model": "text-davinci-003", "temperature": 0.0, "max_tokens": 256, "top_p": 1, "frequency_penalty": 0, "presence_penalty": 0, "n": 1, "best_of": 1, "logit_bias": {}}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/completions HTTP/1.1" 200 306
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/completions processing_ms=975 request_id=b09ce5d8d3960fe1a83380fb89bc044f response_code=200
# DEBUG:root:
# The population of Berlin is 3.7 million.
# DEBUG:root:> Initial response:
# The population of Berlin is 3.7 million.
# INFO:root:> [query] Total LLM token usage: 627 tokens
# INFO:root:> [query] Total embedding token usage: 0 tokens
# The population of Berlin is 3.7 million.
#
#
# Ran 12 combinations in total.
#                    Index       Mode  \
# 0   GPTSimpleVectorIndex    default
# 1   GPTSimpleVectorIndex    default
# 2   GPTSimpleVectorIndex  embedding
# 3   GPTSimpleVectorIndex  embedding
# 4           GPTTreeIndex    default
# 5           GPTTreeIndex    default
# 6           GPTTreeIndex  summarize
# 7           GPTTreeIndex  summarize
# 8           GPTTreeIndex  embedding
# 9           GPTTreeIndex  embedding
# 10          GPTTreeIndex   retrieve
# 11          GPTTreeIndex   retrieve
#
#                                                Output   Duration  LLM Tokens  \
# 0   \nThe population of Berlin is approximately 3....  14.576009        3467
# 1   \nThe population of Berlin is around 4.5 million.   4.447877        1739
# 2   \nThe population of Berlin is approximately 3....   3.254070        3467
# 3   \nThe population of Berlin is around 4.5 million.   1.936516        1739
# 4   The population of Berlin is approximately 3.7 ...   4.861451        4827
# 5   The population of Berlin is approximately 3.7 ...   4.206117        4827
# 6   \nThe population of Berlin is approximately 3....  10.079303       21472
# 7   \nThe population of Berlin is approximately 3....  51.382679       11348
# 8   As of 2019, the population of Berlin was appro...   3.027780         373
# 9   As of 2019, the population of Berlin was appro...   0.921451         373
# 10  \nThe population of Berlin is 3.75 million reg...   0.776624        1180
# 11         \nThe population of Berlin is 3.7 million.   2.081645         627
#
#     Embedding Tokens Optimization
# 0                  7           No
# 1                  7          Yes
# 2                  7           No
# 3                  7          Yes
# 4                  0           No
# 5                  0          Yes
# 6                  0           No
# 7                  0          Yes
# 8               4263           No
# 9                 14          Yes
# 10                 0           No
# 11                 0          Yes

# %% [markdown]
# ### Initialize with Documents

# %%
# Uses documents in a preset list of indices
# playground = Playground.from_docs(documents=documents)
