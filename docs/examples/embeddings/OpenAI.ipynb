# %% [markdown]
# <a href="https://colab.research.google.com/github/jerryjliu/llama_index/blob/main/docs/examples/embeddings/OpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OpenAI Embeddings

# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install LlamaIndex 🦙.

# %%
# !pip install llama-index
# Out:
# Requirement already satisfied: llama-index in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (0.9.37.post1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index) (2.0.24)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: dataclasses-json in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (1.2.14)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (2023.10.0)
# Requirement already satisfied: httpx in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (0.26.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (3.8.1)
# Requirement already satisfied: numpy in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (1.26.2)
# Requirement already satisfied: openai>=1.1.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (1.6.1)
# Requirement already satisfied: pandas in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (2.1.4)
# Requirement already satisfied: requests>=2.31.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (0.5.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from llama-index) (0.9.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (1.3.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from deprecated>=1.2.9.3->llama-index) (1.16.0)
# Requirement already satisfied: click in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index) (4.66.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from openai>=1.1.0->llama-index) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from openai>=1.1.0->llama-index) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from openai>=1.1.0->llama-index) (1.10.11)
# Requirement already satisfied: sniffio in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from openai>=1.1.0->llama-index) (1.3.0)
# Requirement already satisfied: certifi in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from httpx->llama-index) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from httpx->llama-index) (1.0.2)
# Requirement already satisfied: idna in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from httpx->llama-index) (3.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from requests>=2.31.0->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from requests>=2.31.0->llama-index) (1.26.18)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from dataclasses-json->llama-index) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from pandas->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from pandas->llama-index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from pandas->llama-index) (2023.3)
# Requirement already satisfied: packaging>=17.0 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in /Users/haotianzhang/llama_index/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import openai

os.environ["OPENAI_API_KEY"] = "sk-"
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
from llama_index.embeddings import OpenAIEmbedding
from llama_index import ServiceContext, set_global_service_context

embed_model = OpenAIEmbedding(embed_batch_size=10)

service_context = ServiceContext.from_defaults(embed_model=embed_model)

# optionally set a global service context
set_global_service_context(service_context)

# %%
# get API key and create embeddings
from llama_index.embeddings import OpenAIEmbedding


model_name = "text-embedding-3-large"

embed_model = OpenAIEmbedding(
    model_name=model_name,
)

embeddings = embed_model.get_text_embedding("Open AI new  Embeddings.")

# %%
print(embeddings)
# Out:
# [-0.020278604701161385, 0.00684199808165431, -0.009164511226117611, -0.043629277497529984, 0.034235838800668716, -0.007070926483720541, -0.0012886440381407738, 0.07378871738910675, 0.007665401324629784, 0.0001704268652247265, 0.01572958007454872, 0.0016828066436573863, 0.0009189434931613505, -0.0015378803946077824, -0.012480277568101883, 0.010818702168762684, -0.001649575075134635, 0.018077939748764038, -0.01595112308859825, -0.05133898928761482, -0.02838709205389023, -0.007292469963431358, -0.02952434867620468, -0.04129568859934807, 0.048828162252902985, -0.013964618556201458, 0.005867207422852516, 0.024207307025790215, -0.015064950101077557, 0.03461984544992447, 0.008662346750497818, -0.034442611038684845, 0.008182335644960403, 0.0027379069942981005, -0.012952903285622597, 0.013344296254217625, 0.06034841760993004, 0.032286256551742554, -0.027899697422981262, 0.01572958007454872, 0.027471380308270454, -0.015744350850582123, -0.012207040563225746, 0.007325701415538788, -0.020559