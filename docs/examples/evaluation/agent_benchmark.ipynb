# %%
import pandas as pd

# %%
df = pd.read_csv("../../results.csv")

# %%
df
# Out:
#     Unnamed: 0   agent               model               task  outcome
# 0            0   react    text-davinci-003  add_then_multiply     True
# 1            1   react    text-davinci-003              power    False
# 2            2   react    text-davinci-003  dialed_then_enter    False
# 3            3   react  gpt-3.5-turbo-0613  add_then_multiply    False
# 4            4   react  gpt-3.5-turbo-0613              power     True
# 5            5   react  gpt-3.5-turbo-0613  dialed_then_enter    False
# 6            6   react          gpt-4-0613  add_then_multiply     True
# 7            7   react          gpt-4-0613              power     True
# 8            8   react          gpt-4-0613  dialed_then_enter     True
# 9            9   react            claude-1  add_then_multiply     True
# 10          10   react            claude-1              power     True
# 11          11   react            claude-1  dialed_then_enter     True
# ...
