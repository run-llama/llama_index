# %% [markdown]
# <a href="https://colab.research.google.com/github/jerryjliu/llama_index/blob/main/docs/examples/embeddings/together.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi-Document RAG with Long-Context Embeddings (Together.ai)
#
# This notebook shows how to use long-context together.ai models for hierarchical retrieval + RAG. We index each document by running the embedding model over the entire document text. We then link each document to an underlying top-k based query engine for that document.
#
# Visit https://together.ai and sign up to get an API key.

# %% [markdown]
# ## Setup and Download Data

# %%
domain = "docs.llamaindex.ai"
docs_url = "https://docs.llamaindex.ai/en/latest/"
# !wget -e robots=off --recursive --no-clobber --page-requisites --html-extension --convert-links --restrict-file-names=windows --domains {domain} --no-parent {docs_url}
# Out:
# Both --no-clobber and --convert-links were specified, only --convert-links will be used.
# --2024-01-19 15:20:54--  https://docs.llamaindex.ai/en/latest/
# Resolving docs.llamaindex.ai (docs.llamaindex.ai)... 104.18.0.163, 104.18.1.163
# Connecting to docs.llamaindex.ai (docs.llamaindex.ai)|104.18.0.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/index.html’
#
# docs.llamaindex.ai/     [ <=>                ] 216.44K  --.-KB/s    in 0.01s
#
# 2024-01-19 15:20:55 (15.9 MB/s) - ‘docs.llamaindex.ai/en/latest/index.html’ saved [221633]
#
# --2024-01-19 15:20:55--  https://docs.llamaindex.ai/en/latest/genindex.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/genindex.html’
#
# docs.llamaindex.ai/     [ <=>                ] 971.24K  --.-KB/s    in 0.06s
#
# 2024-01-19 15:20:55 (14.8 MB/s) - ‘docs.llamaindex.ai/en/latest/genindex.html’ saved [994546]
#
# --2024-01-19 15:20:55--  https://docs.llamaindex.ai/en/latest/search.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/search.html’
#
# docs.llamaindex.ai/     [ <=>                ] 207.65K  --.-KB/s    in 0.004s
#
# 2024-01-19 15:20:55 (47.8 MB/s) - ‘docs.llamaindex.ai/en/latest/search.html’ saved [212631]
#
# --2024-01-19 15:20:55--  https://docs.llamaindex.ai/en/latest/getting_started/installation.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/installation.html’
#
# docs.llamaindex.ai/     [ <=>                ] 217.25K  --.-KB/s    in 0.002s
#
# 2024-01-19 15:20:56 (104 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/installation.html’ saved [222463]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/_static/pygments.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/pygments.css’
#
# docs.llamaindex.ai/     [ <=>                ]  20.92K  --.-KB/s    in 0s
#
# 2024-01-19 15:20:56 (82.1 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/pygments.css’ saved [21424]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/_static/styles/furo.css?digest=fad236701ea90a88636c2a8c73b44ae642ed2a53
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/styles/furo.css@digest=fad236701ea90a88636c2a8c73b44ae642ed2a53.css’
#
# docs.llamaindex.ai/     [ <=>                ]  47.56K  --.-KB/s    in 0.001s
#
# 2024-01-19 15:20:56 (60.2 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/styles/furo.css@digest=fad236701ea90a88636c2a8c73b44ae642ed2a53.css’ saved [48697]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/_static/mystnb.4510f1fc1dee50b3e5859aac5469c37c29e427902b24a333a5f9fcb2f0b3ac41.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/mystnb.4510f1fc1dee50b3e5859aac5469c37c29e427902b24a333a5f9fcb2f0b3ac41.css’
#
# docs.llamaindex.ai/     [ <=>                ]  38.44K  --.-KB/s    in 0s
#
# 2024-01-19 15:20:56 (185 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/mystnb.4510f1fc1dee50b3e5859aac5469c37c29e427902b24a333a5f9fcb2f0b3ac41.css’ saved [39364]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/_static/autodoc_pydantic.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 181 [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/autodoc_pydantic.css’
#
# docs.llamaindex.ai/ 100%[===================>]     181  --.-KB/s    in 0s
#
# 2024-01-19 15:20:56 (34.5 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/autodoc_pydantic.css’ saved [181/181]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/_static/graphviz.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/graphviz.css’
#
# docs.llamaindex.ai/     [ <=>                ]     299  --.-KB/s    in 0s
#
# 2024-01-19 15:20:56 (71.3 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/graphviz.css’ saved [299]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/_static/styles/furo-extensions.css?digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/styles/furo-extensions.css@digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e.css’
#
# docs.llamaindex.ai/     [ <=>                ]   5.40K  --.-KB/s    in 0s
#
# 2024-01-19 15:20:56 (586 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/styles/furo-extensions.css@digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e.css’ saved [5529]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/_static/css/custom.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 187 [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/css/custom.css’
#
# docs.llamaindex.ai/ 100%[===================>]     187  --.-KB/s    in 0s
#
# 2024-01-19 15:20:56 (44.6 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/css/custom.css’ saved [187/187]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/_static/css/algolia.css
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/css]
# Saving to: ‘docs.llamaindex.ai/en/latest/_static/css/algolia.css’
#
# docs.llamaindex.ai/     [ <=>                ]   2.10K  --.-KB/s    in 0s
#
# 2024-01-19 15:20:56 (294 MB/s) - ‘docs.llamaindex.ai/en/latest/_static/css/algolia.css’ saved [2155]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/_/static/javascript/readthedocs-addons.js
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/javascript]
# Saving to: ‘docs.llamaindex.ai/_/static/javascript/readthedocs-addons.js’
#
# docs.llamaindex.ai/     [ <=>                ] 357.83K  --.-KB/s    in 0.007s
#
# 2024-01-19 15:20:56 (48.0 MB/s) - ‘docs.llamaindex.ai/_/static/javascript/readthedocs-addons.js’ saved [366421]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/getting_started/reading.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/reading.html’
#
# docs.llamaindex.ai/     [ <=>                ] 215.57K  --.-KB/s    in 0.004s
#
# 2024-01-19 15:20:56 (53.3 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/reading.html’ saved [220748]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/getting_started/starter_example.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/starter_example.html’
#
# docs.llamaindex.ai/     [ <=>                ] 224.19K  --.-KB/s    in 0.005s
#
# 2024-01-19 15:20:56 (41.0 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/starter_example.html’ saved [229567]
#
# --2024-01-19 15:20:56--  https://docs.llamaindex.ai/en/latest/getting_started/concepts.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/concepts.html’
#
# docs.llamaindex.ai/     [ <=>                ] 222.46K  --.-KB/s    in 0.003s
#
# 2024-01-19 15:20:57 (69.7 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/concepts.html’ saved [227804]
#
# --2024-01-19 15:20:57--  https://docs.llamaindex.ai/en/latest/getting_started/customization.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/customization.html’
#
# docs.llamaindex.ai/     [ <=>                ] 229.62K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:20:57 (6.91 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/customization.html’ saved [235128]
#
# --2024-01-19 15:20:57--  https://docs.llamaindex.ai/en/latest/getting_started/discover_llamaindex.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/getting_started/discover_llamaindex.html’
#
# docs.llamaindex.ai/     [ <=>                ] 216.02K  --.-KB/s    in 0.006s
#
# 2024-01-19 15:20:57 (36.6 MB/s) - ‘docs.llamaindex.ai/en/latest/getting_started/discover_llamaindex.html’ saved [221205]
#
# --2024-01-19 15:20:57--  https://docs.llamaindex.ai/en/latest/use_cases/q_and_a.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/q_and_a.html’
#
# docs.llamaindex.ai/     [ <=>                ] 216.81K  --.-KB/s    in 0.005s
#
# 2024-01-19 15:20:57 (41.1 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/q_and_a.html’ saved [222012]
#
# --2024-01-19 15:20:57--  https://docs.llamaindex.ai/en/latest/use_cases/chatbots.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/chatbots.html’
#
# docs.llamaindex.ai/     [ <=>                ] 213.76K  --.-KB/s    in 0.003s
#
# 2024-01-19 15:20:58 (75.3 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/chatbots.html’ saved [218894]
#
# --2024-01-19 15:20:58--  https://docs.llamaindex.ai/en/latest/use_cases/agents.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/agents.html’
#
# docs.llamaindex.ai/     [ <=>                ] 215.38K  --.-KB/s    in 0.001s
#
# 2024-01-19 15:20:58 (353 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/agents.html’ saved [220548]
#
# --2024-01-19 15:20:58--  https://docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents.html’
#
# docs.llamaindex.ai/     [ <=>                ] 225.46K  --.-KB/s    in 0.003s
#
# 2024-01-19 15:20:58 (69.6 MB/s) - ‘docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents.html’ saved [230872]
#
# --2024-01-19 15:20:58--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent.html’
#
# docs.llamaindex.ai/     [ <=>                ] 245.10K  --.-KB/s    in 0.001s
#
# 2024-01-19 15:20:59 (235 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent.html’ saved [250983]
#
# --2024-01-19 15:20:59--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_with_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_with_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 219.45K  --.-KB/s    in 0.003s
#
# 2024-01-19 15:20:59 (72.7 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_with_query_engine.html’ saved [224714]
#
# --2024-01-19 15:20:59--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html’
#
# docs.llamaindex.ai/     [ <=>                ] 242.35K  --.-KB/s    in 0.001s
#
# 2024-01-19 15:20:59 (213 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html’ saved [248166]
#
# --2024-01-19 15:20:59--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html’
#
# docs.llamaindex.ai/     [ <=>                ] 243.58K  --.-KB/s    in 0.006s
#
# 2024-01-19 15:20:59 (38.9 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html’ saved [249427]
#
# --2024-01-19 15:20:59--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_query_cookbook.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_query_cookbook.html’
#
# docs.llamaindex.ai/     [ <=>                ] 281.15K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:00 (9.48 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_query_cookbook.html’ saved [287897]
#
# --2024-01-19 15:21:00--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_forced_function_call.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_forced_function_call.html’
#
# docs.llamaindex.ai/     [ <=>                ] 217.30K  --.-KB/s    in 0.005s
#
# 2024-01-19 15:21:00 (45.8 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_forced_function_call.html’ saved [222514]
#
# --2024-01-19 15:21:00--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_parallel_function_calling.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_parallel_function_calling.html’
#
# docs.llamaindex.ai/     [ <=>                ] 228.33K  --.-KB/s    in 0.001s
#
# 2024-01-19 15:21:00 (166 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_parallel_function_calling.html’ saved [233805]
#
# --2024-01-19 15:21:01--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_context_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_context_retrieval.html’
#
# docs.llamaindex.ai/     [ <=>                ] 254.05K  --.-KB/s    in 0.02s
#
# 2024-01-19 15:21:01 (10.5 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_context_retrieval.html’ saved [260152]
#
# --2024-01-19 15:21:01--  https://docs.llamaindex.ai/en/latest/optimizing/agentic_strategies/agentic_strategies.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/optimizing/agentic_strategies/agentic_strategies.html’
#
# docs.llamaindex.ai/     [ <=>                ] 218.13K  --.-KB/s    in 0.007s
#
# 2024-01-19 15:21:01 (30.8 MB/s) - ‘docs.llamaindex.ai/en/latest/optimizing/agentic_strategies/agentic_strategies.html’ saved [223367]
#
# --2024-01-19 15:21:01--  https://docs.llamaindex.ai/en/latest/module_guides/querying/router/root.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/router/root.html’
#
# docs.llamaindex.ai/     [ <=>                ] 233.50K  --.-KB/s    in 0.003s
#
# 2024-01-19 15:21:01 (86.7 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/router/root.html’ saved [239104]
#
# --2024-01-19 15:21:01--  https://docs.llamaindex.ai/en/latest/examples/query_engine/RouterQueryEngine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/RouterQueryEngine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 228.41K  --.-KB/s    in 0.001s
#
# 2024-01-19 15:21:02 (156 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/RouterQueryEngine.html’ saved [233893]
#
# --2024-01-19 15:21:02--  https://docs.llamaindex.ai/en/latest/examples/query_engine/RetrieverRouterQueryEngine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/RetrieverRouterQueryEngine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 234.57K  --.-KB/s    in 0.003s
#
# 2024-01-19 15:21:02 (68.9 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/RetrieverRouterQueryEngine.html’ saved [240199]
#
# --2024-01-19 15:21:02--  https://docs.llamaindex.ai/en/latest/examples/query_engine/SQLRouterQueryEngine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/SQLRouterQueryEngine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 239.08K  --.-KB/s    in 0.003s
#
# 2024-01-19 15:21:02 (86.7 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/SQLRouterQueryEngine.html’ saved [244814]
#
# --2024-01-19 15:21:02--  https://docs.llamaindex.ai/en/latest/examples/retrievers/router_retriever.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/retrievers/router_retriever.html’
#
# docs.llamaindex.ai/     [ <=>                ] 240.32K  --.-KB/s    in 0.007s
#
# 2024-01-19 15:21:03 (33.4 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/retrievers/router_retriever.html’ saved [246086]
#
# --2024-01-19 15:21:03--  https://docs.llamaindex.ai/en/latest/optimizing/advanced_retrieval/query_transformations.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/optimizing/advanced_retrieval/query_transformations.html’
#
# docs.llamaindex.ai/     [ <=>                ] 228.03K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:03 (7.76 MB/s) - ‘docs.llamaindex.ai/en/latest/optimizing/advanced_retrieval/query_transformations.html’ saved [233499]
#
# --2024-01-19 15:21:03--  https://docs.llamaindex.ai/en/latest/examples/query_transformations/HyDEQueryTransformDemo.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_transformations/HyDEQueryTransformDemo.html’
#
# docs.llamaindex.ai/     [ <=>                ] 233.95K  --.-KB/s    in 0.008s
#
# 2024-01-19 15:21:03 (28.5 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_transformations/HyDEQueryTransformDemo.html’ saved [239568]
#
# --2024-01-19 15:21:03--  https://docs.llamaindex.ai/en/latest/examples/query_transformations/SimpleIndexDemo-multistep.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_transformations/SimpleIndexDemo-multistep.html’
#
# docs.llamaindex.ai/     [ <=>                ] 221.95K  --.-KB/s    in 0.007s
#
# 2024-01-19 15:21:03 (31.8 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_transformations/SimpleIndexDemo-multistep.html’ saved [227280]
#
# --2024-01-19 15:21:03--  https://docs.llamaindex.ai/en/latest/examples/query_engine/sub_question_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/sub_question_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 224.71K  --.-KB/s    in 0.006s
#
# 2024-01-19 15:21:04 (39.4 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/sub_question_query_engine.html’ saved [230101]
#
# --2024-01-19 15:21:04--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_retrieval.html’
#
# docs.llamaindex.ai/     [ <=>                ] 220.79K  --.-KB/s    in 0.002s
#
# 2024-01-19 15:21:04 (87.3 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_retrieval.html’ saved [226089]
#
# --2024-01-19 15:21:04--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_cookbook.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_cookbook.html’
#
# docs.llamaindex.ai/     [ <=>                ] 278.58K  --.-KB/s    in 0.007s
#
# 2024-01-19 15:21:04 (37.5 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_cookbook.html’ saved [285262]
#
# --2024-01-19 15:21:04--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/root.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/root.html’
#
# docs.llamaindex.ai/     [ <=>                ] 223.01K  --.-KB/s    in 0.007s
#
# 2024-01-19 15:21:05 (32.2 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/root.html’ saved [228363]
#
# --2024-01-19 15:21:05--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/usage_pattern.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/usage_pattern.html’
#
# docs.llamaindex.ai/     [ <=>                ] 238.48K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:05 (7.46 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/usage_pattern.html’ saved [244203]
#
# --2024-01-19 15:21:05--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/modules.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/modules.html’
#
# docs.llamaindex.ai/     [ <=>                ] 221.37K  --.-KB/s    in 0.01s
#
# 2024-01-19 15:21:05 (22.7 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/modules.html’ saved [226678]
#
# --2024-01-19 15:21:05--  https://docs.llamaindex.ai/en/latest/examples/query_engine/recursive_retriever_agents.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/recursive_retriever_agents.html’
#
# docs.llamaindex.ai/     [ <=>                ] 233.42K  --.-KB/s    in 0.004s
#
# 2024-01-19 15:21:05 (51.9 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/recursive_retriever_agents.html’ saved [239017]
#
# --2024-01-19 15:21:05--  https://docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html’
#
# docs.llamaindex.ai/     [ <=>                ] 270.63K  --.-KB/s    in 0.04s
#
# 2024-01-19 15:21:06 (6.92 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html’ saved [277128]
#
# --2024-01-19 15:21:06--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_builder.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_builder.html’
#
# docs.llamaindex.ai/     [ <=>                ] 240.00K  --.-KB/s    in 0.005s
#
# 2024-01-19 15:21:06 (45.8 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_builder.html’ saved [245765]
#
# --2024-01-19 15:21:06--  https://docs.llamaindex.ai/en/latest/examples/agent/openai_retrieval_benchmark.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/openai_retrieval_benchmark.html’
#
# docs.llamaindex.ai/     [ <=>                ] 250.17K  --.-KB/s    in 0.006s
#
# 2024-01-19 15:21:06 (38.1 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/openai_retrieval_benchmark.html’ saved [256173]
#
# --2024-01-19 15:21:06--  https://docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 240.50K  --.-KB/s    in 0.001s
#
# 2024-01-19 15:21:07 (218 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html’ saved [246272]
#
# --2024-01-19 15:21:07--  https://docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_initial_context.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_initial_context.html’
#
# docs.llamaindex.ai/     [ <=>                ] 233.92K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:07 (7.50 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_initial_context.html’ saved [239536]
#
# --2024-01-19 15:21:07--  https://docs.llamaindex.ai/en/latest/examples/agent/custom_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/custom_agent.html’
#
# docs.llamaindex.ai/     [ <=>                ] 261.26K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:07 (8.86 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/custom_agent.html’ saved [267530]
#
# --2024-01-19 15:21:07--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner.html’
#
# docs.llamaindex.ai/     [ <=>                ] 245.85K  --.-KB/s    in 0.002s
#
# 2024-01-19 15:21:08 (113 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner.html’ saved [251753]
#
# --2024-01-19 15:21:08--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag.html’
#
# docs.llamaindex.ai/     [ <=>                ] 247.19K  --.-KB/s    in 0.02s
#
# 2024-01-19 15:21:08 (10.5 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag.html’ saved [253121]
#
# --2024-01-19 15:21:08--  https://docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable.html’
#
# docs.llamaindex.ai/     [ <=>                ] 266.10K  --.-KB/s    in 0.005s
#
# 2024-01-19 15:21:08 (47.9 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/agent/agent_runner/agent_runner_rag_controllable.html’ saved [272486]
#
# --2024-01-19 15:21:08--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/root.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/root.html’
#
# docs.llamaindex.ai/     [ <=>                ] 223.83K  --.-KB/s    in 0.005s
#
# 2024-01-19 15:21:08 (42.1 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/root.html’ saved [229200]
#
# --2024-01-19 15:21:08--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/usage_pattern.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/usage_pattern.html’
#
# docs.llamaindex.ai/     [ <=>                ] 224.29K  --.-KB/s    in 0.01s
#
# 2024-01-19 15:21:09 (20.7 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/usage_pattern.html’ saved [229672]
#
# --2024-01-19 15:21:09--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/llamahub_tools_guide.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/llamahub_tools_guide.html’
#
# docs.llamaindex.ai/     [ <=>                ] 225.64K  --.-KB/s    in 0.005s
#
# 2024-01-19 15:21:09 (45.6 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/tools/llamahub_tools_guide.html’ saved [231057]
#
# --2024-01-19 15:21:09--  https://docs.llamaindex.ai/en/latest/module_guides/deploying/agents/agent_runner.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/agent_runner.html’
#
# docs.llamaindex.ai/     [ <=>                ] 224.81K  --.-KB/s    in 0.004s
#
# 2024-01-19 15:21:09 (57.8 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/deploying/agents/agent_runner.html’ saved [230205]
#
# --2024-01-19 15:21:09--  https://docs.llamaindex.ai/en/latest/use_cases/extraction.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/extraction.html’
#
# docs.llamaindex.ai/     [ <=>                ] 215.38K  --.-KB/s    in 0.004s
#
# 2024-01-19 15:21:10 (48.1 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/extraction.html’ saved [220554]
#
# --2024-01-19 15:21:10--  https://docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/structured_outputs.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/structured_outputs.html’
#
# docs.llamaindex.ai/     [ <=>                ] 219.15K  --.-KB/s    in 0.005s
#
# 2024-01-19 15:21:10 (41.2 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/structured_outputs.html’ saved [224407]
#
# --2024-01-19 15:21:10--  https://docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/pydantic_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/pydantic_program.html’
#
# docs.llamaindex.ai/     [ <=>                ] 218.94K  --.-KB/s    in 0.001s
#
# 2024-01-19 15:21:10 (159 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/pydantic_program.html’ saved [224195]
#
# --2024-01-19 15:21:10--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/llm_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/llm_program.html’
#
# docs.llamaindex.ai/     [ <=>                ] 225.99K  --.-KB/s    in 0.008s
#
# 2024-01-19 15:21:10 (28.8 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/llm_program.html’ saved [231412]
#
# --2024-01-19 15:21:10--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/openai_pydantic_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/openai_pydantic_program.html’
#
# docs.llamaindex.ai/     [ <=>                ] 235.92K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:11 (6.64 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/openai_pydantic_program.html’ saved [241584]
#
# --2024-01-19 15:21:11--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html’
#
# docs.llamaindex.ai/     [ <=>                ] 221.95K  --.-KB/s    in 0.002s
#
# 2024-01-19 15:21:11 (113 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html’ saved [227277]
#
# --2024-01-19 15:21:11--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html’
#
# docs.llamaindex.ai/     [ <=>                ] 227.86K  --.-KB/s    in 0.002s
#
# 2024-01-19 15:21:11 (123 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html’ saved [233327]
#
# --2024-01-19 15:21:11--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/df_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/df_program.html’
#
# docs.llamaindex.ai/     [ <=>                ] 233.08K  --.-KB/s    in 0.007s
#
# 2024-01-19 15:21:11 (30.7 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/df_program.html’ saved [238675]
#
# --2024-01-19 15:21:11--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/evaporate_program.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/evaporate_program.html’
#
# docs.llamaindex.ai/     [ <=>                ] 263.93K  --.-KB/s    in 0.006s
#
# 2024-01-19 15:21:12 (46.8 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/evaporate_program.html’ saved [270268]
#
# --2024-01-19 15:21:12--  https://docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 222.88K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:12 (6.62 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/query_engine.html’ saved [228226]
#
# --2024-01-19 15:21:12--  https://docs.llamaindex.ai/en/latest/examples/query_engine/pydantic_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/query_engine/pydantic_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 229.81K  --.-KB/s    in 0.007s
#
# 2024-01-19 15:21:12 (32.6 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/query_engine/pydantic_query_engine.html’ saved [235325]
#
# --2024-01-19 15:21:12--  https://docs.llamaindex.ai/en/latest/examples/response_synthesizers/pydantic_tree_summarize.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/response_synthesizers/pydantic_tree_summarize.html’
#
# docs.llamaindex.ai/     [ <=>                ] 219.03K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:12 (7.14 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/response_synthesizers/pydantic_tree_summarize.html’ saved [224288]
#
# --2024-01-19 15:21:12--  https://docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/output_parser.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/output_parser.html’
#
# docs.llamaindex.ai/     [ <=>                ] 228.31K  --.-KB/s    in 0.04s
#
# 2024-01-19 15:21:13 (6.22 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/output_parser.html’ saved [233789]
#
# --2024-01-19 15:21:13--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html’
#
# docs.llamaindex.ai/     [ <=>                ] 261.23K  --.-KB/s    in 0.005s
#
# 2024-01-19 15:21:13 (48.5 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html’ saved [267501]
#
# --2024-01-19 15:21:13--  https://docs.llamaindex.ai/en/latest/examples/output_parsing/LangchainOutputParserDemo.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/output_parsing/LangchainOutputParserDemo.html’
#
# docs.llamaindex.ai/     [ <=>                ] 221.04K  --.-KB/s    in 0.004s
#
# 2024-01-19 15:21:13 (55.4 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/output_parsing/LangchainOutputParserDemo.html’ saved [226348]
#
# --2024-01-19 15:21:13--  https://docs.llamaindex.ai/en/latest/examples/llm/llama_api.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/llm/llama_api.html’
#
# docs.llamaindex.ai/     [ <=>                ] 223.92K  --.-KB/s    in 0.003s
#
# 2024-01-19 15:21:14 (69.9 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/llm/llama_api.html’ saved [229290]
#
# --2024-01-19 15:21:14--  https://docs.llamaindex.ai/en/latest/examples/usecases/email_data_extraction.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/usecases/email_data_extraction.html’
#
# docs.llamaindex.ai/     [ <=>                ] 250.28K  --.-KB/s    in 0.04s
#
# 2024-01-19 15:21:14 (6.64 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/usecases/email_data_extraction.html’ saved [256290]
#
# --2024-01-19 15:21:14--  https://docs.llamaindex.ai/en/latest/use_cases/multimodal.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/use_cases/multimodal.html’
#
# docs.llamaindex.ai/     [ <=>                ] 219.83K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:14 (7.13 MB/s) - ‘docs.llamaindex.ai/en/latest/use_cases/multimodal.html’ saved [225106]
#
# --2024-01-19 15:21:14--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_multi_modal_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_multi_modal_retrieval.html’
#
# docs.llamaindex.ai/     [ <=>                ] 257.26K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:14 (7.64 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_multi_modal_retrieval.html’ saved [263436]
#
# --2024-01-19 15:21:14--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_retrieval.html’
#
# docs.llamaindex.ai/     [ <=>                ] 251.84K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:15 (7.91 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_retrieval.html’ saved [257888]
#
# --2024-01-19 15:21:15--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/image_to_image_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/image_to_image_retrieval.html’
#
# docs.llamaindex.ai/     [ <=>                ] 238.49K  --.-KB/s    in 0.008s
#
# 2024-01-19 15:21:15 (27.7 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/image_to_image_retrieval.html’ saved [244216]
#
# --2024-01-19 15:21:15--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/structured_image_retrieval.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/structured_image_retrieval.html’
#
# docs.llamaindex.ai/     [ <=>                ] 246.78K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:15 (8.61 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/structured_image_retrieval.html’ saved [252703]
#
# --2024-01-19 15:21:15--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/ChromaMultiModalDemo.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/ChromaMultiModalDemo.html’
#
# docs.llamaindex.ai/     [ <=>                ] 235.41K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:15 (6.66 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/ChromaMultiModalDemo.html’ saved [241062]
#
# --2024-01-19 15:21:15--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pdf_tables.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pdf_tables.html’
#
# docs.llamaindex.ai/     [ <=>                ] 317.33K  --.-KB/s    in 0.04s
#
# 2024-01-19 15:21:16 (7.98 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pdf_tables.html’ saved [324947]
#
# --2024-01-19 15:21:16--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pydantic.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pydantic.html’
#
# docs.llamaindex.ai/     [ <=>                ] 252.45K  --.-KB/s    in 0.04s
#
# 2024-01-19 15:21:16 (7.00 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/multi_modal_pydantic.html’ saved [258505]
#
# --2024-01-19 15:21:16--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/llava_multi_modal_tesla_10q.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/llava_multi_modal_tesla_10q.html’
#
# docs.llamaindex.ai/     [ <=>                ] 242.98K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:16 (7.17 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/llava_multi_modal_tesla_10q.html’ saved [248816]
#
# --2024-01-19 15:21:16--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/mm_agent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/mm_agent.html’
#
# docs.llamaindex.ai/     [ <=>                ] 243.49K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:17 (7.58 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/mm_agent.html’ saved [249332]
#
# --2024-01-19 15:21:17--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_experiments_cot.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_experiments_cot.html’
#
# docs.llamaindex.ai/     [ <=>                ] 260.64K  --.-KB/s    in 0.04s
#
# 2024-01-19 15:21:17 (7.14 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_experiments_cot.html’ saved [266894]
#
# --2024-01-19 15:21:17--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/replicate_multi_modal.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/replicate_multi_modal.html’
#
# docs.llamaindex.ai/     [ <=>                ] 249.89K  --.-KB/s    in 0.03s
#
# 2024-01-19 15:21:17 (8.70 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/replicate_multi_modal.html’ saved [255886]
#
# --2024-01-19 15:21:17--  https://docs.llamaindex.ai/en/latest/examples/multi_modal/openai_multi_modal.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/examples/multi_modal/openai_multi_modal.html’
#
# docs.llamaindex.ai/     [ <=>                ] 242.60K  --.-KB/s    in 0.04s
#
# 2024-01-19 15:21:18 (6.76 MB/s) - ‘docs.llamaindex.ai/en/latest/examples/multi_modal/openai_multi_modal.html’ saved [248427]
#
# ...
# 1131-2
# Converting links in docs.llamaindex.ai/en/latest/module_guides/models/models.html... 1108.
# 1106-2
# Converting links in docs.llamaindex.ai/en/latest/community/integrations/using_with_langchain.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MetadataFilters.html... 1125.
# 1123-2
# Converting links in docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_async.html... 1115.
# 1113-2
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/DeepLakeIndexDemo.html... 1109.
# 1107-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.TwitterTweetReader.html... 1118.
# 1116-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.TransformComponent.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/pdf_tables/recursive_retriever.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.TencentVectorDB.html... 1145.
# 1141-4
# Converting links in docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/unified_query.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/module_guides/indexing/index_guide.html... 1132.
# 1130-2
# Converting links in docs.llamaindex.ai/en/latest/module_guides/evaluating/contributing_llamadatasets.html... 1108.
# 1106-2
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/WebPageDemo.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/finetuning/gradient/gradient_fine_tuning.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/module_guides/models/prompts/usage_pattern.html... 1133.
# 1131-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.Node.html... 1108.
# 1106-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.GithubRepositoryReader.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/multi_modal/llava_multi_modal_tesla_10q.html... 1129.
# 1127-2
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/pgvector_sql_query_engine.html... 1129.
# 1127-2
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/knowledge_graph_query_engine.html... 1117.
# 1113-4
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.node_parser.MarkdownNodeParser.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.SimpleMongoReader.html... 1112.
# 1110-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.WikipediaReader.html... 1114.
# 1112-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.RelatedNodeInfo.html... 1122.
# 1120-2
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/NotionDemo.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/examples/multi_modal/ChromaMultiModalDemo.html... 1118.
# 1116-2
# Converting links in docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/root.html... 1125.
# 1123-2
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/SupabaseVectorIndexDemo.html... 1115.
# 1113-2
# Converting links in docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_multi_modal_retrieval.html... 1126.
# 1124-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.TairVectorStore.html... 1137.
# 1133-4
# Converting links in docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/output_parser.html... 1116.
# 1114-2
# Converting links in docs.llamaindex.ai/en/latest/examples/response_synthesizers/pydantic_tree_summarize.html... 1109.
# 1107-2
# Converting links in docs.llamaindex.ai/en/latest/community/integrations/vector_stores.html... 1147.
# 1145-2
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_bundle.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/managed/zcpDemo.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/examples/composable_indices/ComposableIndices-Prior.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/RetrieverRouterQueryEngine.html... 1115.
# 1113-2
# Converting links in docs.llamaindex.ai/en/latest/examples/evaluation/guideline_eval.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.SimpleVectorStore.html... 1149.
# 1146-3
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/vllm.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/anyscale.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.node_parser.HTMLNodeParser.html... 1119.
# 1117-2
# Converting links in docs.llamaindex.ai/en/latest/examples/chat_engine/chat_engine_context.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MyScaleVectorStore.html... 1143.
# 1139-4
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_engines/router_query_engine.html... 1146.
# 1144-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/openllm.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/retrievers/list.html... 1179.
# 1177-2
# Converting links in docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_camel.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/gradient_base_model.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/chatbots/building_a_chatbot.html... 1124.
# 1122-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.node_parser.CodeSplitter.html... 1123.
# 1121-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.PineconeVectorStore.html... 1145.
# 1142-3
# Converting links in docs.llamaindex.ai/en/latest/community/full_stack_projects.html... 1115.
# 1113-2
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/multi_doc_auto_retrieval/multi_doc_auto_retrieval.html... 1129.
# 1127-2
# Converting links in docs.llamaindex.ai/en/latest/optimizing/evaluation/e2e_evaluation.html... 1122.
# 1120-2
# Converting links in docs.llamaindex.ai/en/latest/examples/retrievers/composable_retrievers.html... 1119.
# 1117-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/ollama.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/litellm.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.PsychicReader.html... 1112.
# 1110-2
# Converting links in docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/community/integrations/graphsignal.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/deplot/DeplotReader.html... 1109.
# 1107-2
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/SQLRouterQueryEngine.html... 1119.
# 1117-2
# Converting links in docs.llamaindex.ai/en/latest/examples/metadata_extraction/MetadataExtractionSEC.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/examples/docstore/MongoDocstoreDemo.html... 1106.
# 1104-2
# Converting links in docs.llamaindex.ai/en/latest/examples/response_synthesizers/refine.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/output_parsing/lmformatenforcer_pydantic_program.html... 1100.
# 1098-2
# Converting links in docs.llamaindex.ai/en/latest/api_reference/llms/palm.html... 1125.
# 1123-2
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/simple_directory_reader.html... 1109.
# 1107-2
# Converting links in docs.llamaindex.ai/en/latest/examples/finetuning/embeddings/finetune_embedding.html... 1129.
# 1127-2
# Converting links in docs.llamaindex.ai/en/latest/community/integrations/trulens.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llama_dataset/labelled-rag-datasets.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.BaseComponent.html... 1121.
# 1119-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/bedrock.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/gradient_model_adapter.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/module_guides/loading/ingestion_pipeline/transformations.html... 1116.
# 1114-2
# Converting links in docs.llamaindex.ai/en/latest/examples/response_synthesizers/structured_refine.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.MetadataMode.html... 1119.
# 1117-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llama_dataset/downloading_llama_datasets.html... 1109.
# 1107-2
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/ZepIndexDemo.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/examples/docstore/DocstoreDemo.html... 1105.
# 1103-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.GoogleDocsReader.html... 1114.
# 1112-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.node_parser.get_root_nodes.html... 1109.
# 1107-2
# Converting links in docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/module_guides/models/llms/local.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/examples/callbacks/OpenLLMetry.html... 1116.
# 1114-2
# Converting links in docs.llamaindex.ai/en/latest/use_cases/multimodal.html... 1134.
# 1132-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.ChromaVectorStore.html... 1141.
# 1138-3
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/TwitterDemo.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/examples/retrievers/simple_fusion.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/node_postprocessor/MetadataReplacementDemo.html... 1127.
# 1125-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeWithScore.html... 1135.
# 1133-2
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_engines/retriever_router_query_engine.html... 1141.
# 1139-2
# Converting links in docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data/Airbyte_demo.html... 1124.
# 1122-2
# Converting links in docs.llamaindex.ai/en/latest/getting_started/reading.html... 1115.
# 1113-2
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/MilvusReaderDemo.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/FaissIndexDemo.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/embeddings/together.html... 1109.
# 1107-2
# Converting links in docs.llamaindex.ai/en/latest/api_reference/example_notebooks.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/examples/node_postprocessor/PrevNextPostprocessorDemo.html... 1115.
# 1113-2
# Converting links in docs.llamaindex.ai/en/latest/examples/node_postprocessor/RecencyPostprocessorDemo.html... 1115.
# 1113-2
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/recursive_retriever_agents.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/JaguarIndexDemo.html... 1125.
# 1123-2
# Converting links in docs.llamaindex.ai/en/latest/examples/finetuning/llm_judge/pairwise/finetune_llm_judge.html... 1125.
# 1123-2
# Converting links in docs.llamaindex.ai/en/latest/examples/embeddings/llm_rails.html... 1104.
# 1102-2
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_transform.html... 1153.
# 1151-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MilvusVectorStore.html... 1129.
# 1126-3
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/simple_chat_engine.html... 1136.
# 1134-2
# Converting links in docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/examples/evaluation/answer_and_context_relevancy.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageDocument.html... 1109.
# 1107-2
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/PineconeDemo.html... 1107.
# 1105-2
# Converting links in docs.llamaindex.ai/en/latest/api_reference/indices/tree.html... 1265.
# 1263-2
# Converting links in docs.llamaindex.ai/en/latest/api_reference/finetuning.html... 1199.
# 1197-2
# Converting links in docs.llamaindex.ai/en/latest/examples/low_level/evaluation.html... 1126.
# 1122-4
# Converting links in docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/examples/evaluation/relevancy_eval.html... 1109.
# 1107-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.JSONReader.html... 1111.
# 1109-2
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/llama_2.html... 1117.
# 1115-2
# Converting links in docs.llamaindex.ai/en/latest/examples/index_structs/knowledge_graph/Neo4jKGIndexDemo.html... 1119.
# 1117-2
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/Timescalevector.html... 1139.
# 1137-2
# Converting links in docs.llamaindex.ai/en/latest/optimizing/fine-tuning/fine-tuning.html... 1148.
# 1146-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.AstraDBVectorStore.html... 1128.
# 1125-3
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.WeaviateVectorStore.html... 1135.
# 1132-3
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_engines.html... 1118.
# 1116-2
# Converting links in docs.llamaindex.ai/en/latest/examples/response_synthesizers/custom_prompt_synthesizer.html... 1113.
# 1111-2
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/WeaviateIndexDemo.html... 1115.
# 1113-2
# Converting links in docs.llamaindex.ai/en/latest/community/faq/chat_engines.html... 1115.
# 1113-2
# Converting links in docs.llamaindex.ai/en/latest/examples/retrievers/you_retriever.html... 1107.
# 1105-2
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/condense_question_chat_engine.html... 1137.
# 1135-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.ZepVectorStore.html... 1146.
# 1140-6
# Converting links in docs.llamaindex.ai/en/latest/_static/mystnb.4510f1fc1dee50b3e5859aac5469c37c29e427902b24a333a5f9fcb2f0b3ac41.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/pygments.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/autodoc_pydantic.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/graphviz.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/styles/furo-extensions.css@digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/css/algolia.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/css/custom.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/styles/furo.css@digest=fad236701ea90a88636c2a8c73b44ae642ed2a53.css... nothing to do.
# Converted links in 697 files in 4.1 seconds.

# %%
from llama_hub.file.unstructured.base import UnstructuredReader
from pathlib import Path
from llama_index.llms import OpenAI
from llama_index import ServiceContext
from llama_index import Document

# %%
reader = UnstructuredReader()
all_files_gen = Path("./docs.llamaindex.ai/").rglob("*")
all_files = [f.resolve() for f in all_files_gen]
all_html_files = [f for f in all_files if f.suffix.lower() == ".html"]


# TODO: set to higher value if you want more docs
doc_limit = 100

docs = []
for idx, f in enumerate(all_html_files):
    if idx > doc_limit:
        break
    print(f"Idx {idx}/{len(all_html_files)}")
    loaded_docs = reader.load_data(file=f, split_documents=True)
    # Hardcoded Index. Everything before this is ToC for all pages
    start_idx = 72
    loaded_doc = Document(
        text="\n\n".join([d.get_content() for d in loaded_docs[72:]]),
        metadata={"path": str(f)},
    )
    print(loaded_doc.metadata["path"])
    docs.append(loaded_doc)
# Out:
# [nltk_data] Downloading package punkt to /Users/jerryliu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/jerryliu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Idx 0/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/index.html
# Idx 1/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/genindex.html
# Idx 2/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/search.html
# Idx 3/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/contributing/documentation.html
# Idx 4/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/contributing/contributing.html
# Idx 5/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/changes/changelog.html
# Idx 6/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/changes/deprecated_terms.html
# Idx 7/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/understanding.html
# Idx 8/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/using_llms/using_llms.html
# Idx 9/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/using_llms/privacy.html
# Idx 10/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/loading/llamahub.html
# Idx 11/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/loading/loading.html
# Idx 12/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/evaluating/evaluating.html
# Idx 13/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/root.html
# Idx 14/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/usage_pattern.html
# Idx 15/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/storing/storing.html
# Idx 16/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/tracing_and_debugging/tracing_and_debugging.html
# Idx 17/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/indexing/indexing.html
# Idx 18/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/querying/querying.html
# Idx 19/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps.html
# Idx 20/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a.html
# Idx 21/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/graphs.html
# Idx 22/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data.html
# Idx 23/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/agents.html
# Idx 24/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/putting_it_all_together.html
# Idx 25/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/terms_definitions_tutorial.html
# Idx 26/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/unified_query.html
# Idx 27/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data/Airbyte_demo.html
# Idx 28/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/chatbots/building_a_chatbot.html
# Idx 29/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_app_guide.html
# Idx 30/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/apps/fullstack_with_delphic.html
# Idx 31/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/evaluation.html
# Idx 32/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/node.html
# Idx 33/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/callbacks.html
# Idx 34/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/storage.html
# Idx 35/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/index.html
# Idx 36/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llm_predictor.html
# Idx 37/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/response.html
# Idx 38/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/prompts.html
# Idx 39/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/indices.html
# Idx 40/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/struct_store.html
# Idx 41/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/agents.html
# Idx 42/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/multi_modal.html
# Idx 43/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/service_context.html
# Idx 44/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/node_postprocessor.html
# Idx 45/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query.html
# Idx 46/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/memory.html
# Idx 47/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms.html
# Idx 48/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/finetuning.html
# Idx 49/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/playground.html
# Idx 50/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/example_notebooks.html
# Idx 51/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/readers.html
# Idx 52/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/composability.html
# Idx 53/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/indices/tree.html
# Idx 54/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/indices/list.html
# Idx 55/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/indices/table.html
# Idx 56/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/indices/struct_store.html
# Idx 57/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/indices/kg.html
# Idx 58/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/indices/vector_store.html
# Idx 59/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/indices/empty.html
# Idx 60/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/service_context/prompt_helper.html
# Idx 61/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/service_context/node_parser.html
# Idx 62/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/service_context/embeddings.html
# Idx 63/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/langchain_integrations/base.html
# Idx 64/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/storage/kv_store.html
# Idx 65/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/storage/docstore.html
# Idx 66/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/storage/index_store.html
# Idx 67/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/storage/indices_save_load.html
# Idx 68/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/storage/vector_store.html
# Idx 69/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/multi_modal/openai.html
# Idx 70/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/multi_modal/replicate.html
# Idx 71/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/openai_like.html
# Idx 72/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/palm.html
# Idx 73/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/gradient_base_model.html
# Idx 74/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/langchain.html
# Idx 75/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/litellm.html
# Idx 76/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/openllm.html
# Idx 77/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/llama_cpp.html
# Idx 78/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/azure_openai.html
# Idx 79/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/gradient_model_adapter.html
# Idx 80/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/huggingface.html
# Idx 81/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/xinference.html
# Idx 82/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/predibase.html
# Idx 83/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/anthropic.html
# Idx 84/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/openai.html
# Idx 85/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/llms/replicate.html
# Idx 86/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/query_engines.html
# Idx 87/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/retrievers.html
# Idx 88/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/response_synthesizer.html
# Idx 89/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/query_transform.html
# Idx 90/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/query_bundle.html
# Idx 91/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/chat_engines.html
# Idx 92/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/retrievers/tree.html
# Idx 93/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/retrievers/transform.html
# Idx 94/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/retrievers/list.html
# Idx 95/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/retrievers/table.html
# Idx 96/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/retrievers/kg.html
# Idx 97/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/retrievers/vector_store.html
# Idx 98/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/retrievers/empty.html
# Idx 99/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/simple_chat_engine.html
# Idx 100/691
# /Users/jerryliu/Programming/gpt_index/docs/examples/embeddings/docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/condense_plus_context_chat_engine.html

# %% [markdown]
# ## Building Multi-Document Hierarchical Retrieval

# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install LlamaIndex 🦙.

# %%
# !pip install llama-index

# %%
# You can set the API key in the embeddings or env
# import os
# os.environ["TOEGETHER_API_KEY"] = "your-api-key"

from llama_index.embeddings import TogetherEmbedding

api_key = "69830899a4a7bb86b9abbdfea76a114bfbabcf66bde48956a3ecf789256e7601"

embed_model_long = TogetherEmbedding(
    model_name="togethercomputer/m2-bert-80M-32k-retrieval", api_key=api_key
)
embed_model_short = TogetherEmbedding(
    model_name="togethercomputer/m2-bert-80M-8k-retrieval", api_key=api_key
)

llm = OpenAI(temperature=0, model="gpt-3.5-turbo")
sc_long = ServiceContext.from_defaults(llm=llm, embed_model=embed_model_long)
sc_short = ServiceContext.from_defaults(llm=llm, embed_model=embed_model_short)

# %%
from llama_index.schema import IndexNode
from llama_index import load_index_from_storage, StorageContext, VectorStoreIndex
from llama_index.node_parser import SentenceSplitter
import os
from tqdm.notebook import tqdm
import pickle


async def build_index_per_doc(nodes, file_base):
    print(file_base)

    vi_out_path = f"./data/llamaindex_docs/{file_base}"
    if not os.path.exists(vi_out_path):
        Path("./data/llamaindex_docs/").mkdir(parents=True, exist_ok=True)
        # build vector index
        vector_index = VectorStoreIndex(nodes, service_context=sc_short)
        vector_index.storage_context.persist(persist_dir=vi_out_path)
    else:
        vector_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=vi_out_path),
            service_context=sc_short,
        )

    # define query engines
    vector_query_engine = vector_index.as_query_engine()

    return vector_query_engine

async def build_hierarchical_index(docs):
    node_parser = SentenceSplitter()

    # Build agents dictionary
    query_engine_dict = {}
    index_node_dict = {}
    extra_info_dict = {}

    index_nodes = []

    # # this is for the baseline
    # all_nodes = []

    for idx, doc in enumerate(tqdm(docs)):
        nodes = node_parser.get_nodes_from_documents([doc])
        # all_nodes.extend(nodes)

        # ID will be base + parent
        file_path = Path(doc.metadata["path"])
        file_base = str(file_path.parent.stem) + "_" + str(file_path.stem)

        # get query engine
        vector_query_engine = await build_index_per_doc(nodes, file_base)
        query_engine_dict[file_base] = vector_query_engine


        # get document embedding
        doc_embedding = sc_long.embed_model.get_text_embedding(doc.get_content())
        index_node = IndexNode(
            text=str(file_path), index_id=str(file_path), obj=vector_query_engine
        )
        index_nodes.append(index_node)
        # extra_info_dict[file_base] = {"file_path": file_path}


    top_index = VectorStoreIndex(index_nodes, service_context=sc_long)

    return top_index

# %%
top_index = await build_hierarchical_index(docs)
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]
# latest_index
# latest_genindex
# latest_search
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 top_index = await build_hierarchical_index(docs)
#
# Cell In[7], line 56, in build_hierarchical_index(docs)
#      52 query_engine_dict[file_base] = vector_query_engine
#      55 # get document embedding
# ---> 56 doc_embedding = sc_long.embed_model.get_text_embedding(doc.get_content())
#      57 index_node = IndexNode(
#      58     text=str(file_path), index_id=str(file_path), obj=vector_query_engine
#      59 )
#      60 index_nodes.append(index_node)
#
# File ~/Programming/gpt_index/llama_index/core/embeddings/base.py:207, in BaseEmbedding.get_text_embedding(self, text)
#     196 """
#     197 Embed the input text.
#     198
#    (...)
#     202 predefined instructions can be found in embeddings/huggingface_utils.py.
#     203 """
#     204 with self.callback_manager.event(
#     205     CBEventType.EMBEDDING, payload={EventPayload.SERIALIZED: self.to_dict()}
#     206 ) as event:
# --> 207     text_embedding = self._get_text_embedding(text)
#     209     event.on_end(
#     210         payload={
#     211             EventPayload.CHUNKS: [text],
#     212             EventPayload.EMBEDDINGS: [text_embedding],
#     213         }
#     214     )
#     216 return text_embedding
#
# File ~/Programming/gpt_index/llama_index/embeddings/together.py:97, in TogetherEmbedding._get_text_embedding(self, text)
#      95 def _get_text_embedding(self, text: str) -> Embedding:
#      96     """Get text embedding."""
# ---> 97     return self._generate_embedding(text, self.model_name)
#
# File ~/Programming/gpt_index/llama_index/embeddings/together.py:60, in TogetherEmbedding._generate_embedding(self, text, model_api_string)
#      54 response = session.post(
#      55     self.api_base.strip("/") + "/embeddings",
#      56     headers=headers,
#      57     json={"input": text, "model": model_api_string},
#      58 )
#      59 if response.status_code != 200:
# ---> 60     raise ValueError(
#      61         f"Request failed with status code {response.status_code}: {response.text}"
#      62     )
#      64 return response.json()["data"][0]["embedding"]
#
# ValueError: Request failed with status code 400: {"error":"Input required"}

# %%
top_query_engine = top_index.as_query_engine(verbose=True, similarity_top_k=2)

# %% [markdown]
# ## Run Some Queries

# %%
response = top_query_engine.query(
    "Tell me about the different types of evaluation in LlamaIndex"
)
print(str(response))

# %%
response = top_agent.query(
    "Can you tell me more about some advanced retrieval strategies?"
)
print(str(response))
