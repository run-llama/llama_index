# %%
from llama_index.agent import ReActAgent
from llama_index.llms import OpenAI, ChatMessage
from llama_index.tools import BaseTool, FunctionTool

# %%
def multiply(a: int, b: int) -> int:
    """Multiple two integers and returns the result integer"""
    return a * b


multiply_tool = FunctionTool.from_defaults(fn=multiply)

# %%
def add(a: int, b: int) -> int:
    """Add two integers and returns the result integer"""
    return a + b


add_tool = FunctionTool.from_defaults(fn=add)

# %% [markdown]
# ## gpt-3.5-turbo-0613

# %%
llm = OpenAI(model="gpt-3.5-turbo-0613")
agent = ReActAgent.from_tools([multiply_tool, add_tool], llm=llm, verbose=True)

# %%
response = agent.chat('What is 2+2*4')
print(response)
# Out:
# Thought: I can use the tools to perform the multiplication and addition operations.
# Action: multiply
# Action Input: {'a': 2, 'b': 4}
# Observation: 8
# Thought: Now I need to add 2 to the result of the multiplication.
# Action: add
# Action Input: {'a': 8, 'b': 2}
# Observation: 10
# Response: 10
# 10

# %% [markdown]
# ## gpt-4

# %%
llm = OpenAI(model="gpt-4")
agent = ReActAgent.from_tools([multiply_tool, add_tool], llm=llm, verbose=True)

# %%
response = agent.chat('What is 2+2*4')
print(response)
# Out:
# Thought: I need to use the tools to help me answer the question. I will first multiply 2 and 4, then add the result to 2.
# Action: multiply
# Action Input: {'a': 2, 'b': 4}
# Observation: 8
# Thought: Now that I have the result of 2*4, I need to add this result to 2.
# Action: add
# Action Input: {'a': 2, 'b': 8}
# Observation: 10
# Response: 10
# 10

# %% [markdown]
# ## text-davinci-003

# %%
llm = OpenAI(model="text-davinci-003")
agent = ReActAgent.from_tools([multiply_tool, add_tool], llm=llm, verbose=True)

# %%
response = agent.chat('What is 2+2*4')
print(response)
# Out:
# Thought: I need to use a tool to help me answer the question.
# Action: add
# Action Input: {'a': 2, 'b': 8}
# Observation: 10
# Response: 10
# 10
