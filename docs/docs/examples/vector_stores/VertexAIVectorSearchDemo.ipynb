# %% [markdown]
# <a href=\"https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/vector_stores/VertexAIVectorSearchDemo.ipynb\" target=\"_parent\"><img src=\"https://colab.research.google.com/assets/colab-badge.svg\" alt=\"Open In Colab\"/></a>

# %%
# ! pip install llama-index-readers-file
# ! pip install --quiet llama-index-embeddings-vertex
# ! pip install --quiet llama-index-storage-docstore-firestore
# ! pip install --quiet llama-index-llms-vertex

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import SimpleNodeParser

# load the blogs in using the reader
blogs = SimpleDirectoryReader("./data").load_data()

# chunk up the blog posts into nodes
parser = SimpleNodeParser.from_defaults(chunk_size=1024, chunk_overlap=20)
nodes = parser.get_nodes_from_documents(blogs)

# %%
from llama_index.embeddings.vertex import VertexTextEmbedding

embed_model = VertexTextEmbedding(
    project="rthallam-demo-project", location="us-central1"
)
embed_model.dict()
# Out:
# {'model_name': 'textembedding-gecko@003',
#  'embed_batch_size': 10,
#  'num_workers': None,
#  'embed_mode': <VertexEmbeddingMode.RETRIEVAL_MODE: 'retrieval'>,
#  'additional_kwargs': {},
#  'class_name': 'VertexTextEmbedding'}

# %%
embed_text_result = embed_model.get_text_embedding("Hello World!")
embed_query_result = embed_model.get_query_embedding("Hello World!")
from llama_index.core.base.embeddings.base import SimilarityMode

embed_model.similarity(
    embed_text_result, embed_query_result, SimilarityMode.DOT_PRODUCT
)
# Out:
# 0.7372278621095343

# %%
# Project settings
PROJECT_ID = "rthallam-demo-project"  # @param {type:"string"}
REGION = "us-central1"  # @param {type:"string"}
LOCATION = REGION
PROJECT_NUMBER = (
    ! gcloud projects describe $PROJECT_ID --format="value(projectNumber)"
)
PROJECT_NUMBER = PROJECT_NUMBER[0]

# Cloud storage buckets
GCS_BUCKET_URI = "gs://llamaindex-vertexai"  # @param {type:"string"}
GCS_BUCKET_NAME = GCS_BUCKET_URI.replace("gs://", "")

# Vertex AI Vector Search
# parameter description here
# https://cloud.google.com/python/docs/reference/aiplatform/latest/google.cloud.aiplatform.MatchingEngineIndex#google_cloud_aiplatform_MatchingEngineIndex_create_tree_ah_index
VS_INDEX_NAME = "llamaindex-doc-index"  # @param {type:"string"}
VS_INDEX_ENDPOINT_NAME = "llamaindex-doc-endpoint"  # @param {type:"string"}
VS_CONTENTS_DELTA_URI = f"{GCS_BUCKET_URI}/index/embeddings"
VS_DIMENSIONS = 768
VS_APPROX_NEIGHBORS = 150
VS_INDEX_UPDATE_METHOD = "STREAM_UPDATE"
VS_INDEX_SHARD_SIZE = "SHARD_SIZE_SMALL"
VS_LEAF_NODE_EMB_COUNT = 500
VS_LEAF_SEARCH_PERCENT = 80
VS_DISTANCE_MEASURE_TYPE = "DOT_PRODUCT_DISTANCE"
VS_MACHINE_TYPE = "e2-standard-16"
VS_MIN_REPLICAS = 1
VS_MAX_REPLICAS = 1
VS_DESCRIPTION = (
    "Index for llamaindex Vertex integration"  # @param {type:"string"}
)

CREATE_RESOURCES = True  # @param {type:"boolean"}

# %%
# @title Utility function to create resources
import hashlib
import uuid

from google.cloud import storage
from google.cloud import aiplatform
from google.cloud.aiplatform import (
    MatchingEngineIndex,
    MatchingEngineIndexEndpoint,
)
from google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint import (
    Namespace,
)


def create_bucket(bucket_name):
    # create Cloud Storage bucket if does not exists
    storage_client = storage.Client()
    GCS_BUCKET = storage_client.bucket(bucket_name)
    if not GCS_BUCKET.exists() and CREATE_RESOURCES:
        bucket = storage_client.create_bucket(bucket_name)
        print(f"Bucket {bucket.name} created")
    else:
        print(f"Bucket {GCS_BUCKET.name} exists")

    return GCS_BUCKET


def create_index():
    index_names = [
        index.resource_name
        for index in MatchingEngineIndex.list(
            filter=f"display_name={VS_INDEX_NAME}"
        )
    ]

    if len(index_names) == 0:
        if CREATE_RESOURCES:
            print(f"Creating Vector Search index {VS_INDEX_NAME} ...")
            vs_index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
                display_name=VS_INDEX_NAME,
                dimensions=VS_DIMENSIONS,
                approximate_neighbors_count=VS_APPROX_NEIGHBORS,
                distance_measure_type=VS_DISTANCE_MEASURE_TYPE,
                leaf_node_embedding_count=VS_LEAF_NODE_EMB_COUNT,
                leaf_nodes_to_search_percent=VS_LEAF_SEARCH_PERCENT,
                description=VS_DESCRIPTION,
                shard_size=VS_INDEX_SHARD_SIZE,
                index_update_method=VS_INDEX_UPDATE_METHOD,
                project=PROJECT_ID,
                location=REGION,
            )
            print(
                f"Vector Search index {vs_index.display_name} created with resource name {vs_index.resource_name}"
            )
        else:
            vs_index = None
            print(
                f"CREATE_RESOURCES flag set to {CREATE_RESOURCES}. Skip creating resources"
            )
    else:
        vs_index = MatchingEngineIndex(index_name=index_names[0])
        print(
            f"Vector Search index {vs_index.display_name} exists with resource name {vs_index.resource_name}"
        )

    return vs_index


def create_index_endpoint():
    endpoint_names = [
        endpoint.resource_name
        for endpoint in MatchingEngineIndexEndpoint.list(
            filter=f"display_name={VS_INDEX_ENDPOINT_NAME}"
        )
    ]

    if len(endpoint_names) == 0:
        if CREATE_RESOURCES:
            print(
                f"Creating Vector Search index endpoint {VS_INDEX_ENDPOINT_NAME} ..."
            )
            vs_endpoint = aiplatform.MatchingEngineIndexEndpoint.create(
                display_name=VS_INDEX_ENDPOINT_NAME,
                public_endpoint_enabled=True,
                description=VS_DESCRIPTION,
                project=PROJECT_ID,
                location=REGION,
            )
            print(
                f"Vector Search index endpoint {vs_endpoint.display_name} created with resource name {vs_endpoint.resource_name}"
            )
        else:
            vs_endpoint = None
            print(
                f"CREATE_RESOURCES flag set to {CREATE_RESOURCES}. Skip creating resources"
            )
    else:
        vs_endpoint = MatchingEngineIndexEndpoint(
            index_endpoint_name=endpoint_names[0]
        )
        print(
            f"Vector Search index endpoint {vs_endpoint.display_name} exists with resource name {vs_endpoint.resource_name}"
        )

    return vs_endpoint


def deploy_index(index, endpoint):
    index_endpoints = [
        (deployed_index.index_endpoint, deployed_index.deployed_index_id)
        for deployed_index in index.deployed_indexes
    ]

    if len(index_endpoints) == 0:
        if CREATE_RESOURCES:
            print(
                f"Deploying Vector Search index {index.display_name} at endpoint {endpoint.display_name} ..."
            )
            deployed_index_id = f'{VS_INDEX_NAME}_{create_uuid(VS_INDEX_NAME).split("-")[-1]}'.replace(
                "-", "_"
            )
            vs_deployed_index = endpoint.deploy_index(
                index=index,
                deployed_index_id=deployed_index_id,
                display_name=VS_INDEX_NAME,
                machine_type=VS_MACHINE_TYPE,
                min_replica_count=VS_MIN_REPLICAS,
                max_replica_count=VS_MAX_REPLICAS,
            )
            print(
                f"Vector Search index {index.display_name} is deployed at endpoint {vs_deployed_index.display_name}"
            )
        else:
            vs_deployed_index = None
            print(
                f"CREATE_RESOURCES flag set to {CREATE_RESOURCES}. Skip creating resources"
            )
    else:
        vs_deployed_index = MatchingEngineIndexEndpoint(
            index_endpoint_name=index_endpoints[0][0]
        )
        print(
            f"Vector Search index {index.display_name} is already deployed at endpoint {vs_deployed_index.display_name}"
        )

    return vs_deployed_index


def create_uuid(name: str):
    hex_string = hashlib.md5(name.encode("UTF-8")).hexdigest()
    return str(uuid.UUID(hex=hex_string))

# %%
import vertexai

vertexai.init(project=PROJECT_ID, location=LOCATION)

# %%
# Create bucket if not exists
bucket = create_bucket(GCS_BUCKET_NAME)
# Out:
# Bucket llamaindex-vertexai exists

# %%
# Create vector search index if not exists else return index resource name
vs_index = create_index()
vs_index = MatchingEngineIndex(index_name=vs_index.resource_name)
# Out:
# Vector Search index llamaindex-doc-index exists with resource name projects/560224572293/locations/us-central1/indexes/6244298057953837056

# %%
# Create vector search index endpoint if not exists else return index endpoint resource name
vs_endpoint = create_index_endpoint()
# Out:
# Vector Search index endpoint llamaindex-doc-endpoint exists with resource name projects/560224572293/locations/us-central1/indexEndpoints/151948108912132096

# %%
# Deploy index to the index endpoint
deploy_index(vs_index, vs_endpoint)
# Out:
# Vector Search index llamaindex-doc-index is already deployed at endpoint llamaindex-doc-endpoint
# <google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint.MatchingEngineIndexEndpoint object at 0x7fc398a077f0>
# resource name: projects/560224572293/locations/us-central1/indexEndpoints/151948108912132096

# %%
from llama_index.core import StorageContext, Settings, VectorStoreIndex
from llama_index.vector_stores.vertexaivectorsearch import VertexAIVectorStore
from llama_index.embeddings.vertex import (
    VertexTextEmbedding,
    VertexEmbeddingMode,
)
from llama_index.storage.docstore.firestore import FirestoreDocumentStore
from llama_index.storage.kvstore.firestore import FirestoreKVStore

# %%
print(f'export PROJECT_ID="{PROJECT_ID}"')
print(f'export REGION="{LOCATION}"')
print(f'export INDEX_ID="{vs_index.resource_name}"')
print(f'export ENDPOINT_ID="{vs_endpoint.resource_name}"')
print(f'export GCS_BUCKET_NAME="{GCS_BUCKET_NAME}"')
# Out:
# export PROJECT_ID="rthallam-demo-project"
# export REGION="us-central1"
# export INDEX_ID="projects/560224572293/locations/us-central1/indexes/6244298057953837056"
# export ENDPOINT_ID="projects/560224572293/locations/us-central1/indexEndpoints/151948108912132096"
# export GCS_BUCKET_NAME="llamaindex-vertexai"

# %%
# setup storage
vector_store = VertexAIVectorStore(
    project_id=PROJECT_ID,
    region=LOCATION,
    index_id=vs_index.resource_name,
    endpoint_id=vs_endpoint.resource_name,
    gcs_bucket_name=GCS_BUCKET_NAME,
)

kv_store = FirestoreKVStore()
doc_store = FirestoreDocumentStore(kv_store)

storage_context = StorageContext.from_defaults(
    docstore=doc_store, vector_store=vector_store
)

# setup the index/query process, ie the embedding model (and completion if used)
Settings.embed_model = VertexTextEmbedding(
    project=PROJECT_ID,
    location=LOCATION,
    model_name="textembedding-gecko@003",
    embed_mode=VertexEmbeddingMode.RETRIEVAL_MODE,
)

# %%
from llama_index.core.schema import TextNode
import uuid
import hashlib


def create_uuid(text: str):
    hex_string = hashlib.md5(text.encode("UTF-8")).hexdigest()
    return str(uuid.UUID(hex=hex_string))


record_data = [
    {
        "description": "A versatile pair of dark-wash denim jeans."
        "Made from durable cotton with a classic straight-leg cut, these jeans"
        " transition easily from casual days to dressier occasions.",
        "price": 65.00,
        "color": "blue",
        "season": ["fall", "winter", "spring"],
    },
    {
        "description": "A lightweight linen button-down shirt in a crisp white."
        " Perfect for keeping cool with breathable fabric and a relaxed fit.",
        "price": 34.99,
        "color": "white",
        "season": ["summer", "spring"],
    },
    {
        "description": "A soft, chunky knit sweater in a vibrant forest green. "
        "The oversized fit and cozy wool blend make this ideal for staying warm "
        "when the temperature drops.",
        "price": 89.99,
        "color": "green",
        "season": ["fall", "winter"],
    },
    {
        "description": "A classic crewneck t-shirt in a soft, heathered blue. "
        "Made from comfortable cotton jersey, this t-shirt is a wardrobe essential "
        "that works for every season.",
        "price": 19.99,
        "color": "blue",
        "season": ["fall", "winter", "summer", "spring"],
    },
    {
        "description": "A flowing midi-skirt in a delicate floral print. "
        "Lightweight and airy, this skirt adds a touch of feminine style "
        "to warmer days.",
        "price": 45.00,
        "color": "white",
        "season": ["spring", "summer"],
    },
    {
        "description": "A pair of tailored black trousers in a comfortable stretch "
        "fabric. Perfect for work or dressier events, these trousers provide a"
        " sleek, polished look.",
        "price": 59.99,
        "color": "black",
        "season": ["fall", "winter", "spring"],
    },
    {
        "description": "A cozy fleece hoodie in a neutral heather grey.  "
        "This relaxed sweatshirt is perfect for casual days or layering when the "
        "weather turns chilly.",
        "price": 39.99,
        "color": "grey",
        "season": ["fall", "winter", "spring"],
    },
    {
        "description": "A bright yellow raincoat with a playful polka dot pattern. "
        "This waterproof jacket will keep you dry and add a touch of cheer to "
        "rainy days.",
        "price": 75.00,
        "color": "yellow",
        "season": ["spring", "fall"],
    },
    {
        "description": "A pair of comfortable khaki chino shorts. These versatile "
        "shorts are a summer staple, perfect for outdoor adventures or relaxed"
        " weekends.",
        "price": 34.99,
        "color": "khaki",
        "season": ["summer"],
    },
    {
        "description": "A bold red cocktail dress with a flattering A-line "
        "silhouette. This statement piece is made from a luxurious satin fabric, "
        "ensuring a head-turning look.",
        "price": 125.00,
        "color": "red",
        "season": ["fall", "winter", "summer", "spring"],
    },
    {
        "description": "A pair of classic white sneakers crafted from smooth "
        "leather. These timeless shoes offer a clean and polished look, perfect "
        "for everyday wear.",
        "price": 79.99,
        "color": "white",
        "season": ["fall", "winter", "summer", "spring"],
    },
    {
        "description": "A chunky cable-knit scarf in a rich burgundy color. "
        "Made from a soft wool blend, this scarf will provide warmth and a touch "
        "of classic style to cold-weather looks.",
        "price": 45.00,
        "color": "burgundy",
        "season": ["fall", "winter"],
    },
    {
        "description": "A lightweight puffer vest in a vibrant teal hue. "
        "This versatile piece adds a layer of warmth without bulk, transitioning"
        " perfectly between seasons.",
        "price": 65.00,
        "color": "teal",
        "season": ["fall", "spring"],
    },
    {
        "description": "A pair of high-waisted leggings in a sleek black."
        " Crafted from a moisture-wicking fabric with plenty of stretch, "
        "these leggings are perfect for workouts or comfortable athleisure style.",
        "price": 49.99,
        "color": "black",
        "season": ["fall", "winter", "summer", "spring"],
    },
    {
        "description": "A denim jacket with a faded wash and distressed details. "
        "This wardrobe staple adds a touch of effortless cool to any outfit.",
        "price": 79.99,
        "color": "blue",
        "season": ["fall", "spring", "summer"],
    },
    {
        "description": "A woven straw sunhat with a wide brim. This stylish "
        "accessory provides protection from the sun while adding a touch of "
        "summery elegance.",
        "price": 32.00,
        "color": "beige",
        "season": ["summer"],
    },
    {
        "description": "A graphic tee featuring a vintage band logo. "
        "Made from a soft cotton blend, this casual tee adds a touch of "
        "personal style to everyday looks.",
        "price": 24.99,
        "color": "white",
        "season": ["fall", "winter", "summer", "spring"],
    },
    {
        "description": "A pair of well-tailored dress pants in a neutral grey. "
        "Made from a wrinkle-resistant blend, these pants look sharp and "
        "professional for workwear or formal occasions.",
        "price": 69.99,
        "color": "grey",
        "season": ["fall", "winter", "summer", "spring"],
    },
    {
        "description": "A pair of classic leather ankle boots in a rich brown hue."
        " Featuring a subtle stacked heel and sleek design, these boots are perfect"
        " for elevating outfits in cooler seasons.",
        "price": 120.00,
        "color": "brown",
        "season": ["fall", "winter", "spring"],
    },
    # {
    #     "description": "A vibrant swimsuit with a bold geometric pattern. This fun "
    #     "and eye-catching piece is perfect for making a splash by the pool or at "
    #     "the beach.",
    #     "price": 55.00,
    #     "color": "multicolor",
    #     "season": ["summer"],
    # },
]

nodes = []
for record in record_data:
    record = record.copy()
    page_content = record.pop("description")
    node_id = create_uuid(page_content)
    if isinstance(page_content, str):
        metadata = {**record}
        node = TextNode(id_=node_id, text=page_content, metadata=metadata)
        nodes.append(node)

# %%
nodes[0].text
# Out:
# 'A versatile pair of dark-wash denim jeans.Made from durable cotton with a classic straight-leg cut, these jeans transition easily from casual days to dressier occasions.'

# %%
storage_context.docstore.add_documents(nodes)

# %%
len(storage_context.docstore.docs)
# Out:
# 109

# %%
index = VectorStoreIndex(nodes, storage_context=storage_context)
# Out:
# Upserting datapoints MatchingEngineIndex index: projects/560224572293/locations/us-central1/indexes/6244298057953837056
# MatchingEngineIndex index Upserted datapoints. Resource name: projects/560224572293/locations/us-central1/indexes/6244298057953837056

# %%
from llama_index.llms.vertex import Vertex

vertex_gemini = Vertex(model="gemini-pro", temperature=0, additional_kwargs={})
Settings.llm = vertex_gemini

# %%
vector_index = VectorStoreIndex.from_vector_store(vector_store)
query_engine = vector_index.as_query_engine()
vector_response = query_engine.query(
    "What is the Google Cloud revenues in 2022?"
)
print(vector_response.response)
# Out:
# Google Cloud revenues in 2022 were $26.28 billion.

# %%
vector_response = query_engine.query("What are Google's R&D expenses in 2022?")
print(vector_response.response)
# Out:
# Google's research and development expenses in 2022 were $31.2 billion. This represents a 17% increase from the previous year. The company's R&D expenses are primarily focused on artificial intelligence, cloud computing, and hardware.

# %%
vars(vector_response)
# Out:
# {'response': "Google's research and development expenses in 2022 were $31.2 billion. This represents a 17% increase from the previous year. The company's R&D expenses are primarily focused on artificial intelligence, cloud computing, and hardware.",
#  'source_nodes': [NodeWithScore(node=TextNode(id_='b674578d-347c-48ad-a659-4b24c0a6dead', embedding=[0.03281565383076668, -0.027546964585781097, 0.011594679206609726, 0.02160458266735077, 0.10328283905982971, 0.04076341167092323, 0.01853843219578266, -0.047991152852773666, 0.013566440902650356, -0.004668778739869595, -5.800629151053727e-05, 0.019096558913588524, -0.0012207955587655306, 0.022969670593738556, 0.025282833725214005, -0.016517166048288345, -0.039272062480449677, 0.0002738218172453344, 0.02130301482975483, -0.002971512032672763, 0.010454706847667694, 0.0012866107281297445, -0.04000452905893326, -0.03143702819943428, -0.04003188759088516, -0.029545437544584274, -0.04830791801214218, -0.018948303535580635, -0.05820021405816078, 0.008111360482871532, -0.07614091038703918, 0.02804400399327278, -0.012556828558444977, 0.034886155277490616, -0.038563281297683716, -0.05152074992656708, -0.004925751127302647, -0.033944547176361084, 0.017934467643499374, 0.0063530378974974155, -0.014503942802548409, -0.025953056290745735, -0.017885036766529083, -0.0026695881970226765, 0.006806495133787394, 0.008965629152953625, 0.027599329128861427, 0.01396170537918806, 0.02912127412855625, -0.050701286643743515, 0.008772363886237144, 0.011941672302782536, 0.059082139283418655, -0.015585781075060368, 0.02980327419936657, -0.054882511496543884, -0.005009629298001528, -0.035552673041820526, -0.024223167449235916, -0.0038604584988206625, 0.06488950550556183, 0.009364886209368706, -0.0318363793194294, 0.0053581674583256245, 0.007266588509082794, -0.09343595802783966, -0.02488708309829235, 0.0011266639921814203, 0.01929164119064808, -0.01028518471866846, -0.015976781025528908, -0.012686549685895443, 0.08356563001871109, -0.03132646530866623, -0.061615027487277985, -0.11680859327316284, -0.05017003417015076, 0.0749218687415123, 0.05939439311623573, 0.03068443574011326, 0.012229320593178272, -0.035937968641519547, -0.04829427972435951, -0.052724119275808334, -0.016230199486017227, 0.012977921403944492, -0.021182790398597717, 0.027960937470197678, -0.024503733962774277, -0.002558337524533272, 0.005628474988043308, -0.010925901122391224, 0.019228707998991013, -0.01800297386944294, 0.009471513330936432, 0.047823626548051834, -0.0026150885969400406, -0.002598145743831992, 0.03147316351532936, -0.06576942652463913, 0.0022890681866556406, -0.0059152087196707726, -0.01552449818700552, -0.00878868903964758, 0.05484069138765335, -0.014708592556416988, -0.05341973155736923, 0.02811863273382187, -0.02538093365728855, 0.003271179972216487, -0.07974512130022049, -0.012188514694571495, -0.03518349304795265, -0.03338431566953659, 0.08986680209636688, -0.015675144270062447, 0.019924834370613098, 0.05106746032834053, 0.008300351910293102, -0.0013782040914520621, 0.0279022678732872, 0.006121060345321894, 0.045813217759132385, 0.02258804254233837, -0.006828849669545889, -0.022703921422362328, -0.048355210572481155, 0.03947554901242256, 0.057982005178928375, 0.08800072222948074, 0.015841715037822723, -0.03952622413635254, 0.024388615041971207, 0.008983423933386803, 0.022538308054208755, 0.10108201950788498, 0.016447873786091805, 0.014893281273543835, 0.03867827355861664, -0.0062613035552203655, -0.047040682286024094, 0.027241667732596397, -0.005464059766381979, 0.012260769493877888, 0.0044619119726121426, 0.06035029515624046, -0.03786822035908699, 0.019669191911816597, 0.014813589863479137, -0.034517087042331696, -0.0020011088345199823, 0.00037904782220721245, -0.011508257128298283, 0.0009499082807451487, 0.03981371596455574, -0.003197119804099202, -0.015244808979332447, 0.028160639107227325, 0.003845774568617344, -0.00930391252040863, 0.052313271909952164, 0.0266940426081419, 0.01085109543055296, 0.03192716836929321, -0.04328345134854317, -0.059347979724407196, -0.010576662607491016, 0.03789689764380455, -0.006914348807185888, 0.027273541316390038, -0.020538199692964554, 0.034338224679231644, -0.017804834991693497, -0.03473132476210594, 0.03231990337371826, -0.0531201 ...
#   NodeWithScore(node=TextNode(id_='8498cc70-b223-4d9a-82b7-e9f7c6aa1b1d', embedding=[0.04552190750837326, -0.04709625616669655, -0.001687613781541586, 0.01762014627456665, 0.05877694487571716, 0.04099208489060402, 0.02776246890425682, -0.040384139865636826, 0.022270269691944122, 0.009974110871553421, -0.013098654337227345, 0.02126774936914444, -0.012360544875264168, 0.009958827868103981, 0.02865653671324253, -0.02292049117386341, -0.04339715838432312, 0.03757031261920929, 0.015085728839039803, 0.00889598298817873, -0.013971639797091484, 0.009850158356130123, -0.04305027797818184, -0.05180409923195839, -0.033463165163993835, -0.011856835335493088, -0.04301723092794418, -0.0327531062066555, -0.040280867367982864, -0.004446155391633511, -0.05936635285615921, 0.013943376950919628, -0.03713008761405945, 0.0406528078019619, -0.042337022721767426, -0.05088511109352112, -0.0025835183914750814, -0.050013378262519836, 0.016176264733076096, 0.0016544483369216323, -0.016677960753440857, -0.007804574444890022, -0.023395869880914688, 0.020506802946329117, -0.009057248011231422, 0.01789010688662529, -0.0023508158046752214, 0.002487263409420848, -0.0002048419410130009, -0.05259857326745987, 0.004896138794720173, -0.003076832741498947, 0.06697778403759003, -0.012763336300849915, 0.031047943979501724, -0.05772466957569122, 0.001370375626720488, -0.02523995004594326, -0.017280276864767075, -0.019142527133226395, 0.07130523771047592, 0.013297401368618011, -0.027091698721051216, 0.011408430524170399, 0.011902873404324055, -0.08797488361597061, -0.029429569840431213, 0.013831369578838348, 0.007620149292051792, 0.0023195291869342327, -0.020808853209018707, -0.010949413292109966, 0.09592805802822113, -0.017583221197128296, -0.060455407947301865, -0.09962566941976547, -0.06949789822101593, 0.07451798021793365, 0.08464518189430237, 0.022619280964136124, 0.005209327209740877, -0.029810136184096336, -0.05399797111749649, -0.034270498901605606, -0.044209934771060944, 0.013488341122865677, -0.029775749891996384, 0.01883227936923504, -0.025004908442497253, -0.008682426996529102, -0.005742086563259363, -0.0066453381441533566, 0.018662428483366966, -0.009736650623381138, 0.017637360841035843, 0.02687416598200798, -0.005792131181806326, -0.013443457894027233, 0.024120735004544258, -0.07954543828964233, -0.004518370609730482, -0.007015372160822153, -0.015389800071716309, -0.012866000644862652, 0.07482243329286575, -0.02744741179049015, -0.022217046469449997, 0.035730984061956406, -0.05857351794838905, -0.0028524380177259445, -0.08946485817432404, -0.012824542820453644, -0.042367663234472275, -0.018664423376321793, 0.07306218892335892, -0.0038246139883995056, 0.015285339206457138, 0.04207823798060417, -0.0030370315071195364, 0.023610539734363556, 0.0020897802896797657, 0.0020841786172240973, 0.030415799468755722, 0.004258369095623493, -0.009462839923799038, 0.0003052265092264861, -0.04200147092342377, 0.02382652647793293, 0.059518735855817795, 0.07591906934976578, 0.015517780557274818, -0.03647559508681297, 0.022244635969400406, 0.007905763573944569, 0.030057182535529137, 0.11699497699737549, 0.02339625358581543, 0.03764987364411354, 0.03151540830731392, -0.01647624745965004, -0.03227270767092705, 0.033073414117097855, -0.017917770892381668, 0.0011264880886301398, 0.01841544918715954, 0.06764961034059525, -0.024611087515950203, 0.02281305566430092, 0.053826551884412766, -0.010485445149242878, 0.015841497108340263, -0.008118060417473316, -0.02824249304831028, 0.023525990545749664, 0.06062735244631767, -0.00714122224599123, -0.012619911693036556, 0.016636166721582413, -0.01758069358766079, -0.008170383982360363, 0.08669912070035934, 0.003097425913438201, -0.012620905414223671, -0.0029095385689288378, -0.04291251301765442, -0.06916367262601852, -0.005944901145994663, 0.03667082637548447, -0.0005754227167926729, 0.018031904473900795, -0.014113940298557281, 0.037694402039051056, -0.03289522975683212, -0.048070602118968964, 0.021466828882694244, -0.06671406328678131,  ...
#  'metadata': {'b674578d-347c-48ad-a659-4b24c0a6dead': {'page_label': '36',
#    'file_name': 'Google_10-K_2022.pdf',
#    'file_path': '/home/jupyter/llama_index/llama-index-integrations/vector_stores/llama-index-vector-stores-vertexaivectorsearch/tests/data/Google_10-K_2022.pdf',
#    'file_type': 'application/pdf',
#    'file_size': 4006440,
#    'creation_date': '2024-04-26',
#    'last_modified_date': '2024-04-26'},
#   '8498cc70-b223-4d9a-82b7-e9f7c6aa1b1d': {'page_label': '30',
#    'file_name': 'Google_10-K_2022.pdf',
#    'file_path': '/home/jupyter/llama_index/llama-index-integrations/vector_stores/llama-index-vector-stores-vertexaivectorsearch/tests/data/Google_10-K_2022.pdf',
#    'file_type': 'application/pdf',
#    'file_size': 4006440,
#    'creation_date': '2024-04-26',
#    'last_modified_date': '2024-04-26'}},
#  '__pydantic_initialised__': True}

# %%
vector_response.metadata
# Out:
# {'7efb5bf2-5af0-432d-b18b-2a1702aadbbe': {'page_label': '16',
#   'file_name': 'Google_10-K_2022.pdf',
#   'file_path': '/home/jupyter/llama_index/llama-index-integrations/vector_stores/llama-index-vector-stores-vertexaivectorsearch/tests/data/Google_10-K_2022.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 4006440,
#   'creation_date': '2024-04-26',
#   'last_modified_date': '2024-04-26'},
#  'bc6af642-d06f-4bec-aec3-4fee8329f18c': {'page_label': '12',
#   'file_name': 'Google_10-K_2022.pdf',
#   'file_path': '/home/jupyter/llama_index/llama-index-integrations/vector_stores/llama-index-vector-stores-vertexaivectorsearch/tests/data/Google_10-K_2022.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 4006440,
#   'creation_date': '2024-04-26',
#   'last_modified_date': '2024-04-26'}}

# %% [markdown]
# ---

# %%
# Delete datapoints from Vertex AI Vector Store
import json
from google.cloud import aiplatform_v1


def delete_from_matching_engine(vs_index, vs_endpoint, delete=False):
    neighbors = vs_endpoint.find_neighbors(
        deployed_index_id=vs_index.deployed_indexes[0].deployed_index_id,
        queries=[[0.0] * VS_DIMENSIONS],
        num_neighbors=5000,
        return_full_datapoint=True,
    )

    for neighbor in neighbors[0]:
        entry = {
            namespace.name: namespace.allow_tokens
            for namespace in neighbor.restricts
        }
        node_content = json.loads(entry["_node_content"][0])
        print(node_content["text"])

    datapoint_ids = [neighbor.id for neighbor in neighbors[0]]
    print(f"Deleting {len(datapoint_ids)} datapoints")

    # Delete datapoints
    if delete:
        response = vs_index.remove_datapoints(datapoint_ids=datapoint_ids)
        print(response)


delete_from_matching_engine(vs_index, vs_endpoint, delete=True)
# Out:
# A versatile pair of dark-wash denim jeans.Made from durable cotton with a classic straight-leg cut, these jeans transition easily from casual days to dressier occasions.
# A lightweight linen button-down shirt in a crisp white. Perfect for keeping cool with breathable fabric and a relaxed fit.
# A soft, chunky knit sweater in a vibrant forest green. The oversized fit and cozy wool blend make this ideal for staying warm when the temperature drops.
# A classic crewneck t-shirt in a soft, heathered blue. Made from comfortable cotton jersey, this t-shirt is a wardrobe essential that works for every season.
# A flowing midi-skirt in a delicate floral print. Lightweight and airy, this skirt adds a touch of feminine style to warmer days.
# A pair of tailored black trousers in a comfortable stretch fabric. Perfect for work or dressier events, these trousers provide a sleek, polished look.
# A cozy fleece hoodie in a neutral heather grey.  This relaxed sweatshirt is perfect for casual days or layering when the weather turns chilly.
# A bright yellow raincoat with a playful polka dot pattern. This waterproof jacket will keep you dry and add a touch of cheer to rainy days.
# A pair of comfortable khaki chino shorts. These versatile shorts are a summer staple, perfect for outdoor adventures or relaxed weekends.
# A bold red cocktail dress with a flattering A-line silhouette. This statement piece is made from a luxurious satin fabric, ensuring a head-turning look.
# A pair of classic white sneakers crafted from smooth leather. These timeless shoes offer a clean and polished look, perfect for everyday wear.
# A chunky cable-knit scarf in a rich burgundy color. Made from a soft wool blend, this scarf will provide warmth and a touch of classic style to cold-weather looks.
# A lightweight puffer vest in a vibrant teal hue. This versatile piece adds a layer of warmth without bulk, transitioning perfectly between seasons.
# A pair of high-waisted leggings in a sleek black. Crafted from a moisture-wicking fabric with plenty of stretch, these leggings are perfect for workouts or comfortable athleisure style.
# A denim jacket with a faded wash and distressed details. This wardrobe staple adds a touch of effortless cool to any outfit.
# A woven straw sunhat with a wide brim. This stylish accessory provides protection from the sun while adding a touch of summery elegance.
# A graphic tee featuring a vintage band logo. Made from a soft cotton blend, this casual tee adds a touch of personal style to everyday looks.
# A pair of well-tailored dress pants in a neutral grey. Made from a wrinkle-resistant blend, these pants look sharp and professional for workwear or formal occasions.
# A pair of classic leather ankle boots in a rich brown hue. Featuring a subtle stacked heel and sleek design, these boots are perfect for elevating outfits in cooler seasons.
# A vibrant swimsuit with a bold geometric pattern. This fun and eye-catching piece is perfect for making a splash by the pool or at the beach.
# A vibrant swimsuit with a bold geometric pattern. This fun and eye-catching piece is perfect for making a splash by the pool or at the beach.
# A vibrant swimsuit with a bold geometric pattern. This fun and eye-catching piece is perfect for making a splash by the pool or at the beach.
# Deleting 22 datapoints
# Removing datapoints MatchingEngineIndex index: projects/560224572293/locations/us-central1/indexes/6244298057953837056
# MatchingEngineIndex index Removed datapoints. Resource name: projects/560224572293/locations/us-central1/indexes/6244298057953837056
# <google.cloud.aiplatform.matching_engine.matching_engine_index.MatchingEngineIndex object at 0x7fcbf1d990c0>
# resource name: projects/560224572293/locations/us-central1/indexes/6244298057953837056

# %%
print(vs_endpoint.private_service_access_network)
print(vs_endpoint.public_endpoint_domain_name)
# Out:
# 1087190516.us-central1-560224572293.vdb.vertexai.goog

# %%
from google.cloud import aiplatform_v1

# Set variables for the current deployed index.
API_ENDPOINT = "1087190516.us-central1-560224572293.vdb.vertexai.goog"
INDEX_ENDPOINT = "projects/560224572293/locations/us-central1/indexEndpoints/151948108912132096"
DEPLOYED_INDEX_ID = "llamaindex_doc_index_425fae5a7fc2"

# Configure Vector Search client
client_options = {"api_endpoint": API_ENDPOINT}
vector_search_client = aiplatform_v1.MatchServiceClient(
    client_options=client_options,
)

# Build FindNeighborsRequest object
datapoint = aiplatform_v1.IndexDatapoint(
    datapoint_id="8b2faa25-0bcd-41b3-8612-b745b5a2adf1"
    # feature_vector=[]
)
query = aiplatform_v1.FindNeighborsRequest.Query(
    datapoint=datapoint,
    # The number of nearest neighbors to be retrieved
    neighbor_count=1,
)
request = aiplatform_v1.FindNeighborsRequest(
    index_endpoint=INDEX_ENDPOINT,
    deployed_index_id=DEPLOYED_INDEX_ID,
    # Request can have multiple queries
    queries=[query],
    return_full_datapoint=True,
)

# Execute the request
response = vector_search_client.find_neighbors(request)

# Handle the response
print(response)
# Out:
# nearest_neighbors {
#   id: "8b2faa25-0bcd-41b3-8612-b745b5a2adf1"
#   neighbors {
#     datapoint {
#       datapoint_id: "8b2faa25-0bcd-41b3-8612-b745b5a2adf1"
#       feature_vector: 0.0508964248
#       feature_vector: 0.000485334109
#       feature_vector: -0.0424281061
#       feature_vector: -0.0081797773
#       feature_vector: 0.0729037821
#       feature_vector: 0.0293532051
#       feature_vector: 0.0218644273
#       feature_vector: -0.020121431
#       feature_vector: 0.0132044675
#       feature_vector: 0.0502230786
#       feature_vector: -0.0423855744
#       feature_vector: 0.0398046114
#       feature_vector: -0.0360235535
#       feature_vector: 0.00263720495
#       feature_vector: -0.0220741685
#       feature_vector: -0.0560635589
#       feature_vector: 0.0160678215
#       feature_vector: 0.020458106
#       feature_vector: -0.000417721691
#       feature_vector: 0.0169399362
#       feature_vector: 0.0189459175
#       feature_vector: 0.00547863776
#       feature_vector: 0.000317752972
#       feature_vector: -0.0057523842
#       feature_vector: 0.0195931084
#       feature_vector: -0.0393329039
#       feature_vector: 0.0109905489
#       feature_vector: -0.0450932868
#       feature_vector: -0.0163816977
#       feature_vector: -0.00501167541
#       feature_vector: -0.0335044973
#       feature_vector: 0.0175368022
#       feature_vector: 0.00525935134
#       feature_vector: -0.00153115345
#       feature_vector: 0.00913059
#       feature_vector: -0.0598171614
#       feature_vector: -0.0137166344
#       feature_vector: 0.0347078107
#       feature_vector: -0.0104172509
#       feature_vector: 0.0315494053
#       feature_vector: 0.016361434
#       feature_vector: -0.0670367107
#       feature_vector: -0.0518751033
#       feature_vector: 0.0275289696
#       feature_vector: -0.0252156015
#       feature_vector: 0.0625403449
#       feature_vector: -0.00258525833
#       feature_vector: -0.0280558169
#       feature_vector: 0.0169635378
#       feature_vector: -0.0646157041
#       feature_vector: 0.0230540689
#       feature_vector: 0.00180606765
#       feature_vector: 0.0466803275
#       feature_vector: -0.0262025539
#       feature_vector: 0.0115740355
#       feature_vector: -0.0147480508
#       feature_vector: 0.0132557722
#       feature_vector: -0.0441964
#       feature_vector: 0.00125857221
#       feature_vector: 0.0135387778
#       feature_vector: -0.0187478457
#       feature_vector: 0.0306636821
#       feature_vector: 0.0255619418
#       feature_vector: -0.00814928487
#       feature_vector: 0.0250505563
#       feature_vector: -0.0593909733
#       feature_vector: -0.0083509
#       feature_vector: 0.00655669253
#       feature_vector: 0.0675700232
#       feature_vector: -0.0276052039
#       feature_vector: -0.0194347668
#       feature_vector: 0.0166919623
#       feature_vector: 0.0132042328
#       feature_vector: -0.00104123028
#       feature_vector: 0.0464717411
#       feature_vector: -0.0857175663
#       feature_vector: -0.0224965625
#       feature_vector: 0.0635944232
#       feature_vector: 0.0527743511
#       feature_vector: 0.00466805324
#       feature_vector: 0.0215831157
#       feature_vector: -0.0511774868
#       feature_vector: -0.0514258221
#       feature_vector: -0.0428984314
#       feature_vector: -0.0383584686
#       feature_vector: 0.00963745266
#       feature_vector: 0.00493877
#       feature_vector: -0.0169246085
#       feature_vector: 0.0234114919
#       feature_vector: 0.0370818116
#       feature_vector: -0.0477819256
#       feature_vector: -0.0256836582
#       feature_vector: 0.0525930934
#       feature_vector: -0.0529118404
#       feature_vector: -0.0226670131
#       feature_vector: 0.0976443738
#       feature_vector: -0.0378119536
#       feature_vector: -0.00222134171
#       feature_vector: 0.0354154184
#       feature_vector: -0.0547052622
#       feature_vector: 0.0471131951
#       feature_vector: 0.000306217436
#       feature_vector: -0.0107412944
#       feature_vector: -0.00829376839
#       feature_vector: 0.0304385107
#       feature_vector: -0.0119641759
#       feature_vector: 0.0292071905
#       feature_vector: 0.0109756393
#       feature_vector: 0.00128742633
#       feature_vector: 0.0210705325
#       feature_vector: -0.00732790539
#       feature_vector: -0.00411503343
#       feature_vector: 0.0218173675
#       feature_vector: -0.0273152199
#       feature_vector: 0.0303851664
#       feature_vector: -7.79723487e-05
#       feature_vector: 0.0713396296
#       feature_vector: 0.100091204
#       feature_vector: 0.065474622
#       feature_vector: 0.082291387
#       feature_vector: 0.0187601186
#       feature_vector: -0.0602604039
#       feature_vector: 0.0832964554
#       feature_vector: -0.0207612645
#       feature_vector: 2.4570234e-05
#       feature_vector: -0.0374276154
#       feature_vector: 0.0337835737
#       feature_vector: 0.00188989053
#       feature_vector: 0.026558267
#       feature_vector: -0.0140621224
#       feature_vector: -0.0363427438
#       feature_vector: -0.0558081828
#       feature_vector: -0.0213586148
#       feature_vector: 0.0309765041
#       feature_vector: 0.0464129746
#       feature_vector: 0.0939536765
#       feature_vector: 0.0550796762
#       feature_vector: -0.0253383275
#       feature_vector: 0.0141501622
#       feature_vector: -0.0558621734
#       feature_vector: -0.0147169326
#       feature_vector: 0.0208048671
#       feature_vector: -0.0131292092
#       feature_vector: 0.024558207
#       feature_vector: -0.00410962477
#       feature_vector: 0.0510134362
#       feature_vector: -0.0663889647
#       feature_vector: 0.0148649281
#       feature_vector: 0.0302727018
#       feature_vector: -0.00607024552
#       feature_vector: 0.0168072786
#       feature_vector: 0.0150665231
#       feature_vector: -0.0344859026
#       feature_vector: 0.0364693217
#       feature_vector: 0.0462825857
#       feature_vector: 0.0134955365
#       feature_vector: -0.00375270098
#       feature_vector: 0.0127133
#       feature_vector: -0.00127291598
#       feature_vector: 0.0435031392
#       feature_vector: 0.0420882776
#       feature_vector: -0.0555553734
#       feature_vector: 0.024477087
#       feature_vector: 0.0407073535
#       feature_vector: -0.0244432222
#       feature_vector: -0.034248963
#       feature_vector: 0.00496363407
#       feature_vector: -0.0307140741
#       feature_vector: 0.00330773927
#       feature_vector: -0.00361134415
#       feature_vector: -0.017757345
#       feature_vector: 0.073599264
#       feature_vector: -0.0400562733
#       feature_vector: -0.038585104
#       feature_vector: 0.024300592
#       feature_vector: 0.00147010991
#       feature_vector: 0.0268943626
#       feature_vector: 0.0126754399
#       feature_vector: -0.0211784765
#       feature_vector: -0.053120397
#       feature_vector: -0.0144075146
#       feature_vector: -0.036006961
#       feature_vector: 0.0174138956
#       feature_vector: 0.00379516836
#       feature_vector: 0.0258335732
#       feature_vector: -0.0358642973
#       feature_vector: 0.0657896921
#       feature_vector: 0.00819039159
#       feature_vector: 0.00673357444
#       feature_vector: 0.0722577274
#       feature_vector: 0.00441304827
#       feature_vector: 0.0237010568
#       feature_vector: -0.0482280888
#       feature_vector: -0.00619232142
#       feature_vector: -0.0657232255
#       feature_vector: 0.0401175357
#       feature_vector: 0.00523446733
#       feature_vector: 0.0569768324
#       feature_vector: 1.5755897e-05
#       feature_vector: -0.0451862738
#       feature_vector: -0.0448503122
#       feature_vector: 0.0843356624
#       feature_vector: -0.0102829225
#       feature_vector: 0.0287984535
#       feature_vector: 0.0197475739
#       feature_vector: 0.0236278176
#       feature_vector: 0.031724602
#       feature_vector: -0.0224128272
#       feature_vector: -0.000649730733
#       feature_vector: 0.0362993032
#       feature_vector: 0.00405435683
#       feature_vector: 0.0429935232
#       feature_vector: 0.022491226
#       feature_vector: 0.0204293132
#       feature_vector: 0.0578680709
#       feature_vector: -0.0185074452
#       feature_vector: 0.0365986675
#       feature_vector: 0.0249846391
#       feature_vector: -0.0202485323
#       feature_vector: 0.00344054122
#       feature_vector: 0.000836867839
#       feature_vector: 0.0142178666
#       feature_vector: -0.0429653898
#       feature_vector: -0.0161053538
#       feature_vector: -0.00713328039
#       feature_vector: 0.0268330686
#       feature_vector: -0.0526115559
#       feature_vector: -0.0224432759
#       feature_vector: 0.0352338701
#       feature_vector: -0.0594135448
#       feature_vector: -0.00139787281
#       feature_vector: 0.0754824728
#       feature_vector: 0.0133867655
#       feature_vector: 0.0134673575
#       feature_vector: 0.0758622
#       feature_vector: -0.0304956902
#       feature_vector: 0.0177504551
#       feature_vector: 0.0497067831
#       feature_vector: 0.0706522688
#       feature_vector: 0.0396650396
#       feature_vector: -0.0570098236
#       feature_vector: 0.036307849
#       feature_vector: -0.00183778279
#       feature_vector: 0.0203624498
#       feature_vector: -0.0829427093
#       feature_vector: -0.0488722436
#       feature_vector: -0.0271316264
#       feature_vector: 0.067693
#       feature_vector: 0.0390423648
#       feature_vector: 0.026312137
#       feature_vector: -0.00634204037
#       feature_vector: -0.0232414287
#       feature_vector: -0.0371452272
#       feature_vector: 0.0424713045
#       feature_vector: -0.0619517341
#       feature_vector: 0.0191002153
#       feature_vector: -0.090849027
#       feature_vector: 0.0158161893
#       feature_vector: -0.0865538046
#       feature_vector: -0.0112213586
#       feature_vector: 0.0623447411
#       feature_vector: 0.057523381
#       feature_vector: 0.0369787738
#       feature_vector: 0.000925208849
#       feature_vector: -0.0112550296
#       feature_vector: 0.0190115944
#       feature_vector: 0.0276432745
#       feature_vector: -0.0890969783
#       feature_vector: -0.0235566013
#       feature_vector: -0.00347058591
#       feature_vector: -0.00802281592
#       feature_vector: 0.0193539113
#       feature_vector: 0.0515753627
#       feature_vector: 0.0220100153
#       feature_vector: -0.00399183761
#       feature_vector: 0.0368575305
#       feature_vector: 0.000527312804
#       feature_vector: 0.0166736245
#       feature_vector: 0.00392826134
#       feature_vector: -0.0244827569
#       feature_vector: -0.00549937319
#       feature_vector: 0.0164576527
#       feature_vector: 0.0356748328
#       feature_vector: -0.0196952038
#       feature_vector: -0.00989819784
#       feature_vector: -0.0114651928
#       feature_vector: -0.0257645678
#       feature_vector: -0.0269799288
#       feature_vector: -0.0514047742
#       feature_vector: -0.0664303154
#       feature_vector: 0.0104048541
#       feature_vector: -0.0237438641
#       feature_vector: 0.00393757923
#       feature_vector: -0.0303357486
#       feature_vector: -0.0070403181
#       feature_vector: -0.0135953035
#       feature_vector: -0.00745111238
#       feature_vector: 0.0798886865
#       feature_vector: -0.0215105712
#       feature_vector: -0.0358166136
#       feature_vector: -0.0185989235
#       feature_vector: -0.0809528604
#       feature_vector: 0.0369411111
#       feature_vector: -0.050266955
#       feature_vector: -0.0219082925
#       feature_vector: 0.035320811
#       feature_vector: -0.0346701518
#       feature_vector: -0.0237359107
#       feature_vector: 0.0555037
#       feature_vector: -0.00254316558
#       feature_vector: 0.00169117935
#       feature_vector: -0.0259025767
#       feature_vector: -0.0585469194
#       feature_vector: -0.020256348
#       feature_vector: 0.0918944553
#       feature_vector: 0.0316468738
#       feature_vector: -0.024011761
#       feature_vector: 0.0472243205
#       feature_vector: -0.0309516601
#       feature_vector: 0.0519524366
#       feature_vector: 0.023743324
#       feature_vector: 0.0418458544
#       feature_vector: 0.0131076425
#       feature_vector: -0.00622718129
#       feature_vector: -0.00454204669
#       feature_vector: 0.0112179983
#       feature_vector: -0.0142983915
#       feature_vector: 0.047457397
#       feature_vector: -0.0460609794
#       feature_vector: -0.00779812783
#       feature_vector: 0.0087515926
#       feature_vector: 0.00773522723
#       feature_vector: -0.0167238526
#       feature_vector: -0.0187536962
#       feature_vector: 0.0315007642
#       feature_vector: 0.0106034167
#       feature_vector: -0.084125571
#       feature_vector: -0.0303887706
#       feature_vector: -0.0317676365
#       feature_vector: -0.0249069706
#       feature_vector: -0.0464300923
#       feature_vector: 0.0101484647
#       feature_vector: -0.0487333648
#       feature_vector: -0.0681055114
#       feature_vector: -0.007438384
#       feature_vector: -0.0324303806
#       feature_vector: -0.0248251
#       feature_vector: 0.0347247198
#       feature_vector: 0.0759606063
#       feature_vector: 0.0564904921
#       feature_vector: 0.00225048047
#       feature_vector: 0.0695025399
#       feature_vector: 0.0144183971
#       feature_vector: 0.00229164679
#       feature_vector: -0.0347779542
#       feature_vector: -0.032356441
#       feature_vector: 0.066796124
#       feature_vector: -0.0160357673
#       feature_vector: 0.033015985
#       feature_vector: -0.0143048279
#       feature_vector: 0.00804070476
#       feature_vector: 0.0262988079
#       feature_vector: -0.0102855032
#       feature_vector: -0.0301082153
#       feature_vector: 0.00780632533
#       feature_vector: 0.0184899569
#       feature_vector: -0.00380031206
#       feature_vector: 0.031591814
#       feature_vector: -0.0431949943
#       feature_vector: 0.00725987367
#       feature_vector: 0.00243485905
#       feature_vector: -0.0153597174
#       feature_vector: 0.0322413072
#       feature_vector: -0.00839771
#       feature_vector: 0.0440010354
#       feature_vector: 0.0180399958
#       feature_vector: -0.0388218276
#       feature_vector: -0.0192180444
#       feature_vector: 0.0222914349
#       feature_vector: -0.0125607988
#       feature_vector: 0.00285464
#       feature_vector: 0.0026492679
#       feature_vector: 0.0274636447
#       feature_vector: 0.0160706975
#       feature_vector: 0.00362129114
#       feature_vector: 0.0240540411
#       feature_vector: 0.0443851948
#       feature_vector: 0.0541292019
#       feature_vector: -0.0426909812
#       feature_vector: 0.017737817
#       feature_vector: -0.0675631836
#       feature_vector: 0.0164061282
#       feature_vector: 0.108256862
#       feature_vector: 0.0232660435
#       feature_vector: 0.0106622716
#       feature_vector: 0.00407094276
#       feature_vector: -0.0512695312
#       feature_vector: -0.034631189
#       feature_vector: 0.0406892523
#       feature_vector: -0.0224263277
#       feature_vector: -0.0407796055
#       feature_vector: -0.06298884
#       feature_vector: -0.0512955822
#       feature_vector: -0.0121062314
#       feature_vector: -0.0552273691
#       feature_vector: -0.00403196877
#       feature_vector: 0.0179789625
#       feature_vector: -0.0287371334
#       feature_vector: -0.0389522128
#       feature_vector: -0.0120876897
#       feature_vector: 0.0302046556
#       feature_vector: 0.0300728381
#       feature_vector: 0.0231879428
#       feature_vector: -0.0892720595
#       feature_vector: -0.0253579505
#       feature_vector: 0.0187672097
#       feature_vector: 0.00658817
#       feature_vector: -0.000442352786
#       feature_vector: -0.0102303848
#       feature_vector: 0.00683814753
#       feature_vector: -0.0189007297
#       feature_vector: 0.00770106912
#       feature_vector: -0.00520033669
#       feature_vector: -0.0166225471
#       feature_vector: -0.0294634867
#       feature_vector: 0.0012945421
#       feature_vector: 0.036906939
#       feature_vector: -0.0304781795
#       feature_vector: -0.00922803488
#       feature_vector: 0.0281073488
#       feature_vector: 0.0466096811
#       feature_vector: 0.0160606056
#       feature_vector: 0.0100029083
#       feature_vector: -0.0259117279
#       feature_vector: 0.00992669351
#       feature_vector: -0.0563504435
#       feature_vector: 0.0199495107
#       feature_vector: 0.055576507
#       feature_vector: -0.00861813594
#       feature_vector: 0.0225135796
#       feature_vector: 0.03906307
#       feature_vector: -0.0270871092
#       feature_vector: 0.00462908251
#       feature_vector: -0.0145239579
#       feature_vector: -0.00330432528
#       feature_vector: -0.0233458187
#       feature_vector: -0.0429940708
#       feature_vector: -0.00173146359
#       feature_vector: 0.00108068623
#       feature_vector: -0.0806565806
#       feature_vector: 0.0100165168
#       feature_vector: -0.0325228237
#       feature_vector: 0.00816011056
#       feature_vector: -0.0511882864
#       feature_vector: -0.0324748717
#       feature_vector: -0.0216137022
#       feature_vector: 0.00115468435
#       feature_vector: 0.0536679
#       feature_vector: -0.00276306598
#       feature_vector: -0.0382932909
#       feature_vector: 0.0696493685
#       feature_vector: -0.0101010213
#       feature_vector: -0.0170914158
#       feature_vector: -0.0543309338
#       feature_vector: 0.061614003
#       feature_vector: -0.00620174734
#       feature_vector: 0.00440294435
#       feature_vector: 0.0231447723
#       feature_vector: -0.0252825692
#       feature_vector: 0.00391828688
#       feature_vector: -0.0250477493
#       feature_vector: -0.00947822165
#       feature_vector: -0.0561096221
#       feature_vector: -0.0485418662
#       feature_vector: -0.0351932496
#       feature_vector: 0.0167889576
#       feature_vector: -0.0872312114
#       feature_vector: -0.0378564857
#       feature_vector: -0.0112021491
#       feature_vector: -0.0317581147
#       feature_vector: -0.0332543924
#       feature_vector: 0.0269239619
#       feature_vector: 0.043281123
#       feature_vector: 0.0139205661
#       feature_vector: -0.02171476
#       feature_vector: -0.0054238732
#       feature_vector: 0.00667525735
#       feature_vector: -0.0182672217
#       feature_vector: -0.0841803253
#       feature_vector: 0.0677052215
#       feature_vector: 0.0158056989
#       feature_vector: -0.0358703174
#       feature_vector: -0.0356377922
#       feature_vector: -0.0340020172
#       feature_vector: 0.00489126612
#       feature_vector: -0.00573862437
#       feature_vector: 0.0127335908
#       feature_vector: 0.0100819096
#       feature_vector: 0.00602424564
#       feature_vector: 0.0471030325
#       feature_vector: -0.0238668509
#       feature_vector: 0.011484297
#       feature_vector: 0.0463524573
#       feature_vector: 0.0312031657
#       feature_vector: 0.0449738726
#       feature_vector: -0.0725621656
#       feature_vector: -0.0152250966
#       feature_vector: 0.0394528583
#       feature_vector: -0.00399636198
#       feature_vector: 0.00388073502
#       feature_vector: -0.00297612441
#       feature_vector: 0.0451312326
#       feature_vector: -0.0175111219
#       feature_vector: 0.0396323167
#       feature_vector: 0.0431898534
#       feature_vector: -0.0465502515
#       feature_vector: -0.0194950253
#       feature_vector: -0.0615116917
#       feature_vector: 0.0165037774
#       feature_vector: -0.00966097
#       feature_vector: -0.0153560778
#       feature_vector: -0.0231548343
#       feature_vector: -0.0888042822
#       feature_vector: -0.0174730364
#       feature_vector: 0.016149383
#       feature_vector: -0.00859027728
#       feature_vector: 0.0091537917
#       feature_vector: 0.0221186932
#       feature_vector: -0.0227431934
#       feature_vector: 0.0461092256
#       feature_vector: -0.0302553233
#       feature_vector: 0.0547043
#       feature_vector: -0.0642558709
#       feature_vector: -0.0361712575
#       feature_vector: 0.00177909434
#       feature_vector: 0.00141439366
#       feature_vector: 0.0110594863
#       feature_vector: 0.0474383496
#       feature_vector: -0.0380532742
#       feature_vector: 0.00734097231
#       feature_vector: 0.0801530108
#       feature_vector: -0.0326775797
#       feature_vector: 0.0415346958
#       feature_vector: 0.0411406606
#       feature_vector: -0.0264937785
#       feature_vector: 0.00577107444
#       feature_vector: -0.00786910672
#       feature_vector: -0.061211098
#       feature_vector: 0.0112614362
#       feature_vector: 0.0120280813
#       feature_vector: -0.0124676879
#       feature_vector: 0.032494653
#       feature_vector: 0.02858527
#       feature_vector: -0.0263348799
#       feature_vector: -0.00752653228
#       feature_vector: -0.0242437776
#       feature_vector: -0.0204051808
#       feature_vector: -0.0351859778
#       feature_vector: 0.0571752451
#       feature_vector: -0.047804933
#       feature_vector: -0.0168855693
#       feature_vector: -0.0286633149
#       feature_vector: -0.0498724654
#       feature_vector: 0.025650084
#       feature_vector: 0.0862858593
#       feature_vector: -0.00751584815
#       feature_vector: 0.0183869191
#       feature_vector: 0.006434
#       feature_vector: 0.0970353186
#       feature_vector: -0.0256909877
#       feature_vector: 0.0135759059
#       feature_vector: -0.00844697468
#       feature_vector: 0.0351584889
#       feature_vector: -0.0424946025
#       feature_vector: 0.0492749773
#       feature_vector: 0.000994596398
#       feature_vector: -0.0390966833
#       feature_vector: -0.0413410254
#       feature_vector: -0.0491062514
#       feature_vector: 0.0055533275
#       feature_vector: 0.0545394
#       feature_vector: -0.00540183112
#       feature_vector: 0.0147461463
#       feature_vector: 0.050033398
#       feature_vector: -0.0663239509
#       feature_vector: -0.0276903417
#       feature_vector: 0.0443453118
#       feature_vector: 0.0386193171
#       feature_vector: 0.00747094071
#       feature_vector: -0.00651664473
#       feature_vector: -0.0829519257
#       feature_vector: 0.0193346888
#       feature_vector: 6.00565545e-05
#       feature_vector: -0.0246131923
#       feature_vector: -0.0210532267
#       feature_vector: -0.00961782224
#       feature_vector: 0.0367855094
#       feature_vector: -0.0283525884
#       feature_vector: 0.00370232854
#       feature_vector: -0.0737344399
#       feature_vector: -0.0197484102
#       feature_vector: -0.0680178776
#       feature_vector: 0.0377677903
#       feature_vector: -0.0158290695
#       feature_vector: 0.0729014799
#       feature_vector: 0.0317268856
#       feature_vector: 0.0198595989
#       feature_vector: -0.0291422233
#       feature_vector: 0.030025648
#       feature_vector: 0.0161328763
#       feature_vector: -0.00846381672
#       feature_vector: -0.0392731689
#       feature_vector: -0.0363579132
#       feature_vector: -0.000191285202
#       feature_vector: -0.0151823787
#       feature_vector: -0.0147520341
#       feature_vector: 0.0821068361
#       feature_vector: 0.0407376215
#       feature_vector: 0.017477354
#       feature_vector: -0.00935247261
#       feature_vector: -0.010060274
#       feature_vector: 0.00274207746
#       feature_vector: 0.0376296
#       feature_vector: -0.0200000554
#       feature_vector: -0.00675521
#       feature_vector: 0.011485544
#       feature_vector: -0.0555594712
#       feature_vector: -0.0331218876
#       feature_vector: 0.0558875762
#       feature_vector: 0.0352811143
#       feature_vector: 0.0802440494
#       feature_vector: 0.011842411
#       feature_vector: -0.0426892117
#       feature_vector: 0.0219933484
#       feature_vector: -0.0230714511
#       feature_vector: -0.00522431033
#       feature_vector: -0.0368131325
#       feature_vector: 0.0109048523
#       feature_vector: 0.0249694474
#       feature_vector: -0.0244176108
#       feature_vector: -0.0490908027
#       feature_vector: 0.00283477269
#       feature_vector: -0.0184345953
#       feature_vector: 0.00372842979
#       feature_vector: -0.0354348421
#       feature_vector: 0.0469005853
#       feature_vector: -0.00167166803
#       feature_vector: -0.0641864464
#       feature_vector: 0.00811168645
#       feature_vector: 0.0195310488
#       feature_vector: -0.0628219247
#       feature_vector: 0.0416200571
#       feature_vector: -0.0439157039
#       feature_vector: 0.0140322903
#       feature_vector: 0.0167362485
#       feature_vector: -0.010803761
#       feature_vector: -0.00826834049
#       feature_vector: -0.0578001887
#       feature_vector: 0.0583732165
#       feature_vector: -0.0377503857
#       feature_vector: -0.0537979789
#       feature_vector: 0.0273148417
#       feature_vector: -0.0135127846
#       feature_vector: 0.0135827353
#       feature_vector: 0.0244931187
#       feature_vector: 0.00412566774
#       feature_vector: -0.0726405904
#       feature_vector: -0.105242252
#       feature_vector: 0.0194858126
#       feature_vector: 0.00498853112
#       feature_vector: -0.0484015457
#       feature_vector: -0.0069662584
#       feature_vector: 0.0509582125
#       feature_vector: -0.016985165
#       feature_vector: 0.0328233503
#       feature_vector: 0.00688468106
#       feature_vector: -0.0106564555
#       feature_vector: 0.0348024592
#       feature_vector: -0.00929780491
#       feature_vector: 0.0424803384
#       feature_vector: -0.0183391031
#       feature_vector: 0.000735647569
#       feature_vector: -0.0347410776
#       feature_vector: 0.00377039309
#       feature_vector: -0.0195153337
#       feature_vector: 0.0587559603
#       feature_vector: 0.0652219877
#       feature_vector: -0.0139229344
#       feature_vector: -0.00611029193
#       feature_vector: -0.0400254317
#       feature_vector: 0.0026693386
#       feature_vector: 0.00656330725
#       feature_vector: -0.0180532243
#       feature_vector: 0.0201376919
#       feature_vector: 0.0458685
#       feature_vector: 0.0129028009
#       feature_vector: -0.0348583385
#       feature_vector: -0.0185584892
#       feature_vector: -0.041535262
#       feature_vector: 0.0318128
#       feature_vector: 0.00851958897
#       feature_vector: -0.03266434
#       feature_vector: 0.0103473887
#       feature_vector: 0.0319339372
#       feature_vector: -0.015564614
#       feature_vector: -0.0155017013
#       feature_vector: 0.0238044411
#       feature_vector: 0.0430836752
#       feature_vector: 0.0517675877
#       feature_vector: 0.0490593649
#       feature_vector: 0.0300754905
#       feature_vector: -0.0187465232
#       feature_vector: -0.0485833
#       feature_vector: 0.0146200489
#       feature_vector: 0.0123166842
#       feature_vector: -0.0625100061
#       feature_vector: -0.0181691051
#       feature_vector: 0.0213836897
#       feature_vector: -0.0225533042
#       feature_vector: 0.0457213856
#       feature_vector: 0.00990800932
#       feature_vector: 0.0261601396
#       feature_vector: 0.0131018758
#       feature_vector: -0.0163577721
#       feature_vector: -0.0105432384
#       feature_vector: 0.0598029532
#       feature_vector: -0.0623394772
#       feature_vector: 0.000573095749
#       feature_vector: -0.0317618176
#       feature_vector: -0.00683973823
#       feature_vector: 0.0516207069
#       feature_vector: -0.0297677852
#       feature_vector: -0.00308589474
#       feature_vector: -0.0370598957
#       feature_vector: -0.017428156
#       feature_vector: 0.0881620497
#       feature_vector: 0.0107406834
#       feature_vector: 0.0141688781
#       feature_vector: -0.0262218043
#       feature_vector: -0.0430217758
#       feature_vector: -0.0519321784
#       feature_vector: -0.0238082595
#       feature_vector: -0.00969263446
#       feature_vector: 0.0336211547
#       feature_vector: 0.0246073902
#       feature_vector: -0.0251361299
#       feature_vector: 0.0228342842
#       feature_vector: -0.0207105801
#       feature_vector: 0.0288508907
#       feature_vector: -0.0449636281
#       feature_vector: -0.0243349485
#       feature_vector: 0.0127804922
#       feature_vector: -0.013277391
#       feature_vector: 0.0541404188
#       feature_vector: 0.00856047
#       feature_vector: 0.0298160966
#       feature_vector: 0.00935114454
#       feature_vector: -0.0323214978
#       feature_vector: 0.0149558159
#       feature_vector: 0.0192946978
#       feature_vector: -0.00148828269
#       feature_vector: -0.0231577791
#       feature_vector: -0.0217727572
#       feature_vector: -0.0189397614
#       feature_vector: 0.0279235616
#       feature_vector: 0.0335315168
#       feature_vector: -0.0450924374
#       feature_vector: -0.0153729077
#       restricts {
#         namespace: "color"
#         allow_list: "multicolor"
#       }
#       restricts {
#         namespace: "season"
#         allow_list: "summer"
#       }
#       restricts {
#         namespace: "_node_content"
#         allow_list: "{\"id_\": \"8b2faa25-0bcd-41b3-8612-b745b5a2adf1\", \"embedding\": null, \"metadata\": {\"color\": \"multicolor\", \"price\": 55.0, \"season\": [\"summer\"]}, \"excluded_embed_metadata_keys\": [], \"excluded_llm_metadata_keys\": [], \"relationships\": {\"1\": {\"node_id\": \"e7f7b237-cc43-594c-69d2-ff9fc297c3b7\", \"node_type\": \"4\", \"metadata\": {\"color\": \"multicolor\", \"price\": 55.0, \"season\": [\"summer\"]}, \"hash\": \"3d189aaa8949b328ec80c8ff70db09c34e36a15c02856e10f4bd67b728776be9\", \"class_name\": \"RelatedNodeInfo\"}}, \"text\": \"A vibrant swimsuit with a bold geometric pattern. This fun and eye-catching piece is perfect for making a splash by the pool or at the beach.\", \"start_char_idx\": 0, \"end_char_idx\": 141, \"text_template\": \"{metadata_str}\\n\\n{content}\", \"metadata_template\": \"{key}: {value}\", \"metadata_seperator\": \"\\n\", \"class_name\": \"TextNode\"}"
#       }
#       restricts {
#         namespace: "_node_type"
#         allow_list: "TextNode"
#       }
#       restricts {
#         namespace: "document_id"
#         allow_list: "e7f7b237-cc43-594c-69d2-ff9fc297c3b7"
#       }
#       restricts {
#         namespace: "doc_id"
#         allow_list: "e7f7b237-cc43-594c-69d2-ff9fc297c3b7"
#       }
#       restricts {
#         namespace: "ref_doc_id"
#         allow_list: "e7f7b237-cc43-594c-69d2-ff9fc297c3b7"
#       }
#       numeric_restricts {
#         value_float: 55
#         namespace: "price"
#       }
#       crowding_tag {
#         crowding_attribute: "0"
#       }
#     }
#     distance: 0.999998152256012
#   }
# }

# %%
from llama_index.vector_stores.vertexaivectorsearch.utils import get_datapoint

result = get_datapoint(
    vs_index, vs_endpoint, "5dd452b3-5eee-412c-aaad-129fb7efb577"
)
len(result.nearest_neighbors)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/llama-index-vector-stores-vertexaivectorse-fOlz0BPR-py3.10/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File ~/.cache/pypoetry/virtualenvs/llama-index-vector-stores-vertexaivectorse-fOlz0BPR-py3.10/lib/python3.10/site-packages/grpc/_channel.py:1176, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 (
#    1171     state,
#    1172     call,
#    1173 ) = self._blocking(
#    1174     request, timeout, metadata, credentials, wait_for_ready, compression
#    1175 )
# -> 1176 return _end_unary_response_blocking(state, call, False, None)
#
# File ~/.cache/pypoetry/virtualenvs/llama-index-vector-stores-vertexaivectorse-fOlz0BPR-py3.10/lib/python3.10/site-packages/grpc/_channel.py:1005, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1004 else:
# -> 1005     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.NOT_FOUND
# 	details = "5dd452b3-5eee-412c-aaad-129fb7efb577 entity does not exist in the dataset"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2024-04-30T00:42:29.056468063+00:00", grpc_status:5, grpc_message:"5dd452b3-5eee-412c-aaad-129fb7efb577 entity does not exist in the dataset"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# NotFound                                  Traceback (most recent call last)
# Cell In[64], line 3
#       1 from llama_index.vector_stores.vertexaivectorsearch.utils import get_datapoint
# ----> 3 result = get_datapoint(vs_index, vs_endpoint, "5dd452b3-5eee-412c-aaad-129fb7efb577")
#       4 len(result.nearest_neighbors)
#
# File ~/llama_index/llama-index-integrations/vector_stores/llama-index-vector-stores-vertexaivectorsearch/llama_index/vector_stores/vertexaivectorsearch/utils.py:382, in get_datapoint(index, endpoint, datapoint_id)
#     375 request = aip.FindNeighborsRequest(
#     376     index_endpoint=endpoint.resource_name,
#     377     deployed_index_id=_get_deployed_index_id(index, endpoint),
#     378     queries=[query],
#     379     return_full_datapoint=False)
#     381 # Execute the request and return the result
# --> 382 result = vector_search_client.find_neighbors(request)
#     383 return result
#
# File ~/.cache/pypoetry/virtualenvs/llama-index-vector-stores-vertexaivectorse-fOlz0BPR-py3.10/lib/python3.10/site-packages/google/cloud/aiplatform_v1/services/match_service/client.py:748, in MatchServiceClient.find_neighbors(self, request, retry, timeout, metadata)
#     745 self._validate_universe_domain()
#     747 # Send the request.
# --> 748 response = rpc(
#     749     request,
#     750     retry=retry,
#     751     timeout=timeout,
#     752     metadata=metadata,
#     753 )
#     755 # Done; return the response.
#     756 return response
#
# File ~/.cache/pypoetry/virtualenvs/llama-index-vector-stores-vertexaivectorse-fOlz0BPR-py3.10/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/llama-index-vector-stores-vertexaivectorse-fOlz0BPR-py3.10/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# NotFound: 404 5dd452b3-5eee-412c-aaad-129fb7efb577 entity does not exist in the dataset

# %%
metadata = {
    m.namespace: m.allow_list
    for m in response.nearest_neighbors[0].neighbors[0].datapoint.restricts
}
node_json = metadata.get("_node_content", None)
print(json.loads(node_json[0])["text"])
# Out:
# Table of Contents Alphabet Inc.
# Research and Development
# The following table presents R&D expenses (in millions, except percentages):
#  Year Ended December 31,
#  2021 2022
# Research and development expenses $ 31,562 $ 39,500
# Research and development expenses as a percentage of revenues 12 % 14 %
# R&D expenses increased $7.9 billion from 2021 to 2022 primarily driven by an increase in compensation expenses of
# $5.4 billion, largely resulting from a 21% increase in average headcount, and an increase in third-party service fees of
# $704 million.
# Sales and Marketing
# The following table presents sales and marketing expenses (in millions, except percentages):
#  Year Ended December 31,
#  2021 2022
# Sales and marketing expenses $ 22,912 $ 26,567
# Sales and marketing expenses as a percentage of revenues 9 % 9 %
# Sales and marketing expenses increased $3.7 billion from 2021 to 2022, primarily driven by an increase in
# compensation expenses of $1.8 billion, largely resulting from a 19% increase in average headcount, and an increase in
# advertising and promotional activities of $1.3 billion.
# General and Administrative
# The following table presents general and administrative expenses (in millions, except percentages):
#  Year Ended December 31,
#  2021 2022
# General and administrative expenses $ 13,510 $ 15,724
# General and administrative expenses as a percentage of revenues 5 % 6 %
# General and administrative expenses increased $2.2 billion from 2021 to 2022. The increase was primarily driven by
# an increase in compensation expenses of $1.1 billion, largely resulting from a 21% increase in average headcount, and an
# increase in third-party services fees of $815 million. In addition, there was a $551 million increase to the allowance for
# credit losses for accounts receivable, as the prior year comparable period reflected a decline in the allowance.
# Segment Profitability
# The following table presents segment operating income (loss) (in millions).
# Year Ended December 31,
# 2021 2022
# Operating income (loss):
# Google Services $ 91,855 $ 86,572
# Google Cloud (3,099) (2,968)
# Other Bets (5,281) (6,083)
# Corporate costs, unallocated (4,761) (2,679)
# Total income from operations $ 78,714 $ 74,842
# Unallocated corporate costs primarily include corporate initiatives, corporate shared costs, such as finance and legal, including
# certain fines and settlements, as well as costs associated with certain shared R&D activities. Additionally , hedging gains (losses)
# related to revenue are included in corporate costs and totaled $149 million and $2.0 billion in 2021 and 2022, respectively .
# Google Services
# Google Services operating income decreased $5.3 billion from 2021 to 2022. The decrease in operating income was
# primarily driven by increases in compensation expenses and TAC, partially offset by growth in revenues.(1)
# (1)
# 35

# %%
import json

node_json = [
    metadata.allow_list
    for metadata in response.nearest_neighbors[0]
    .neighbors[0]
    .datapoint.restricts
    if metadata.namespace == "_node_content"
][0][0]
json.loads(node_json)
type(node_json)
# Out:
# str

# %%
from llama_index.core.schema import TextNode

TextNode.from_json(node_json)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 from llama_index.core.schema import TextNode
# ----> 2 TextNode.from_json(node_json)
#
# File ~/.cache/pypoetry/virtualenvs/llama-index-vector-stores-vertexaivectorse-fOlz0BPR-py3.10/lib/python3.10/site-packages/llama_index/core/schema.py:115, in BaseComponent.from_json(cls, data_str, **kwargs)
#     113 @classmethod
#     114 def from_json(cls, data_str: str, **kwargs: Any) -> Self:  # type: ignore
# --> 115     data = json.loads(data_str)
#     116     return cls.from_dict(data, **kwargs)
#
# File /opt/conda/lib/python3.10/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not Repeated

# %%
import os

PROJECT_ID = os.getenv("PROJECT_ID", "")
REGION = os.getenv("REGION", "")
INDEX_ID = os.getenv("INDEX_ID", "")
ENDPOINT_ID = os.getenv("ENDPOINT_ID", "")
GCS_BUCKET_NAME = os.getenv("GCS_BUCKET_NAME", "")

print(f"PROJECT_ID={PROJECT_ID}")
print(f"REGION={LOCATION}")
print(f"INDEX_ID={vs_index.resource_name}")
print(f"ENDPOINT_ID={vs_endpoint.resource_name}")
print(f"GCS_BUCKET_NAME={GCS_BUCKET_NAME}")


def set_all_env_vars() -> bool:
    """Check if all required environment variables are set."""
    return all([PROJECT_ID, REGION, INDEX_ID, ENDPOINT_ID, GCS_BUCKET_NAME])


set_all_env_vars()
# Out:
# PROJECT_ID=
# REGION=us-central1
# INDEX_ID=projects/560224572293/locations/us-central1/indexes/6244298057953837056
# ENDPOINT_ID=projects/560224572293/locations/us-central1/indexEndpoints/151948108912132096
# GCS_BUCKET_NAME=
# False

# %%
os.environ["INDEX_ID"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 os.environ["INDEX_ID"]
#
# File /opt/conda/lib/python3.10/os.py:680, in _Environ.__getitem__(self, key)
#     677     value = self._data[self.encodekey(key)]
#     678 except KeyError:
#     679     # raise KeyError with the original key value
# --> 680     raise KeyError(key) from None
#     681 return self.decodevalue(value)
#
# KeyError: 'INDEX_ID'

# %%
print(f"PROJECT_ID={PROJECT_ID}")
print(f"REGION={LOCATION}")
print(f"INDEX_ID={vs_index.resource_name}")
print(f"ENDPOINT_ID={vs_endpoint.resource_name}")
print(f"GCS_BUCKET_NAME={GCS_BUCKET_NAME}")
# Out:
# PROJECT_ID=
# REGION=us-central1
# INDEX_ID=projects/560224572293/locations/us-central1/indexes/6244298057953837056
# ENDPOINT_ID=projects/560224572293/locations/us-central1/indexEndpoints/151948108912132096
# GCS_BUCKET_NAME=
