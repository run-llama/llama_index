# %% [markdown]
# # Oracle AI Vector Search: Vector Store
#
# Oracle AI Vector Search is designed for Artificial Intelligence (AI) workloads that allows you to query data based on semantics, rather than keywords.
# One of the biggest benefit of Oracle AI Vector Search is that semantic search on unstructured data can be combined with relational search on business data in one single system.
# This is not only powerful but also significantly more effective because you dont need to add a specialized vector database, eliminating the pain of data fragmentation between multiple systems.
#
# In addition, because Oracle has been building database technologies for so long, your vectors can benefit from all of Oracle Database's most powerful features, like the following:
#
#  * Partitioning Support
#  * Real Application Clusters scalability
#  * Exadata smart scans
#  * Shard processing across geographically distributed databases
#  * Transactions
#  * Parallel SQL
#  * Disaster recovery
#  * Security
#  * Oracle Machine Learning
#  * Oracle Graph Database
#  * Oracle Spatial and Graph
#  * Oracle Blockchain
#  * JSON

# %% [markdown]
# ### Prerequisites for using Langchain with Oracle AI Vector Search
#
# Please install Oracle Python Client driver to use Llama Index with Oracle AI Vector Search.

# %%
% pip install llama-index-vector-stores-oracledb
! pip install llama-index

# %% [markdown]
# ### Connect to Oracle AI Vector Search

# %%
import oracledb

username = "shailendra"
password = "shailendra"
dsn = "138.2.233.65:1521/freepdb1"

try:
    connection = oracledb.connect(user=username, password=password, dsn=dsn)
    print("Connection successful!")
except Exception as ex:
    print("Exception occurred while index creation", ex)
# Out:
# Connection successful!

# %% [markdown]
# ### Import the required dependencies to play with Oracle AI Vector Search

# %%
from llama_index.core.schema import NodeRelationship, RelatedNodeInfo, TextNode
from llama_index.core.vector_stores.types import (
    ExactMatchFilter,
    MetadataFilters,
    VectorStoreQuery,
)
from llama_index.vector_stores.oracledb import OraLlamaVS, orallamavs
from llama_index.vector_stores.oracledb import DistanceStrategy

# %% [markdown]
# ### Load Documents

# %%
# Define a list of documents (These dummy examples are 4 random documents )

text_json_list = [
    {
        "text": "If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.",
        "id_": "cncpt_15.5.3.2.2_P4",
        "embedding": [1.0, 0.0],
        "relationships": "test-0",
        "metadata": {
            "weight": 1.0,
            "rank": "a",
            "url": "https://docs.oracle.com/en/database/oracle/oracle-database/23/cncpt/logical-storage-structures.html#GUID-5387D7B2-C0CA-4C1E-811B-C7EB9B636442",
        },
    },
    {
        "text": "A tablespace can be online (accessible) or offline (not accessible) whenever the database is open.\nA tablespace is usually online so that its data is available to users. The SYSTEM tablespace and temporary tablespaces cannot be taken offline.",
        "id_": "cncpt_15.5.5_P1",
        "embedding": [0.0, 1.0],
        "relationships": "test-1",
        "metadata": {
            "weight": 2.0,
            "rank": "c",
            "url": "https://docs.oracle.com/en/database/oracle/oracle-database/23/cncpt/logical-storage-structures.html#GUID-D02B2220-E6F5-40D9-AFB5-BC69BCEF6CD4",
        },
    },
    {
        "text": "The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.",
        "id_": "cncpt_22.3.4.3.1_P2",
        "embedding": [1.0, 1.0],
        "relationships": "test-2",
        "metadata": {
            "weight": 3.0,
            "rank": "d",
            "url": "https://docs.oracle.com/en/database/oracle/oracle-database/23/cncpt/concepts-for-database-developers.html#GUID-3C50EAB8-FC39-4BB3-B680-4EACCE49E866",
        },
    },
    {
        "text": "The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.",
        "id_": "cncpt_22.3.4.3.1_P3",
        "embedding": [2.0, 1.0],
        "relationships": "test-3",
        "metadata": {
            "weight": 4.0,
            "rank": "e",
            "url": "https://docs.oracle.com/en/database/oracle/oracle-database/23/cncpt/concepts-for-database-developers.html#GUID-3C50EAB8-FC39-4BB3-B680-4EACCE49E866",
        },
    },
]

# %%
# Create Llama Text Nodes
text_nodes = []
for text_json in text_json_list:
    # Construct the relationships using RelatedNodeInfo
    relationships = {
        NodeRelationship.SOURCE: RelatedNodeInfo(
            node_id=text_json["relationships"]
        )
    }

    # Prepare the metadata dictionary; you might want to exclude certain metadata fields if necessary
    metadata = {
        "weight": text_json["metadata"]["weight"],
        "rank": text_json["metadata"]["rank"],
    }

    # Create a TextNode instance
    text_node = TextNode(
        text=text_json["text"],
        id_=text_json["id_"],
        embedding=text_json["embedding"],
        relationships=relationships,
        metadata=metadata,
    )

    text_nodes.append(text_node)
print(text_nodes)
# Out:
# [TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=[1.0, 0.0], metadata={'weight': 1.0, 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.5_P1', embedding=[0.0, 1.0], metadata={'weight': 2.0, 'rank': 'c'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-1', node_type=None, metadata={}, hash=None)}, text='A tablespace can be online (accessible) or offline (not accessible) whenever the database is open.\nA tablespace is usually online so that its data is available to users. The SYSTEM tablespace and temporary tablespaces cannot be taken offline.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=[1.0, 1.0], metadata={'weight': 3.0, 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P3', embedding=[2.0, 1.0], metadata={'weight': 4.0, 'rank': 'e'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-3', node_type=None, metadata={}, hash=None)}, text='The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %% [markdown]
# ### Using AI Vector Search Create a bunch of Vector Stores with different distance strategies
#
# First we will create three vector stores each with different distance functions. Since we have not created indices in them yet, they will just create tables for now. Later we will use these vector stores to create HNSW indicies.
#
# You can manually connect to the Oracle Database and will see three tables
# Documents_DOT, Documents_COSINE and Documents_EUCLIDEAN.
#
# We will then create three additional tables Documents_DOT_IVF, Documents_COSINE_IVF and Documents_EUCLIDEAN_IVF which will be used
# to create IVF indicies on the tables instead of HNSW indices.

# %%
# Ingest documents into Oracle Vector Store using different distance strategies

vector_store_dot = OraLlamaVS.from_documents(
    text_nodes,
    table_name="Documents_DOT",
    client=connection,
    distance_strategy=DistanceStrategy.DOT_PRODUCT,
)
vector_store_max = OraLlamaVS.from_documents(
    text_nodes,
    table_name="Documents_COSINE",
    client=connection,
    distance_strategy=DistanceStrategy.COSINE,
)
vector_store_euclidean = OraLlamaVS.from_documents(
    text_nodes,
    table_name="Documents_EUCLIDEAN",
    client=connection,
    distance_strategy=DistanceStrategy.EUCLIDEAN_DISTANCE,
)

# Ingest documents into Oracle Vector Store using different distance strategies
vector_store_dot_ivf = OraLlamaVS.from_documents(
    text_nodes,
    table_name="Documents_DOT_IVF",
    client=connection,
    distance_strategy=DistanceStrategy.DOT_PRODUCT,
)
vector_store_max_ivf = OraLlamaVS.from_documents(
    text_nodes,
    table_name="Documents_COSINE_IVF",
    client=connection,
    distance_strategy=DistanceStrategy.COSINE,
)
vector_store_euclidean_ivf = OraLlamaVS.from_documents(
    text_nodes,
    table_name="Documents_EUCLIDEAN_IVF",
    client=connection,
    distance_strategy=DistanceStrategy.EUCLIDEAN_DISTANCE,
)

# %% [markdown]
# ### Demonstrating add, delete operations for texts, and basic similarity search

# %%
def manage_texts(vector_stores):
    """
    Adds texts to each vector store, demonstrates error handling for duplicate additions,
    and performs deletion of texts. Showcases similarity searches and index creation for each vector store.

    Args:
    - vector_stores (list): A list of OracleVS instances.
    """
    for i, vs in enumerate(vector_stores, start=1):
        # Adding texts
        try:
            vs.add_texts(text_nodes, metadata)
            print(f"\n\n\nAdd texts complete for vector store {i}\n\n\n")
        except Exception as ex:
            print(
                f"\n\n\nExpected error on duplicate add for vector store {i}\n\n\n"
            )

        # Deleting texts using the value of 'id'
        vs.delete("test-1")
        print(f"\n\n\nDelete texts complete for vector store {i}\n\n\n")

        # Similarity search
        query = VectorStoreQuery(
            query_embedding=[1.0, 1.0], similarity_top_k=3
        )
        results = vs.query(query=query)
        print(
            f"\n\n\nSimilarity search results for vector store {i}: {results}\n\n\n"
        )


vector_store_list = [
    vector_store_dot,
    vector_store_max,
    vector_store_euclidean,
    vector_store_dot_ivf,
    vector_store_max_ivf,
    vector_store_euclidean_ivf,
]
manage_texts(vector_store_list)
# Out:
# Expected error on duplicate add for vector store 1
#
#
#
#
#
#
# Delete texts complete for vector store 1
#
#
#
#
#
#
# Similarity search results for vector store 1: VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P3', embedding=None, metadata={'weight': Decimal('4'), 'rank': 'e'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-3', node_type=None, metadata={}, hash=None)}, text='The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[-19.085536923187668, -6.38905609893065, -1.718281828459045], ids=['cncpt_22.3.4.3.1_P3', 'cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4'])
#
#
#
#
#
#
# Expected error on duplicate add for vector store 2
#
#
#
#
#
#
# Delete texts complete for vector store 2
#
#
#
#
#
#
# Similarity search results for vector store 2: VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P3', embedding=None, metadata={'weight': Decimal('4'), 'rank': 'e'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-3', node_type=None, metadata={}, hash=None)}, text='The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[2.220446049250313e-16, 0.050022236923581764, 0.25389819392009794], ids=['cncpt_22.3.4.3.1_P2', 'cncpt_22.3.4.3.1_P3', 'cncpt_15.5.3.2.2_P4'])
#
#
#
#
#
#
# Expected error on duplicate add for vector store 3
#
#
#
#
#
#
# Delete texts complete for vector store 3
#
#
#
#
#
#
# Similarity search results for vector store 3: VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.5_P1', embedding=None, metadata={'weight': Decimal('2'), 'rank': 'c'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-1', node_type=None, metadata={}, hash=None)}, text='A tablespace can be online (accessible) or offline (not accessible) whenever the database is open.\nA tablespace is usually online so that its data is available to users. The SYSTEM tablespace and temporary tablespaces cannot be taken offline.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[0.0, 0.6321205588285577, 0.6321205588285577], ids=['cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4', 'cncpt_15.5.5_P1'])
#
#
#
#
#
#
# Expected error on duplicate add for vector store 4
#
#
#
#
#
#
# Delete texts complete for vector store 4
#
#
#
#
#
#
# Similarity search results for vector store 4: VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P3', embedding=None, metadata={'weight': Decimal('4'), 'rank': 'e'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-3', node_type=None, metadata={}, hash=None)}, text='The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[-19.085536923187668, -6.38905609893065, -1.718281828459045], ids=['cncpt_22.3.4.3.1_P3', 'cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4'])
#
#
#
#
#
#
# Expected error on duplicate add for vector store 5
#
#
#
#
#
#
# Delete texts complete for vector store 5
#
#
#
#
#
#
# Similarity search results for vector store 5: VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P3', embedding=None, metadata={'weight': Decimal('4'), 'rank': 'e'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-3', node_type=None, metadata={}, hash=None)}, text='The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[2.220446049250313e-16, 0.050022236923581764, 0.25389819392009794], ids=['cncpt_22.3.4.3.1_P2', 'cncpt_22.3.4.3.1_P3', 'cncpt_15.5.3.2.2_P4'])
#
#
#
#
#
#
# Expected error on duplicate add for vector store 6
#
#
#
#
#
#
# Delete texts complete for vector store 6
#
#
#
#
#
#
# Similarity search results for vector store 6: VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.5_P1', embedding=None, metadata={'weight': Decimal('2'), 'rank': 'c'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-1', node_type=None, metadata={}, hash=None)}, text='A tablespace can be online (accessible) or offline (not accessible) whenever the database is open.\nA tablespace is usually online so that its data is available to users. The SYSTEM tablespace and temporary tablespaces cannot be taken offline.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[0.0, 0.6321205588285577, 0.6321205588285577], ids=['cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4', 'cncpt_15.5.5_P1'])

# %% [markdown]
# ### Demonstrating index creation with specific parameters for each distance strategy

# %%
def create_search_indices(connection):
    """
    Creates search indices for the vector stores, each with specific parameters tailored to their distance strategy.
    """
    # Index for DOT_PRODUCT strategy
    # Notice we are creating a HNSW index with default parameters
    # This will default to creating a HNSW index with 8 Parallel Workers and use the Default Accuracy used by Oracle AI Vector Search
    orallamavs.create_index(
        connection,
        vector_store_dot,
        params={"idx_name": "hnsw_idx1", "idx_type": "HNSW"},
    )

    # Index for COSINE strategy with specific parameters
    # Notice we are creating a HNSW index with parallel 16 and Target Accuracy Specification as 97 percent
    orallamavs.create_index(
        connection,
        vector_store_max,
        params={
            "idx_name": "hnsw_idx2",
            "idx_type": "HNSW",
            "accuracy": 97,
            "parallel": 16,
        },
    )

    # Index for EUCLIDEAN_DISTANCE strategy with specific parameters
    # Notice we are creating a HNSW index by specifying Power User Parameters which are neighbors = 64 and efConstruction = 100
    orallamavs.create_index(
        connection,
        vector_store_euclidean,
        params={
            "idx_name": "hnsw_idx3",
            "idx_type": "HNSW",
            "neighbors": 64,
            "efConstruction": 100,
        },
    )

    # Index for DOT_PRODUCT strategy with specific parameters
    # Notice we are creating an IVF index with default parameters
    # This will default to creating an IVF index with 8 Parallel Workers and use the Default Accuracy used by Oracle AI Vector Search
    orallamavs.create_index(
        connection,
        vector_store_dot_ivf,
        params={
            "idx_name": "ivf_idx1",
            "idx_type": "IVF",
        },
    )

    # Index for COSINE strategy with specific parameters
    # Notice we are creating an IVF index with parallel 32 and Target Accuracy Specification as 90 percent
    orallamavs.create_index(
        connection,
        vector_store_max_ivf,
        params={
            "idx_name": "ivf_idx2",
            "idx_type": "IVF",
            "accuracy": 90,
            "parallel": 32,
        },
    )

    # Index for EUCLIDEAN_DISTANCE strategy with specific parameters
    # Notice we are creating an IVF index by specifying Power User Parameters which is neighbor_part = 64
    orallamavs.create_index(
        connection,
        vector_store_euclidean_ivf,
        params={
            "idx_name": "ivf_idx3",
            "idx_type": "IVF",
            "neighbor_part": 64,
        },
    )

    print("Index creation complete.")


create_search_indices(connection)
# Out:
# 2024-05-13 05:03:23,912 - ERROR - An unexpected error occurred: ORA-51961: The vector memory area is out of space.
# Help: https://docs.oracle.com/error-help/db/ora-51961/
# Traceback (most recent call last):
#   File "/Users/skmishra/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py", line 68, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/skmishra/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py", line 291, in _create_hnsw_index
#     cursor.execute(ddl)
#   File "/Users/skmishra/repo/llama_index/.venv/lib/python3.11/site-packages/oracledb/cursor.py", line 701, in execute
#     impl.execute(self)
#   File "src/oracledb/impl/thin/cursor.pyx", line 178, in oracledb.thin_impl.ThinCursorImpl.execute
#   File "src/oracledb/impl/thin/protocol.pyx", line 438, in oracledb.thin_impl.Protocol._process_single_message
#   File "src/oracledb/impl/thin/protocol.pyx", line 439, in oracledb.thin_impl.Protocol._process_single_message
#   File "src/oracledb/impl/thin/protocol.pyx", line 432, in oracledb.thin_impl.Protocol._process_message
# oracledb.exceptions.DatabaseError: ORA-51961: The vector memory area is out of space.
# Help: https://docs.oracle.com/error-help/db/ora-51961/
# 2024-05-13 05:03:23,915 - ERROR - DB-related error occurred.
# Traceback (most recent call last):
#   File "/Users/skmishra/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py", line 68, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/skmishra/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py", line 291, in _create_hnsw_index
#     cursor.execute(ddl)
#   File "/Users/skmishra/repo/llama_index/.venv/lib/python3.11/site-packages/oracledb/cursor.py", line 701, in execute
#     impl.execute(self)
#   File "src/oracledb/impl/thin/cursor.pyx", line 178, in oracledb.thin_impl.ThinCursorImpl.execute
#   File "src/oracledb/impl/thin/protocol.pyx", line 438, in oracledb.thin_impl.Protocol._process_single_message
#   File "src/oracledb/impl/thin/protocol.pyx", line 439, in oracledb.thin_impl.Protocol._process_single_message
#   File "src/oracledb/impl/thin/protocol.pyx", line 432, in oracledb.thin_impl.Protocol._process_message
# oracledb.exceptions.DatabaseError: ORA-51961: The vector memory area is out of space.
# Help: https://docs.oracle.com/error-help/db/ora-51961/
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/skmishra/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py", line 68, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/skmishra/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py", line 207, in create_index
#     _create_hnsw_index(
#   File "/Users/skmishra/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py", line 80, in wrapper
#     raise RuntimeError(f"Unexpected error: {e}") from e
# RuntimeError: Unexpected error: ORA-51961: The vector memory area is out of space.
# Help: https://docs.oracle.com/error-help/db/ora-51961/
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File ~/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py:68, in _handle_exceptions.<locals>.wrapper(*args, **kwargs)
#      67 try:
# ---> 68     return func(*args, **kwargs)
#      69 except RuntimeError as db_err:
#      70     # Handle a known type of error (e.g., DB-related) specifically
#
# File ~/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py:291, in _create_hnsw_index(client, table_name, distance_strategy, params)
#     290 with client.cursor() as cursor:
# --> 291     cursor.execute(ddl)
#     292     logger.info("Index created successfully...")
#
# File ~/repo/llama_index/.venv/lib/python3.11/site-packages/oracledb/cursor.py:701, in Cursor.execute(self, statement, parameters, **keyword_parameters)
#     700 impl = self._impl
# --> 701 impl.execute(self)
#     702 if impl.fetch_vars is not None:
#
# File src/oracledb/impl/thin/cursor.pyx:178, in oracledb.thin_impl.ThinCursorImpl.execute()
#
# File src/oracledb/impl/thin/protocol.pyx:438, in oracledb.thin_impl.Protocol._process_single_message()
#
# File src/oracledb/impl/thin/protocol.pyx:439, in oracledb.thin_impl.Protocol._process_single_message()
#
# File src/oracledb/impl/thin/protocol.pyx:432, in oracledb.thin_impl.Protocol._process_message()
#
# DatabaseError: ORA-51961: The vector memory area is out of space.
# Help: https://docs.oracle.com/error-help/db/ora-51961/
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py:68, in _handle_exceptions.<locals>.wrapper(*args, **kwargs)
#      67 try:
# ---> 68     return func(*args, **kwargs)
#      69 except RuntimeError as db_err:
#      70     # Handle a known type of error (e.g., DB-related) specifically
#
# File ~/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py:207, in create_index(client, vector_store, params)
#     206 if params["idx_type"] == "HNSW":
# --> 207     _create_hnsw_index(
#     208         client, vector_store.table_name, vector_store.distance_strategy, params
#     209     )
#     210 elif params["idx_type"] == "IVF":
#
# File ~/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py:80, in _handle_exceptions.<locals>.wrapper(*args, **kwargs)
#      79 logger.exception(f"An unexpected error occurred: {e}")
# ---> 80 raise RuntimeError(f"Unexpected error: {e}") from e
#
# RuntimeError: Unexpected error: ORA-51961: The vector memory area is out of space.
# Help: https://docs.oracle.com/error-help/db/ora-51961/
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 76
#      67     orallamavs.create_index(
#      68         connection,
#      69         vector_store_euclidean_ivf,
#      70         params={"idx_name": "ivf_idx3", "idx_type": "IVF", "neighbor_part": 64},
#      71     )
#      73     print("Index creation complete.")
# ---> 76 create_search_indices(connection)
#
# Cell In[8], line 8, in create_search_indices(connection)
#       2 """
#       3 Creates search indices for the vector stores, each with specific parameters tailored to their distance strategy.
#       4 """
#       5 # Index for DOT_PRODUCT strategy
#       6 # Notice we are creating a HNSW index with default parameters
#       7 # This will default to creating a HNSW index with 8 Parallel Workers and use the Default Accuracy used by Oracle AI Vector Search
# ----> 8 orallamavs.create_index(
#       9     connection,
#      10     vector_store_dot,
#      11     params={"idx_name": "hnsw_idx1", "idx_type": "HNSW"},
#      12 )
#      14 # Index for COSINE strategy with specific parameters
#      15 # Notice we are creating a HNSW index with parallel 16 and Target Accuracy Specification as 97 percent
#      16 orallamavs.create_index(
#      17     connection,
#      18     vector_store_max,
#    (...)
#      24     },
#      25 )
#
# File ~/repo/llama_index/.venv/lib/python3.11/site-packages/llama_index/legacy/vector_stores/orallamavs.py:72, in _handle_exceptions.<locals>.wrapper(*args, **kwargs)
#      69 except RuntimeError as db_err:
#      70     # Handle a known type of error (e.g., DB-related) specifically
#      71     logger.exception("DB-related error occurred.")
# ---> 72     raise RuntimeError(f"Failed due to a DB issue: {db_err}") from db_err
#      73 except ValueError as val_err:
#      74     # Handle another known type of error specifically
#      75     logger.exception("Validation error.")
#
# RuntimeError: Failed due to a DB issue: Unexpected error: ORA-51961: The vector memory area is out of space.
# Help: https://docs.oracle.com/error-help/db/ora-51961/

# %% [markdown]
# ### Now we will conduct a bunch of advanced searches on all six vector stores. Each of these three searches have a with and without filter version. The filter only selects the document with id 101 out and filters out everything else

# %%
# Conduct advanced searches after creating the indices
def conduct_advanced_searches(vector_stores):
    # Constructing a filter for direct comparison against document metadata
    # This filter aims to include documents whose metadata 'id' is exactly '2'

    for i, vs in enumerate(vector_stores, start=1):

        def query_without_filters_returns_all_rows_sorted_by_similarity():
            print(f"\n--- Vector Store {i} Advanced Searches ---")
            # Similarity search without a filter
            print("\nSimilarity search results without filter:")
            query = VectorStoreQuery(
                query_embedding=[1.0, 1.0], similarity_top_k=3
            )
            print(vs.query(query=query))

        query_without_filters_returns_all_rows_sorted_by_similarity()

        def query_with_filters_returns_multiple_matches():
            print(f"\n--- Vector Store {i} Advanced Searches ---")
            # Similarity search with filter
            print("\nSimilarity search results without filter:")
            filters = MetadataFilters(
                filters=[ExactMatchFilter(key="rank", value="c")]
            )
            query = VectorStoreQuery(
                query_embedding=[1.0, 1.0], filters=filters, similarity_top_k=1
            )
            result = vs.query(query)
            print(result.ids)

        query_with_filters_returns_multiple_matches()

        def query_with_filter_applies_top_k():
            print(f"\n--- Vector Store {i} Advanced Searches ---")
            # Similarity search with a filter
            print("\nSimilarity search results with filter:")
            filters = MetadataFilters(
                filters=[ExactMatchFilter(key="rank", value="c")]
            )
            query = VectorStoreQuery(
                query_embedding=[1.0, 1.0], filters=filters, similarity_top_k=1
            )
            result = vs.query(query)
            print(result.ids)

        query_with_filter_applies_top_k()

        def query_with_filter_applies_node_id_filter():
            print(f"\n--- Vector Store {i} Advanced Searches ---")
            # Similarity search with a filter
            print("\nSimilarity search results with filter:")
            filters = MetadataFilters(
                filters=[ExactMatchFilter(key="rank", value="c")]
            )
            query = VectorStoreQuery(
                query_embedding=[1.0, 1.0],
                filters=filters,
                similarity_top_k=3,
                node_ids=["452D24AB-F185-414C-A352-590B4B9EE51B"],
            )
            result = vs.query(query)
            print(result.ids)

        query_with_filter_applies_node_id_filter()

        def query_with_exact_filters_returns_single_match():
            print(f"\n--- Vector Store {i} Advanced Searches ---")
            # Similarity search with a filter
            print("\nSimilarity search results with filter:")
            filters = MetadataFilters(
                filters=[
                    ExactMatchFilter(key="rank", value="c"),
                    ExactMatchFilter(key="weight", value=2),
                ]
            )
            query = VectorStoreQuery(
                query_embedding=[1.0, 1.0], filters=filters
            )
            result = vs.query(query)
            print(result.ids)

        query_with_exact_filters_returns_single_match()

        def query_with_contradictive_filter_returns_no_matches():
            filters = MetadataFilters(
                filters=[
                    ExactMatchFilter(key="weight", value=2),
                    ExactMatchFilter(key="weight", value=3),
                ]
            )
            query = VectorStoreQuery(
                query_embedding=[1.0, 1.0], filters=filters
            )
            result = vs.query(query)
            print(result.ids)

        query_with_contradictive_filter_returns_no_matches()

        def query_with_filter_on_unknown_field_returns_no_matches():
            print(f"\n--- Vector Store {i} Advanced Searches ---")
            # Similarity search with a filter
            print("\nSimilarity search results with filter:")
            filters = MetadataFilters(
                filters=[ExactMatchFilter(key="unknown_field", value="c")]
            )
            query = VectorStoreQuery(
                query_embedding=[1.0, 1.0], filters=filters
            )
            result = vs.query(query)
            print(result.ids)

        query_with_filter_on_unknown_field_returns_no_matches()

        def delete_removes_document_from_query_results():
            vs.delete("test-1")
            query = VectorStoreQuery(
                query_embedding=[1.0, 1.0], similarity_top_k=2
            )
            result = vs.query(query)
            print(result.ids)

        delete_removes_document_from_query_results()


conduct_advanced_searches(vector_store_list)
# Out:
# --- Vector Store 1 Advanced Searches ---
#
# Similarity search results without filter:
# VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P3', embedding=None, metadata={'weight': Decimal('4'), 'rank': 'e'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-3', node_type=None, metadata={}, hash=None)}, text='The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[-19.085536923187668, -6.38905609893065, -1.718281828459045], ids=['cncpt_22.3.4.3.1_P3', 'cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4'])
#
# --- Vector Store 1 Advanced Searches ---
#
# Similarity search results without filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 1 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 1 Advanced Searches ---
#
# Similarity search results with filter:
# []
#
# --- Vector Store 1 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
# []
#
# --- Vector Store 1 Advanced Searches ---
#
# Similarity search results with filter:
# []
# ['cncpt_22.3.4.3.1_P3', 'cncpt_22.3.4.3.1_P2']
#
# --- Vector Store 2 Advanced Searches ---
#
# Similarity search results without filter:
# VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P3', embedding=None, metadata={'weight': Decimal('4'), 'rank': 'e'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-3', node_type=None, metadata={}, hash=None)}, text='The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[2.220446049250313e-16, 0.050022236923581764, 0.25389819392009794], ids=['cncpt_22.3.4.3.1_P2', 'cncpt_22.3.4.3.1_P3', 'cncpt_15.5.3.2.2_P4'])
#
# --- Vector Store 2 Advanced Searches ---
#
# Similarity search results without filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 2 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 2 Advanced Searches ---
#
# Similarity search results with filter:
# []
#
# --- Vector Store 2 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
# []
#
# --- Vector Store 2 Advanced Searches ---
#
# Similarity search results with filter:
# []
# ['cncpt_22.3.4.3.1_P2', 'cncpt_22.3.4.3.1_P3']
#
# --- Vector Store 3 Advanced Searches ---
#
# Similarity search results without filter:
# VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.5_P1', embedding=None, metadata={'weight': Decimal('2'), 'rank': 'c'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-1', node_type=None, metadata={}, hash=None)}, text='A tablespace can be online (accessible) or offline (not accessible) whenever the database is open.\nA tablespace is usually online so that its data is available to users. The SYSTEM tablespace and temporary tablespaces cannot be taken offline.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[0.0, 0.6321205588285577, 0.6321205588285577], ids=['cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4', 'cncpt_15.5.5_P1'])
#
# --- Vector Store 3 Advanced Searches ---
#
# Similarity search results without filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 3 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 3 Advanced Searches ---
#
# Similarity search results with filter:
# []
#
# --- Vector Store 3 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
# []
#
# --- Vector Store 3 Advanced Searches ---
#
# Similarity search results with filter:
# []
# ['cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4']
#
# --- Vector Store 4 Advanced Searches ---
#
# Similarity search results without filter:
# VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P3', embedding=None, metadata={'weight': Decimal('4'), 'rank': 'e'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-3', node_type=None, metadata={}, hash=None)}, text='The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[-19.085536923187668, -6.38905609893065, -1.718281828459045], ids=['cncpt_22.3.4.3.1_P3', 'cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4'])
#
# --- Vector Store 4 Advanced Searches ---
#
# Similarity search results without filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 4 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 4 Advanced Searches ---
#
# Similarity search results with filter:
# []
#
# --- Vector Store 4 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
# []
#
# --- Vector Store 4 Advanced Searches ---
#
# Similarity search results with filter:
# []
# ['cncpt_22.3.4.3.1_P3', 'cncpt_22.3.4.3.1_P2']
#
# --- Vector Store 5 Advanced Searches ---
#
# Similarity search results without filter:
# VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_22.3.4.3.1_P3', embedding=None, metadata={'weight': Decimal('4'), 'rank': 'e'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-3', node_type=None, metadata={}, hash=None)}, text='The LOB segment stores data in pieces called chunks. A chunk is a logically contiguous set of data blocks and is the smallest unit of allocation for a LOB. A row in the table stores a pointer called a LOB locator, which points to the LOB index. When the table is queried, the database uses the LOB index to quickly locate the LOB chunks.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[2.220446049250313e-16, 0.050022236923581764, 0.25389819392009794], ids=['cncpt_22.3.4.3.1_P2', 'cncpt_22.3.4.3.1_P3', 'cncpt_15.5.3.2.2_P4'])
#
# --- Vector Store 5 Advanced Searches ---
#
# Similarity search results without filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 5 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 5 Advanced Searches ---
#
# Similarity search results with filter:
# []
#
# --- Vector Store 5 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
# []
#
# --- Vector Store 5 Advanced Searches ---
#
# Similarity search results with filter:
# []
# ['cncpt_22.3.4.3.1_P2', 'cncpt_22.3.4.3.1_P3']
#
# --- Vector Store 6 Advanced Searches ---
#
# Similarity search results without filter:
# VectorStoreQueryResult(nodes=[TextNode(id_='cncpt_22.3.4.3.1_P2', embedding=None, metadata={'weight': Decimal('3'), 'rank': 'd'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-2', node_type=None, metadata={}, hash=None)}, text='The database stores LOBs differently from other data types. Creating a LOB column implicitly creates a LOB segment and a LOB index. The tablespace containing the LOB segment and LOB index, which are always stored together, may be different from the tablespace containing the table.\nSometimes the database can store small amounts of LOB data in the table itself rather than in a separate LOB segment.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.3.2.2_P4', embedding=None, metadata={'weight': Decimal('1'), 'rank': 'a'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-0', node_type=None, metadata={}, hash=None)}, text='If the answer to any preceding questions is yes, then the database stops the search and allocates space from the specified tablespace; otherwise, space is allocated from the database default shared temporary tablespace.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='cncpt_15.5.5_P1', embedding=None, metadata={'weight': Decimal('2'), 'rank': 'c'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='test-1', node_type=None, metadata={}, hash=None)}, text='A tablespace can be online (accessible) or offline (not accessible) whenever the database is open.\nA tablespace is usually online so that its data is available to users. The SYSTEM tablespace and temporary tablespaces cannot be taken offline.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')], similarities=[0.0, 0.6321205588285577, 0.6321205588285577], ids=['cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4', 'cncpt_15.5.5_P1'])
#
# --- Vector Store 6 Advanced Searches ---
#
# Similarity search results without filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 6 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
#
# --- Vector Store 6 Advanced Searches ---
#
# Similarity search results with filter:
# []
#
# --- Vector Store 6 Advanced Searches ---
#
# Similarity search results with filter:
# ['cncpt_15.5.5_P1']
# []
#
# --- Vector Store 6 Advanced Searches ---
#
# Similarity search results with filter:
# []
# ['cncpt_22.3.4.3.1_P2', 'cncpt_15.5.3.2.2_P4']

# %% [markdown]
# ### End to End Demo
# Please refer to our complete demo guide [Oracle AI Vector Search End-to-End Demo Guide](https://github.com/skmishraoracle/llama_index/blob/oraclevs_integration/docs/docs/examples/cookbooks/oracleai_demo.ipynb) to build an end to end RAG pipeline with the help of Oracle AI Vector Search.
