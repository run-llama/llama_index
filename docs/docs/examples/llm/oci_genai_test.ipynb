# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/examples/llm/bedrock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Oracle Cloud Infrastructure Generative AI
#
# Oracle Cloud Infrastructure (OCI) Generative AI is a fully managed service that provides a set of state-of-the-art, customizable large language models (LLMs) that cover a wide range of use cases, and which is available through a single API.
# Using the OCI Generative AI service you can access ready-to-use pretrained models, or create and host your own fine-tuned custom models based on your own data on dedicated AI clusters. Detailed documentation of the service and API is available __[here](https://docs.oracle.com/en-us/iaas/Content/generative-ai/home.htm)__ and __[here](https://docs.oracle.com/en-us/iaas/api/#/en/generative-ai/20231130/)__.
#
# This notebook explains how to use OCI's Genrative AI models with LlamaIndex.

# %% [markdown]
# ## Setup
#
# If you're opening this Notebook on colab, you will probably need to install LlamaIndex 🦙.

# %%
# %pip install llama-index-llms-oci-genai

# %%
# !pip install llama-index

# %% [markdown]
# You will also need to install the OCI sdk

# %%
# !pip install -U oci

# %% [markdown]
# ## Basic Usage
#
# Using LLMs offered by OCI Generative AI with LlamaIndex only requires you to initialize the OCIGenAI interface with your OCI endpoint, model ID, OCID, and authentication method.

# %% [markdown]
# #### Call `complete` with a prompt

# %%
from llama_index.llms.oci_genai import OCIGenAI

llm = OCIGenAI(
        model="cohere.command", 
        service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id="ocid1.tenancy.oc1..aaaaaaaasz6cicsgfbqh6tj3xahi4ozoescfz36bjm3kucc7lotk2oqep47q",
        auth_type="SECURITY_TOKEN", 
        auth_profile="BoatOc1"  # replace the value with the right profile name
)

resp= llm.complete("Paul Graham is ")
print(resp)
# Out:
# an American computer scientist, entrepreneur, and investor. He is best known for his work in computer science, his founding of the startup accelerator Y Combinator, and his essays on startup company culture and entrepreneurship.
#
# Graham was born in Cambridge, Massachusetts in 1964. He studied at the Harvard University Computer Laboratory and received his Bachelor's degree in philosophy from Harvard in 1986. He then attended the University of Cambridge and received a Master's degree in philosophy in 1988.
#
# Graham's career in computer science began in the early 1990s when he started working on Lisp, a programming language. He was the author of the widely acclaimed book "On Lisp" and has been known for his advocacy of the use of Lisp in modern software development.
#
# In 1995, Graham started his first company, ViaWeb, which was one of the first e-commerce platforms and was acquired by Yahoo! in 1998.
#
# In 2005, Graham founded Y Combinator, a startup accelerator that has provided early funding and advice to numerous technology companies, including Dropbox, AirBnB, Coinbase, Reddit, and Twitch.tv. Graham is known for his pragmatic approach to investing and his focus on the importance of hiring talented entrepreneurs.
#
# Graham is also a prolific writer and has published numerous essays on startup culture, entrepreneurship, and technology. He is known for his ability to clearly articulate complex ideas and his focus on the importance of culture and mindset in building successful companies.
#
# Would you like to know more about Paul Graham's work or his investments?

# %% [markdown]
# #### Call `chat` with a list of messages

# %%
from llama_index.llms.oci_genai import OCIGenAI
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(role="system", content="You are a pirate with a colorful personality"),
    ChatMessage(role="user", content="Tell me a story"),
]

llm = OCIGenAI(
        model="meta.llama-2-70b-chat",
        service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id="ocid1.tenancy.oc1..aaaaaaaasz6cicsgfbqh6tj3xahi4ozoescfz36bjm3kucc7lotk2oqep47q",
        auth_type="SECURITY_TOKEN", 
        auth_profile="BoatOc1"  # replace the value with the right profile name
)

resp = llm.chat(messages)
print(resp)
# Out:
# ---------------------------------------------------------------------------
# ServiceError                              Traceback (most recent call last)
# Cell In[3], line 17
#       4 messages = [
#       5     ChatMessage(role="chatbot", content="You are a pirate with a colorful personality"),
#       6     ChatMessage(role="user", content="Tell me a story"),
#       7 ]
#       9 llm = OCIGenAI(
#      10         model="meta.llama-2-70b-chat",
#      11         service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
#    (...)
#      14         auth_profile="BoatOc1"  # replace the value with the right profile name
#      15 )
# ---> 17 resp = llm.chat(messages)
#      18 print(resp)
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/llama_index/core/llms/callbacks.py:144, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     128 dispatcher.event(
#     129     LLMChatStartEvent(
#     130         model_dict=_self.to_dict(),
#    (...)
#     134     )
#     135 )
#     136 event_id = callback_manager.on_event_start(
#     137     CBEventType.LLM,
#     138     payload={
#    (...)
#     142     },
#     143 )
# --> 144 f_return_val = f(_self, messages, **kwargs)
#     146 if isinstance(f_return_val, Generator):
#     147     # intercept the generator and add a callback to the end
#     148     def wrapped_gen() -> ChatResponseGen:
#
# File ~/git/llama_index/llama-index-integrations/llms/llama-index-llms-oci-genai/llama_index/llms/oci_genai/base.py:287, in OCIGenAI.chat(self, messages, **kwargs)
#     279 chat_params = {**all_kwargs, **oci_params}
#     281 request = self._chat_generator(
#     282     compartment_id=self.compartment_id,
#     283     serving_mode=self._serving_mode,
#     284     chat_request=self._provider.oci_chat_request(**chat_params),
#     285 )
# --> 287 response = self._client.chat(request)
#     289 return ChatResponse(
#     290     message=ChatMessage(role=MessageRole.ASSISTANT, content=self._provider.chat_response_to_text(response)),
#     291     raw=response.__dict__,
#     292 )
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/generative_ai_service_bmc_python_client/generative_ai_inference_client.py:190, in GenerativeAiInferenceClient.chat(self, chat_details, **kwargs)
#     188         self.base_client.add_opc_client_retries_header(header_params)
#     189         retry_strategy.add_circuit_breaker_callback(self.circuit_breaker_callback)
# --> 190     return retry_strategy.make_retrying_call(
#     191         self.base_client.call_api,
#     192         resource_path=resource_path,
#     193         method=method,
#     194         header_params=header_params,
#     195         body=chat_details,
#     196         response_type="ChatResult",
#     197         allow_control_chars=kwargs.get('allow_control_chars'),
#     198         operation_name=operation_name,
#     199         api_reference_link=api_reference_link,
#     200         required_arguments=required_arguments)
#     201 else:
#     202     return self.base_client.call_api(
#     203         resource_path=resource_path,
#     204         method=method,
#    (...)
#     210         api_reference_link=api_reference_link,
#     211         required_arguments=required_arguments)
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/oci/retry/retry.py:309, in ExponentialBackoffRetryStrategyBase.make_retrying_call(self, func_ref, *func_args, **func_kwargs)
#     305 if _should_record_body_position_for_retry:
#     306     # Attempt to save current position for file-like body
#     307     _is_body_retryable, body_position = record_body_position_for_rewind(func_kwargs.get('body'))
# --> 309 response = func_ref(*func_args, **func_kwargs)
#     310 time_elapsed = time.time() - start_time
#     312 if log_info["logger"] and log_info["debug"]:
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/oci/base_client.py:584, in BaseClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, response_type, enforce_content_headers, allow_control_chars, operation_name, api_reference_link, required_arguments)
#     582                 raise
#     583 else:
# --> 584     response = self.request(request, allow_control_chars, operation_name, api_reference_link)
#     585     return response
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/circuitbreaker.py:159, in CircuitBreaker.decorate.<locals>.wrapper(*args, **kwargs)
#     157         return self.fallback_function(*args, **kwargs)
#     158     raise CircuitBreakerError(self)
# --> 159 return call(function, *args, **kwargs)
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/circuitbreaker.py:170, in CircuitBreaker.call(self, func, *args, **kwargs)
#     164 """
#     165 Calls the decorated function and applies the circuit breaker
#     166 rules on success or failure
#     167 :param func: Decorated function
#     168 """
#     169 with self:
# --> 170     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/oci/base_client.py:789, in BaseClient.request(self, request, allow_control_chars, operation_name, api_reference_link)
#     787         self.raise_transient_service_error(request, response, service_code, message, operation_name, api_reference_link, target_service, request_endpoint, client_version, timestamp, deserialized_data)
#     788     else:
# --> 789         self.raise_service_error(request, response, service_code, message, operation_name, api_reference_link, target_service, request_endpoint, client_version, timestamp, deserialized_data)
#     791 if stream:
#     792     if response.headers.get("content-type", "empty").lower() == SSE_RESPONSE_HEADER_VALUE:
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/oci/base_client.py:954, in BaseClient.raise_service_error(self, request, response, service_code, message, operation_name, api_reference_link, target_service, request_endpoint, client_version, timestamp, deserialized_data)
#     953 def raise_service_error(self, request, response, service_code, message, operation_name=None, api_reference_link=None, target_service=None, request_endpoint=None, client_version=None, timestamp=None, deserialized_data=None):
# --> 954     raise exceptions.ServiceError(
#     955         response.status_code,
#     956         service_code,
#     957         response.headers,
#     958         message,
#     959         original_request=request,
#     960         operation_name=operation_name,
#     961         api_reference_link=api_reference_link,
#     962         target_service=target_service,
#     963         request_endpoint=request_endpoint,
#     964         client_version=client_version,
#     965         timestamp=timestamp,
#     966         deserialized_data=deserialized_data)
#
# ServiceError: {'target_service': 'generative_ai_inference', 'status': 400, 'code': '400', 'opc-request-id': '139823F14D2545A098281F92212887EF/549593E68778548C52CD1C2A5448FA0F/023DE18DC1537F91FBC30F9909248DB2', 'message': '{"object":"error","message":"Conversation roles must alternate user/assistant/user/assistant/...","type":"BadRequestError","param":null,"code":400}', 'operation_name': 'chat', 'timestamp': '2024-05-06T19:27:12.088604+00:00', 'client_version': 'Oracle-PythonSDK/2.126.2+preview.1.8984', 'request_endpoint': 'POST https://inference.generativeai.us-chicago-1.oci.oraclecloud.com/20231130/actions/chat', 'logging_tips': 'To get more info on the failing request, refer to https://docs.oracle.com/en-us/iaas/tools/python/latest/logging.html for ways to log the request/response details.', 'troubleshooting_tips': 'See https://docs.oracle.com/iaas/Content/API/References/apierrors.htm#apierrors_400__400_400 for more information about resolving this error. If you are unable to resolve this generative_ai_inference issue, please contact Oracle support and provide them this full error message.'}

# %% [markdown]
# ## Streaming

# %% [markdown]
# Using `stream_complete` endpoint

# %%
from llama_index.llms.oci_genai import OCIGenAI

llm = OCIGenAI(
        model="meta.llama-2-70b-chat", 
        service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id="ocid1.tenancy.oc1..aaaaaaaasz6cicsgfbqh6tj3xahi4ozoescfz36bjm3kucc7lotk2oqep47q",
        auth_type="SECURITY_TOKEN", 
        auth_profile="BoatOc1"  # replace the value with the right profile name
)

resp= llm.stream_complete("Paul Graham is ", is_stream=False, stop=["people"])
for r in resp:
    print(r.delta, end="")
# Out:
# 100% correct. The problem is not the number of hours worked, it's the quality of those hours.
#
# I've worked 80 hour weeks before, and I've worked 40 hour weeks. Guess which ones were more productive? The 40 hour weeks, hands down.
#
# The reason is that when you work too many hours, you start to get burned out. You become less productive, less focused, and less creative. You start to make mistakes, and you start to resent your work.
#
# On the other hand, when you work a reasonable number of hours, you have time to rest, recharge, and refocus. You have time to think, to reflect, and to learn. You have time to enjoy your work, and to enjoy your life outside of work.
#
# So, don't worry about the number of hours you work. Worry about the quality of those hours. Make sure you're working smart, not hard. Make sure you're taking breaks, getting enough sleep, and taking care of yourself.
#
# And above all, remember that work is just a part of your life. It's not the only thing that matters. Take time to enjoy the other parts of your life, too.

# %% [markdown]
# Using `stream_chat` endpoint

# %%
from llama_index.llms.oci_genai import OCIGenAI
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(role="system", content="You are a pirate with a colorful personality"),
    ChatMessage(role="user", content="Tell me a story"),
]

llm = OCIGenAI(
        model="cohere.command-r",
        service_endpoint="https://ppe.inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id="ocid1.tenancy.oc1..aaaaaaaasz6cicsgfbqh6tj3xahi4ozoescfz36bjm3kucc7lotk2oqep47q",
        auth_type="SECURITY_TOKEN", 
        auth_profile="BoatOc1",  # replace the value with the right profile name
)

resp = llm.stream_chat(messages)
for r in resp:
    print(r.delta, end="")
# Out:
# Ahoy, matey! Ye listen to this tale, and ye'll hear the story of a fearsome pirate named Black Bart.
#
# Black Bart was a fearsome pirate who sailed the seven seas in search of treasure and glory. He and his crew had heard tales of a mysterious island hidden away in the vast ocean, said to be bursting to the seams with riches beyond compare. The island was guarded by a terrible monster, and many a pirate had set sail to find it, only to disappear without a trace.
#
# But Black Bart was not a pirate to be deterred by mere rumors. He and his crew set sail on their ship, the Wicked Wench, to find this island and claim the treasure for themselves. They sailed for many a moonlit night, braving the dangers of the high seas, until one fateful day when they spotted a mysterious figurehead looming on the horizon. It was the island, and the monster that guarded it - a giant sea serpent!
#
# Black Bart and his crew prepared their weapons, ready for battle. Bart himself brandished his fearsome cutlass, and with a battle cry, they charged the island. The sea serpent roared and attacked, its massive jaws opening wide, but the pirates fought back valantly. Bart's skill with the cutlass was unmatched, and he struck the monster's head clean off its shoulders!
#
# With the sea serpent defeated, the pirates landed on the island and began to search for the treasure. They dug and searched and soon struck gold, finding a long-lost treasure chest filled with riches beyond their wildest dreams. They returned to the Wicked Wench, triumphant and wealthy beyond measure.
#
# Black Bart and his crew became legends that day, and their story was sung in taverns across the land. Bart spent his newfound wealth on a grand estate, where he lived the rest of his days in luxury, never forgetting the adventure that made him a rich man.
#
# And there ye have it, mateys! A tale of adventure, danger, and treasure. Remember to live life like Black Bart - fearlessly and with a sense of adventure!

# %%
from llama_index.llms.oci_genai import OCIGenAI
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(role="chatbot", content="You are a pirate with a colorful personality"),
    ChatMessage(role="user", content="Tell me a story"),
]

llm = OCIGenAI(
        model="ocid1.generativeaiendpoint.oc1.us-chicago-1.amaaaaaabgjpxjqaxfey5jyxfjlaydari5lhs4sinyxspvjcrdk5xi67s6ha",
        service_endpoint="https://ppe.inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id="ocid1.compartment.oc1..aaaaaaaabma2uwi3rcrlx5qxsihcr2k4ehf7jxer6p6c6ngga2zlhkgir3ka",
        provider="cohere",
        auth_type="SECURITY_TOKEN", 
        auth_profile="BoatOc1",  # replace the value with the right profile name
        context_size=128000
)

resp = llm.stream_chat(messages)
for r in resp:
    print(r.delta, end="")
# Out:
# Once upon a time, there was a fearsome pirate captain named Crimson Jack. He sailed the Seven Seas in search of treasure and glory, striking fear into the hearts of all who crossed his path. With a loyal crew by his side, Captain Jack embarked on countless adventures, always seeking the thrill of the chase and the shine of gold.
#
# One day, Captain Jack received a mysterious map from an old sea dog in a tavern. The map purported to show the location of a legendary treasure, a fortune that could make him the richest pirate in history. With a gleam in his eye, Captain Jack set sail immediately, eager to claim the bounty as his own.
#
# As he followed the map's clues, Captain Jack encountered treacherous storms, cunning enemies, and treacherous traps. He battled rival pirates, outwitted treacherous mermaids, and braved the depths of the ocean to uncover the secrets of the treasure's location. Along the way, he made new allies, including a clever navigator named Lily and a fearsome warrior named Blackbeard.
#
# Finally, after months of perilous journeying, Captain Jack and his crew arrived at a remote island shrouded in mist. As they stepped foot on the shore, they knew they had reached their destination. The air crackled with anticipation as they ventured into the heart of the island, where a hidden cave promised untold riches.
#
# Within the cave, they discovered a chamber filled with golden treasures beyond their wildest dreams. Jewels, coins, and artifacts glittered in the flickering torchlight. Captain Jack's heart raced as he realized that his quest had been successful. He and his crew had earned their place in pirate history.
#
# But as they prepared to load their ship with the bounty, a hidden trap was sprung. The floor of the cave began to shake, and ancient guardians rose from the shadows to protect the treasure. A fierce battle ensued, with Captain Jack and his crew fighting for their lives against the mysterious defenders of the treasure.
#
# In the end, Captain Jack's bravery and quick thinking prevailed. He outsmarted the guardians, using his wits to disable the traps and secure the treasure. With the danger vanquished, the crew loaded their ship with the riches, ready to set sail for home.
#
# As they sailed away, the crew celebrated their incredible victory. Captain Jack, now known as the richest pirate on the seas, shared the spoils with his loyal companions. They feasted, drank, and told tales of their

# %%
from llama_index.llms.oci_genai import OCIGenAI
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(role="chatbot", content="You are a pirate with a colorful personality"),
    ChatMessage(role="user", content="Tell me a story"),
]

llm = OCIGenAI(
        model="cohere.command-r-plus",
        service_endpoint="https://ppe.inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id="ocid1.tenancy.oc1..aaaaaaaaumuuscymm6yb3wsbaicfx3mjhesghplvrvamvbypyehh5pgaasna",
        auth_type="SECURITY_TOKEN", 
        auth_profile="BoatOc1",  # replace the value with the right profile name
)

resp = llm.stream_chat(messages, is_stream=False, stop_sequences=["pirate"])
for r in resp:
    print(r.delta, end="")
# Out:
# ---------------------------------------------------------------------------
# ServiceError                              Traceback (most recent call last)
# Cell In[3], line 17
#       4 messages = [
#       5     ChatMessage(role="chatbot", content="You are a pirate with a colorful personality"),
#       6     ChatMessage(role="user", content="Tell me a story"),
#       7 ]
#       9 llm = OCIGenAI(
#      10         model="cohere.command-r-plus",
#      11         service_endpoint="https://ppe.inference.generativeai.us-chicago-1.oci.oraclecloud.com",
#    (...)
#      14         auth_profile="BoatOc1",  # replace the value with the right profile name
#      15 )
# ---> 17 resp = llm.stream_chat(messages, is_stream=False, stop_sequences=["pirate"])
#      18 for r in resp:
#      19     print(r.delta, end="")
#
# File ~/git/llama_index/llama-index-integrations/llms/llama-index-llms-oci-genai/llama_index/llms/oci_genai/base.py:314, in OCIGenAI.stream_chat(self, messages, **kwargs)
#     306 chat_params = {**all_kwargs, **oci_params}
#     308 request = self._chat_generator(
#     309     compartment_id=self.compartment_id,
#     310     serving_mode=self._serving_mode,
#     311     chat_request=self._provider.oci_chat_request(**chat_params),
#     312 )
# --> 314 response = self._client.chat(request)
#     316 def gen() -> ChatResponseGen:
#     317     content = ""
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/generative_ai_service_bmc_python_client/generative_ai_inference_client.py:190, in GenerativeAiInferenceClient.chat(self, chat_details, **kwargs)
#     188         self.base_client.add_opc_client_retries_header(header_params)
#     189         retry_strategy.add_circuit_breaker_callback(self.circuit_breaker_callback)
# --> 190     return retry_strategy.make_retrying_call(
#     191         self.base_client.call_api,
#     192         resource_path=resource_path,
#     193         method=method,
#     194         header_params=header_params,
#     195         body=chat_details,
#     196         response_type="ChatResult",
#     197         allow_control_chars=kwargs.get('allow_control_chars'),
#     198         operation_name=operation_name,
#     199         api_reference_link=api_reference_link,
#     200         required_arguments=required_arguments)
#     201 else:
#     202     return self.base_client.call_api(
#     203         resource_path=resource_path,
#     204         method=method,
#    (...)
#     210         api_reference_link=api_reference_link,
#     211         required_arguments=required_arguments)
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/oci/retry/retry.py:309, in ExponentialBackoffRetryStrategyBase.make_retrying_call(self, func_ref, *func_args, **func_kwargs)
#     305 if _should_record_body_position_for_retry:
#     306     # Attempt to save current position for file-like body
#     307     _is_body_retryable, body_position = record_body_position_for_rewind(func_kwargs.get('body'))
# --> 309 response = func_ref(*func_args, **func_kwargs)
#     310 time_elapsed = time.time() - start_time
#     312 if log_info["logger"] and log_info["debug"]:
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/oci/base_client.py:584, in BaseClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, response_type, enforce_content_headers, allow_control_chars, operation_name, api_reference_link, required_arguments)
#     582                 raise
#     583 else:
# --> 584     response = self.request(request, allow_control_chars, operation_name, api_reference_link)
#     585     return response
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/circuitbreaker.py:159, in CircuitBreaker.decorate.<locals>.wrapper(*args, **kwargs)
#     157         return self.fallback_function(*args, **kwargs)
#     158     raise CircuitBreakerError(self)
# --> 159 return call(function, *args, **kwargs)
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/circuitbreaker.py:170, in CircuitBreaker.call(self, func, *args, **kwargs)
#     164 """
#     165 Calls the decorated function and applies the circuit breaker
#     166 rules on success or failure
#     167 :param func: Decorated function
#     168 """
#     169 with self:
# --> 170     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/oci/base_client.py:789, in BaseClient.request(self, request, allow_control_chars, operation_name, api_reference_link)
#     787         self.raise_transient_service_error(request, response, service_code, message, operation_name, api_reference_link, target_service, request_endpoint, client_version, timestamp, deserialized_data)
#     788     else:
# --> 789         self.raise_service_error(request, response, service_code, message, operation_name, api_reference_link, target_service, request_endpoint, client_version, timestamp, deserialized_data)
#     791 if stream:
#     792     if response.headers.get("content-type", "empty").lower() == SSE_RESPONSE_HEADER_VALUE:
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/oci/base_client.py:954, in BaseClient.raise_service_error(self, request, response, service_code, message, operation_name, api_reference_link, target_service, request_endpoint, client_version, timestamp, deserialized_data)
#     953 def raise_service_error(self, request, response, service_code, message, operation_name=None, api_reference_link=None, target_service=None, request_endpoint=None, client_version=None, timestamp=None, deserialized_data=None):
# --> 954     raise exceptions.ServiceError(
#     955         response.status_code,
#     956         service_code,
#     957         response.headers,
#     958         message,
#     959         original_request=request,
#     960         operation_name=operation_name,
#     961         api_reference_link=api_reference_link,
#     962         target_service=target_service,
#     963         request_endpoint=request_endpoint,
#     964         client_version=client_version,
#     965         timestamp=timestamp,
#     966         deserialized_data=deserialized_data)
#
# ServiceError: {'target_service': 'generative_ai_inference', 'status': 400, 'code': '400', 'opc-request-id': '44947AB9CBA146988CCF5063288BAE91/3AB3F356D373DEB38829D813BA2FBE50/716635362178B7A9B772AE2CB609E4EA', 'message': 'Entity with key cohere.command-r-plus not found', 'operation_name': 'chat', 'timestamp': '2024-05-06T19:18:43.216613+00:00', 'client_version': 'Oracle-PythonSDK/2.126.2+preview.1.8984', 'request_endpoint': 'POST https://ppe.inference.generativeai.us-chicago-1.oci.oraclecloud.com/20231130/actions/chat', 'logging_tips': 'To get more info on the failing request, refer to https://docs.oracle.com/en-us/iaas/tools/python/latest/logging.html for ways to log the request/response details.', 'troubleshooting_tips': 'See https://docs.oracle.com/iaas/Content/API/References/apierrors.htm#apierrors_400__400_400 for more information about resolving this error. If you are unable to resolve this generative_ai_inference issue, please contact Oracle support and provide them this full error message.'}

# %%
from llama_index.embeddings.oci_genai import OCIGenAIEmbeddings

embeddings = OCIGenAIEmbeddings(
                model="cohere.embed-english-light-v2.0", 
                service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
                compartment_id="ocid1.tenancy.oc1..aaaaaaaasz6cicsgfbqh6tj3xahi4ozoescfz36bjm3kucc7lotk2oqep47q", 
                auth_type="SECURITY_TOKEN",
                auth_profile="BoatOc1"
            )

937256, 0.008674622, 0.0077209473, 0.0027370453, 0.013389587, 0.010292053, -0.013786316, -0.017181396, 0.005596161, -0.029022217, -0.009140015, 0.0038757324, -0.011512756, -0.0287323, -0.0041046143, 0.01965332, 0.0014209747, -0.010154724, 0.011405945, -0.025924683, 0.0059509277, -3.8146973e-05, -0.01574707, 0.0017547607, 0.015991211, 0.00881958, 0.015853882, -0.007801056, -0.011428833, -0.009666443, 0.013267517, 0.0066871643, -0.031402588, -0.00762558, -0.028945923, -0.02178955, -0.005897522, -0.010276794, 0.007972717, 0.0012302399, -0.010871887, 0.020553589, -0.0032672882, 0.010261536, 0.02015686 ...

# %% [markdown]
# ## Configure Model

# %%
from llama_index.llms.oci_genai import OCIGenAI

llm = OCIGenAI(
        model="cohere.command", 
        service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id="MY_OCID",
)

resp= llm.complete("Paul Graham is ")
print(resp)

# %% [markdown]
# ## Authentication
# The authentication methods supported for LlamaIndex are equivalent to those used with other OCI services and follow the __[standard SDK authentication](https://docs.oracle.com/en-us/iaas/Content/API/Concepts/sdk_authentication_methods.htm)__ methods, specifically API Key, session token, instance principal, and resource principal.
#
# API key is the default authentication method. The following example demonstrates how to use a different authentication method (session token)

# %%
from llama_index.llms.oci_genai import OCIGenAI

llm = OCIGenAI(
    model="cohere.command",
    service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
    compartment_id="ocid1.tenancy.oc1..aaaaaaaasz6cicsgfbqh6tj3xahi4ozoescfz36bjm3kucc7lotk2oqep47q",
    auth_type="RESOURCE_PRINCIPAL",
    auth_profile="BoatOc1",  # replace with your profile name
)

resp= llm.stream_chat("Paul Graham is ")
print(resp)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/git/llama_index/llama-index-integrations/llms/llama-index-llms-oci-genai/llama_index/llms/oci_genai/utils.py:89, in create_client(auth_type, auth_profile, service_endpoint)
#      86 elif auth_type == OCIAuthType(4).name:
#      87     client_kwargs[
#      88         "signer"
# ---> 89     ] = oci.auth.signers.get_resource_principals_signer()
#      90 else:
#
# File ~/anaconda3/envs/llama_index/lib/python3.11/site-packages/oci/auth/signers/resource_principals_signer.py:227, in get_resource_principals_signer(resource_principal_token_path_provider)
#     226 elif rp_version == "UNDEFINED":
# --> 227     raise EnvironmentError(f"{OCI_RESOURCE_PRINCIPAL_VERSION} is not defined")
#     228 else:
#
# OSError: OCI_RESOURCE_PRINCIPAL_VERSION is not defined
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 from llama_index.llms.oci_genai import OCIGenAI
# ----> 3 llm = OCIGenAI(
#       4     model="cohere.command",
#       5     service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
#       6     compartment_id="ocid1.tenancy.oc1..aaaaaaaasz6cicsgfbqh6tj3xahi4ozoescfz36bjm3kucc7lotk2oqep47q",
#       7     auth_type="RESOURCE_PRINCIPAL",
#       8     auth_profile="BoatOc1",  # replace with your profile name
#       9 )
#      11 resp= llm.stream_chat("Paul Graham is ")
#      12 print(resp)
#
# File ~/git/llama_index/llama-index-integrations/llms/llama-index-llms-oci-genai/llama_index/llms/oci_genai/base.py:166, in OCIGenAI.__init__(self, model, temperature, max_tokens, context_size, service_endpoint, compartment_id, auth_type, auth_profile, client, provider, additional_kwargs, callback_manager, system_prompt, messages_to_prompt, completion_to_prompt, pydantic_program_mode, output_parser)
#     115 def __init__(
#     116     self,
#     117     model: str,
#    (...)
#     136
#     137 ) -> None:
#     138     """
#     139     Initializes the OCIGenAI class.
#     140
#    (...)
#     164         additional_kwargs (Optional[Dict[str, Any]]): Additional kwargs for the the LLM.
#     165     """
# --> 166     self._client = client or create_client(auth_type, auth_profile, service_endpoint)
#     168     self._provider = get_provider(model, provider)
#     170     self._serving_mode = get_serving_mode(model)
#
# File ~/git/llama_index/llama-index-integrations/llms/llama-index-llms-oci-genai/llama_index/llms/oci_genai/utils.py:101, in create_client(auth_type, auth_profile, service_endpoint)
#      96     raise ModuleNotFoundError(
#      97         "Could not import oci python package. "
#      98         "Please make sure you have the oci package installed."
#      99     ) from ex
#     100 except Exception as e:
# --> 101     raise ValueError(
#     102         """Could not authenticate with OCI client. Please check if ~/.oci/config exists.
#     103         If INSTANCE_PRINCIPAL or RESOURCE_PRINCIPAL is used, please check the specified
#     104         auth_profile and auth_type are valid.""",
#     105         e
#     106     ) from e
#
# ValueError: ('Could not authenticate with OCI client. Please check if ~/.oci/config exists. \n            If INSTANCE_PRINCIPAL or RESOURCE_PRINCIPAL is used, please check the specified \n            auth_profile and auth_type are valid.', OSError('OCI_RESOURCE_PRINCIPAL_VERSION is not defined'))

# %%
from llama_index.llms.oci_genai import OCIGenAI

llm = OCIGenAI(
        model="meta.llama-2-70b-chat", 
        service_endpoint="https://inference.generativeai.us-chicago-1.oci.oraclecloud.com",
        compartment_id="ocid1.tenancy.oc1..aaaaaaaasz6cicsgfbqh6tj3xahi4ozoescfz36bjm3kucc7lotk2oqep47q",
        auth_type="SECURITY_TOKEN", 
        auth_profile="BoatOc1"  # replace the value with the right profile name
)

resp= llm.stream_complete("Paul Graham is ", stop=["person"])
for r in resp:
    print(r.delta, end="")
# Out:
# 100% correct. The only way to get good at programming is to program. A lot.
#
# I've been programming for over 20 years, and I can tell you that the only way to get good at it is to keep writing code. The more code you write, the better you'll get. It's just like any other skill - the more you practice, the better you'll become.
#
# I've seen a lot of people try to learn programming by reading books or taking courses, but they never actually write any code. They might understand the theory, but they don't have any practical experience. And that's what matters - being able to apply what you've learned to real-world problems.
#
# So, if you want to get good at programming, don't worry too much about the theory. Just start writing code. Start with simple programs and gradually work your way up to more complex projects. You'll learn by doing, and you'll get better with each line of code you write.
#
# And don't be afraid to make mistakes. Making mistakes is a natural part of the learning process, and you'll learn more from your mistakes than you will from successes. So, don't be afraid to take risks and try new things. That's how you'll improve.
#
# In short, the only way to get good at programming is to program. A lot. So, get out there and start writing some code!

# %%
# !pip list
# Out:
# Package                                 Version                  Editable project location
# --------------------------------------- ------------------------ ---------------------------------------------------------------------------------------------------
# aiohttp                                 3.9.5
# aiosignal                               1.3.1
# annotated-types                         0.6.0
# anyio                                   4.3.0
# appnope                                 0.1.4
# argon2-cffi                             23.1.0
# argon2-cffi-bindings                    21.2.0
# arrow                                   1.3.0
# astroid                                 2.13.5
# asttokens                               2.4.1
# async-lru                               2.0.4
# attrs                                   23.2.0
# Babel                                   2.14.0
# backcall                                0.2.0
# beautifulsoup4                          4.12.3
# black                                   23.9.1
# bleach                                  6.1.0
# bs4                                     0.0.2
# certifi                                 2024.2.2
# cffi                                    1.16.0
# cfgv                                    3.4.0
# charset-normalizer                      3.3.2
# circuitbreaker                          1.4.0
# click                                   8.1.7
# codespell                               2.2.6
# comm                                    0.2.2
# cryptography                            42.0.5
# dataclasses-json                        0.6.4
# debugpy                                 1.8.1
# decorator                               5.1.1
# defusedxml                              0.7.1
# Deprecated                              1.2.14
# dill                                    0.3.8
# dirtyjson                               1.0.8
# distlib                                 0.3.8
# distro                                  1.9.0
# executing                               2.0.1
# fastjsonschema                          2.19.1
# filelock                                3.13.4
# fqdn                                    1.5.1
# frozenlist                              1.4.1
# fsspec                                  2024.3.1
# generative-ai-service-bmc-python-client 0.2.337
# greenlet                                3.0.3
# h11                                     0.14.0
# httpcore                                1.0.5
# httpx                                   0.27.0
# identify                                2.5.36
# idna                                    3.7
# iniconfig                               2.0.0
# ipykernel                               6.29.4
# ipython                                 8.10.0
# ipywidgets                              8.1.2
# isoduration                             20.11.0
# isort                                   5.13.2
# jedi                                    0.19.1
# Jinja2                                  3.1.3
# joblib                                  1.4.0
# json5                                   0.9.25
# jsonpointer                             2.4
# jsonschema                              4.21.1
# jsonschema-specifications               2023.12.1
# jupyter                                 1.0.0
# jupyter_client                          8.6.1
# jupyter-console                         6.6.3
# jupyter_core                            5.7.2
# jupyter-events                          0.10.0
# jupyter-lsp                             2.2.5
# jupyter_server                          2.14.0
# jupyter_server_terminals                0.5.3
# jupyterlab                              4.1.8
# jupyterlab_pygments                     0.3.0
# jupyterlab_server                       2.27.1
# jupyterlab_widgets                      3.0.10
# lazy-object-proxy                       1.10.0
# llama-index                             0.10.20                  /Users/archeng/git/llama_index
# llama-index-agent-openai                0.2.2
# llama-index-cli                         0.1.11
# llama-index-core                        0.10.33
# llama-index-embeddings-oci-genai        0.1.0                    /Users/archeng/git/llama_index/llama-index-integrations/embeddings/llama-index-embeddings-oci-genai
# llama-index-embeddings-openai           0.1.7
# llama-index-indices-managed-llama-cloud 0.1.5
# llama-index-legacy                      0.9.48
# llama-index-llms-oci-genai              0.1.0                    /Users/archeng/git/llama_index/llama-index-integrations/llms/llama-index-llms-oci-genai
# llama-index-llms-openai                 0.1.14
# llama-index-multi-modal-llms-openai     0.1.4
# llama-index-program-openai              0.1.5
# llama-index-question-gen-openai         0.1.3
# llama-index-readers-file                0.1.16
# llama-index-readers-llama-parse         0.1.4
# llama-parse                             0.4.0
# llamaindex-py-client                    0.1.19
# MarkupSafe                              2.1.5
# marshmallow                             3.21.1
# matplotlib-inline                       0.1.7
# mccabe                                  0.7.0
# mistune                                 3.0.2
# multidict                               6.0.5
# mypy                                    0.991
# mypy-extensions                         1.0.0
# nbclient                                0.10.0
# nbconvert                               7.16.3
# nbformat                                5.10.4
# nest-asyncio                            1.6.0
# networkx                                3.1
# nltk                                    3.8.1
# nodeenv                                 1.8.0
# notebook                                7.1.3
# notebook_shim                           0.2.4
# numpy                                   1.24.4
# oci                                     2.126.2+preview.1.0.9317
# openai                                  1.23.6
# overrides                               7.7.0
# packaging                               24.0
# pandas                                  2.0.3
# pandocfilters                           1.5.1
# parso                                   0.8.4
# pathspec                                0.12.1
# pexpect                                 4.9.0
# pickleshare                             0.7.5
# pillow                                  10.3.0
# pip                                     23.3.1
# platformdirs                            4.2.1
# pluggy                                  1.5.0
# pre-commit                              3.2.0
# prometheus_client                       0.20.0
# prompt-toolkit                          3.0.43
# psutil                                  5.9.8
# ptyprocess                              0.7.0
# pure-eval                               0.2.2
# pycparser                               2.22
# pydantic                                2.7.1
# pydantic_core                           2.18.2
# Pygments                                2.17.2
# pylint                                  2.15.10
# PyMuPDF                                 1.24.1
# PyMuPDFb                                1.24.1
# pyOpenSSL                               24.1.0
# pypdf                                   4.2.0
# pytest                                  7.2.1
# pytest-mock                             3.11.1
# python-dateutil                         2.9.0.post0
# python-json-logger                      2.0.7
# pytz                                    2024.1
# PyYAML                                  6.0.1
# pyzmq                                   26.0.2
# qtconsole                               5.5.1
# QtPy                                    2.4.1
# referencing                             0.35.0
# regex                                   2024.4.28
# requests                                2.31.0
# rfc3339-validator                       0.1.4
# rfc3986-validator                       0.1.1
# rpds-py                                 0.18.0
# ruff                                    0.0.292
# Send2Trash                              1.8.3
# setuptools                              69.5.1
# six                                     1.16.0
# sniffio                                 1.3.1
# soupsieve                               2.5
# SQLAlchemy                              2.0.29
# stack-data                              0.6.3
# striprtf                                0.0.26
# tenacity                                8.2.3
# terminado                               0.18.1
# tiktoken                                0.6.0
# tinycss2                                1.3.0
# tokenize-rt                             5.2.0
# tomlkit                                 0.12.4
# tornado                                 6.4
# tqdm                                    4.66.2
# traitlets                               5.14.3
# tree-sitter                             0.21.3
# tree-sitter-languages                   1.10.2
# types-cffi                              1.16.0.20240331
# types-Deprecated                        1.2.9.20240311
# types-docutils                          0.21.0.20240423
# types-protobuf                          4.25.0.20240417
# types-pyOpenSSL                         24.1.0.20240425
# types-python-dateutil                   2.9.0.20240316
# types-PyYAML                            6.0.12.20240311
# types-redis                             4.5.5.0
# types-requests                          2.28.11.8
# types-setuptools                        67.1.0.0
# types-urllib3                           1.26.25.14
# typing_extensions                       4.11.0
# typing-inspect                          0.9.0
# tzdata                                  2024.1
# uri-template                            1.3.0
# urllib3                                 2.2.1
# virtualenv                              20.26.0
# wcwidth                                 0.2.13
# webcolors                               1.13
# webencodings                            0.5.1
# websocket-client                        1.8.0
# wheel                                   0.41.2
# widgetsnbextension                      4.0.10
# wrapt                                   1.16.0
# yarl                                    1.9.4
