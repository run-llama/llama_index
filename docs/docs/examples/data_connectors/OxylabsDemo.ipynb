# %% [markdown]
# # Oxylabs Reader

# %% [markdown]
# Use Oxylabs Reader to get information from Google Search and Amazon.
# For more information checkout out the [Oxylabs documentation](https://developers.oxylabs.io/scraper-apis/web-scraper-api).

# %%
# %pip install llama-index llama-index-readers-oxylabs

# %% [markdown]
# In this notebook we show how Oxylabs Reader can be used to collect information from different sources.
#
# Firstly, import one of the Oxylabs readers
#
# Currently available readers are:
# * OxylabsAmazonSearchReader
# * OxylabsAmazonPricingReader
# * OxylabsAmazonProductReader
# * OxylabsAmazonSellersReader
# * OxylabsAmazonBestsellersReader
# * OxylabsAmazonReviewsReader
# * OxylabsGoogleSearchReader
# * OxylabsGoogleAdsReader

# %%
import os
from llama_index.readers.oxylabs import OxylabsGoogleSearchReader

# %%
# This is needed to run it in Jupyter notebook
# import nest_asyncio
# nest_asyncio.apply()

# %% [markdown]
# Instantiate OxylabsReader with your username and password

# %%
oxylabs_username = os.environ.get("OXYLABS_USERNAME")
oxylabs_password = os.environ.get("OXYLABS_PASSWORD")

google_search_reader = OxylabsGoogleSearchReader(
    oxylabs_username, oxylabs_password
)

# %% [markdown]
# Prepare parameters. This example will load the Google Search results for the 'iPhone 16' query with the 'Berlin, Germany' location.
#
# Checkout the [documentation](https://developers.oxylabs.io/scraper-apis/web-scraper-api) for more examples.

# %%
docs = google_search_reader.load_data(
    {"query": "Iphone 16", "parse": True, "geo_location": "Berlin, Germany"}
)

print(docs[0].text)
# Out:
#   ORGANIC RESULTS ITEMS:
#     ORGANIC-ITEM-1:
#     POS: 1
#     URL: https://www.apple.com/de/iphone-16/
#     DESC: Dieses Design verdient ein langes Leben. Das iPhone 16 hat ein Gehäuse aus Aluminium in Raumfahrt-Qualität und durchgefärbtes Glas auf der Rückseite, das extrem ...
#     TITLE: iPhone 16 und iPhone 16 Plus - Apple (DE)
#     SITELINKS:
#       SITELINKS:
#       EXPANDED ITEMS:
#         EXPANDED-ITEM-1:
#         URL: https://www.apple.com/de/iphone-16-pro/
#         TITLE: iPhone 16 Pro
#         EXPANDED-ITEM-2:
#         URL: https://www.apple.com/de/shop/buy-iphone/iphone-16-pro
#         TITLE: iPhone 16 Pro kaufen
#     URL_SHOWN: https://www.apple.com› iphone-16
#     FAVICON_TEXT: Apple
#     ORGANIC-ITEM-2:
#     POS: 2
#     URL: https://www.idealo.de/preisvergleich/OffersOfProduct/204736899_-iphone-16-apple.html
#     DESC: 5 Farben sind erhältlich: Schwarz, Blau, Grün, Pink und Weiß. Verbessert wurde die Wasserdichtigkeit. Das iPhone 16 soll die obligatorischen 30 Minuten für die ...
#     TITLE: Apple iPhone 16 ab 737,80 € (April 2025 Preise)
#     RATING: 4.9
#     CURRENCY: € bis
#     URL_SHOWN: https://www.idealo.de› ... › Handys & Smartphones
#     PRICE_LOWER: 737.8
#     PRICE_UPPER: 1657.6
#     FAVICON_TEXT: Idealo
#     REVIEW_COUNT: 10
#     ADDITIONAL_INFO ITEMS:
#       ADDITIONAL_INFO-ITEM-1: 737,80 € bis 1.657,60 €
#       ADDITIONAL_INFO-ITEM-2: Auf Lager
#       ADDITIONAL_INFO-ITEM-3: 4,9(10)   Rezensionen werden von der Google Suche nicht überprüft
#     ORGANIC-ITEM-3:
#     POS: 3
#     URL: https://www.mediamarkt.de/de/brand/apple/iphone/iphone-16-pro
#     DESC: Europas Elektromarkt Nummer 1! Entdecken Sie jetzt das große Angebot und bestellen Sie direkt online.
#     TITLE: Apple iPhone 16 Pro kaufen
#     URL_SHOWN: https://www.mediamarkt.de› Marken › Apple › iPhone
#     FAVICON_TEXT: MediaMarkt
#     ORGANIC-ITEM-4:
#     POS: 4
#     URL: https://www.apple.com/de/iphone/
#     DESC: Entwickelt für Apple Intelligence. Entdecke das neue iPhone 16e zusammen mit dem iPhone 16 Pro, iPhone 16 und iPhone 15.
#     TITLE: iPhone
#     URL_SHOWN: https://www.apple.com› iphone
#     FAVICON_TEXT: Apple
#     ORGANIC-ITEM-5:
#     POS: 5
#     URL: https://www.simplytel.de/handys/apple/iphone-16
#     DESC: Das iPhone 16 günstig mit Handyvertrag kaufen ✓ Einfach günstigen Tarif zum Apple-Handy wählen und online bestellen ✓ schnelle Lieferung.
#     TITLE: Apple iPhone 16 mit Vertrag bestellen
#     URL_SHOWN: https://www.simplytel.de› Handys › Apple Handys
#     FAVICON_TEXT: SimplyTel
#     ORGANIC-ITEM-6:
#     POS: 6
#     URL: https://www.giga.de/tech/halbzeit-fuer-das-iphone-16-warum-sich-der-kauf-fuer-mich-jetzt-nicht-lohnt--01JPAFTMR5EG89KE1N3WQFN8FM
#     DESC: 16.03.2025 — Das iPhone 16 Pro ist, wie bereits festgestellt, ausgereift und aktuell so günstig wie nie zuvor. Wer ein iPhone-Upgrade sucht, für den ist die ...
#     TITLE: Halbzeit für das iPhone 16: Warum sich der Kauf für mich jetzt ...
#     URL_SHOWN: https://www.giga.de› Tech › Apple
#     FAVICON_TEXT: giga.de
#     ORGANIC-ITEM-7:
#     POS: 7
#     URL: https://tarifbestellen.t-online.de/apple-iphone-16-plus-43256
#     DESC: Das iPhone 16 Pro ist vor Wasser und Staub geschützt. Es hat zusätzlich unseren Ceramic Shield der neuesten Generation, der 2x härter ist als jedes andere ...
#     TITLE: Apple iPhone 16 Pro
#     URL_SHOWN: https://tarifbestellen.t-online.de› apple-iphone-16-plus-4...
#     FAVICON_TEXT: T-Online
#
#   PAID RESULTS ITEMS:
#     PAID-ITEM-1:
#     POS: 1
#     URL: https://www.apple.com/de/iphone-16/
#     DESC: Fünf leuchtende Farben. A18 Chip. Weitere Infos zum neuen iPhone 16. iPhone 16 ab 949 €. Zinsfrei in 24 Raten.
#     TITLE: iPhone 16 | Offizielle Apple Website
#     DATA_RW: https://www.google.com/aclk?sa=l&ai=DChcSEwix3-2pzfCMAxVXPAYAHQPLBOcYABAsGgJ3cw&co=1&gclid=EAIaIQobChMIsd_tqc3wjAMVVzwGAB0DywTnEAAYASAAEgIvbvD_BwE&sig=AOD64_0l1kDv6s5m-Tbk5FNEs9sUatE0IA&q&adurl
#     DATA_PCU ITEMS:
#       DATA_PCU-ITEM-1: https://www.apple.com/
#     SITELINKS:
#       SITELINKS:
#       INLINE ITEMS:
#         INLINE-ITEM-1:
#         URL: https://www.apple.com/de/shop/go/iphone_16/specs/?
#         TITLE: Technische Daten
#         INLINE-ITEM-2:
#         URL: https://www.apple.com/de/shop/go/buy_iphone/?
#         TITLE: iPhone kaufen
#         INLINE-ITEM-3:
#         URL: /aclk?sa=l&ai=DChcSEwix3-2pzfCMAxVXPAYAHQPLBOcYABBFGgJ3cw&co=1&gclid=EAIaIQobChMIsd_tqc3wjAMVVzwGAB0DywTnEAAYASAEEgKagvD_BwE&sig=AOD64_17y7qIgNvRPTu-p7GFfI4E2L9mPA&adurl=&q=
#         TITLE: Noch längere Batterielaufzeit
#         INLINE-ITEM-4:
#         URL: /aclk?sa=l&ai=DChcSEwix3-2pzfCMAxVXPAYAHQPLBOcYABBGGgJ3cw&co=1&gclid=EAIaIQobChMIsd_tqc3wjAMVVzwGAB0DywTnEAAYASAFEgL4vfD_BwE&sig=AOD64_0kGLosJ9VkkG5NzlWDA578uiaBpQ&adurl=&q=
#         TITLE: Ganz neue Kameras
#     URL_SHOWN: https://www.apple.com › de
#     PAID-ITEM-2:
#     POS: 2
#     URL: https://www.klarmobil.de/handys-mit-vertrag/apple/iphone-16/P-M-3743921-P-3852440/
#     DESC: 5G Allnet Flat, D-Netz Qualität & iPhone 16. Gleich online bestellen und sparen.
#     TITLE: Unser iPhone 16 Deal | Das Angebot für iPhone-Fans
#     DATA_RW: https://www.google.com/aclk?sa=l&ai=DChcSEwix3-2pzfCMAxVXPAYAHQPLBOcYABAnGgJ3cw&co=1&gclid=EAIaIQobChMIsd_tqc3wjAMVVzwGAB0DywTnEAAYAiAAEgLvDfD_BwE&sig=AOD64_1OpqMFXh3arO6oCrSFfSHo9zmWbw&q&adurl
#     DATA_PCU ITEMS:
#       DATA_PCU-ITEM-1: https://www.klarmobil.de/
#     URL_SHOWN: https://www.klarmobil.de
#     PAID-ITEM-3:
#     POS: 3
#     URL: /aclk?sa=l&ai=DChcSEwix3-2pzfCMAxVXPAYAHQPLBOcYABAuGgJ3cw&co=1&gclid=EAIaIQobChMIsd_tqc3wjAMVVzwGAB0DywTnEAMYASAAEgI6X_D_BwE&sig=AOD64_1Kd06_MuTV9YtdFHZiMJZUf33giw&adurl=&q=
#     DESC: iPhone 16 mit yourfone erleben — yourfone Allnet Flat –Telefonieren und Surfen zum besten Preis. Allnet Flat mit iPhone 16...
#     TITLE: iPhone 16 zum Top Preis
#     DATA_RW: https://www.google.com/aclk?sa=l&ai=DChcSEwix3-2pzfCMAxVXPAYAHQPLBOcYABAuGgJ3cw&co=1&gclid=EAIaIQobChMIsd_tqc3wjAMVVzwGAB0DywTnEAMYASAAEgI6X_D_BwE&sig=AOD64_1Kd06_MuTV9YtdFHZiMJZUf33giw&q&adurl
#     DATA_PCU ITEMS:
#       DATA_PCU-ITEM-1: https://www.yourfone.de/
#     SITELINKS:
#       SITELINKS:
#       INLINE ITEMS:
#         INLINE-ITEM-1:
#         URL: https://www.yourfone.de/handys/apple/iphone-16
#         TITLE: iPhone 16
#         INLINE-ITEM-2:
#         URL: https://www.yourfone.de/handys/apple/iphone-16-pro
#         TITLE: iPhone 16 Pro
#         INLINE-ITEM-3:
#         URL: https://www.yourfone.de/handys/apple/iphone-15-pro-max
#         TITLE: iPhone 16 Pro Max
#         INLINE-ITEM-4:
#         URL: /aclk?sa=l&ai=DChcSEwix3-2pzfCMAxVXPAYAHQPLBOcYABBHGgJ3cw&co=1&gclid=EAIaIQobChMIsd_tqc3wjAMVVzwGAB0DywTnEAMYASAFEgK1DvD_BwE&sig=AOD64_3K9W0VcY4bTziVFMXwFkFlwGrxTg&adurl=&q=
#         TITLE: yourfone Tarif + iPhone 16
#         INLINE-ITEM-5:
#         URL: https://www.yourfone.de/handys/apple
#         TITLE: Top Angebote:
#     URL_SHOWN: https://www.yourfone.de
#
#   POPULAR PRODUCTS ITEMS:
#     POPULAR_PRODUCTS-ITEM-1:
#     ITEMS ITEMS:
#       ITEMS-ITEM-1:
#       POS: 1
#       PRICE: 824,00 €
#       TITLE: Apple iPhone 16
#       RATING: 4.4
#       SELLER: Amazon.de
#       CURRENCY: EUR
#       DESCRIPTION: Amazon.de & mehr
#       RATING_COUNT: 3315
#       ITEMS-ITEM-2:
#       POS: 2
#       PRICE: 1.089,00 €
#       TITLE: Apple iPhone 16 Pro
#       RATING: 4.3
#       SELLER: MediaMarkt
#       CURRENCY: EUR
#       DESCRIPTION: MediaMarkt & mehr
#       RATING_COUNT: 5721
#       ITEMS-ITEM-3:
#       POS: 3
#       PRICE: 974,99 €
#       TITLE: Apple iPhone 16 Plus
#       RATING: 4.4
#       SELLER: DeutschlandCard
#       CURRENCY: EUR
#       DESCRIPTION: DeutschlandCard & mehr
#       RATING_COUNT: 1255
#       ITEMS-ITEM-4:
#       POS: 4
#       PRICE: 1.136,80 €
#       TITLE: Apple iPhone 16 Pro Max
#       RATING: 4.3
#       SELLER: idealo Preisvergleich
#       CURRENCY: EUR
#       DESCRIPTION: idealo Preisvergleich & mehr
#       RATING_COUNT: 8333
#       ITEMS-ITEM-5:
#       POS: 5
#       PRICE: 39,90 € jetzt
#       TITLE: iPhone 16 128GB pink mit Vertrag inkl. All-Net-Flat neu bei 1&1
#       SELLER: 1&1
#       CURRENCY: € jetzt
#       DESCRIPTION: 1&1
#       PREVIOUS_PRICE: 32,99 €/Monat x 36
#       ITEMS-ITEM-6:
#       POS: 6
#       PRICE: 1,00 € jetzt
#       TITLE: Apple iPhone 16 128 GB schwarz mit congstar Allnet Flat S mit GB+ Vertrag und Ratenzahlung
#       RATING: 4.4
#       SELLER: congstar
#       CURRENCY: € jetzt
#       DESCRIPTION: congstar
#       RATING_COUNT: 17657
#       PREVIOUS_PRICE: 39 €/Monat x 36
#       ITEMS-ITEM-7:
#       POS: 7
#       PRICE: 1,00 € jetzt
#       TITLE: Apple iPhone 16 | o2 Mobile Unlimited Max Vertrag | 128 GB | Farbe: schwarz
#       RATING: 4.7
#       SELLER: o2 Online
#       CURRENCY: € jetzt
#       DESCRIPTION: o2 Online
#       RATING_COUNT: 5956
#       PREVIOUS_PRICE: 39 €/Monat x 24
#       ITEMS-ITEM-8:
#       POS: 8
#       PRICE: 1,00 € jetzt
#       TITLE: Apple iPhone 16 128 GB weiß mit congstar Allnet Flat S mit GB+ Vertrag und Ratenzahlung
#       RATING: 4.4
#       SELLER: congstar
#       CURRENCY: € jetzt
#       DESCRIPTION: congstar
#       RATING_COUNT: 3315
#       PREVIOUS_PRICE: 39 €/Monat x 36
#     POPULAR_PRODUCTS-ITEM-2:
#     ITEMS ITEMS:
#       ITEMS-ITEM-1:
#       POS: 1
#       PRICE: 279,00 € jetzt
#       TITLE: Apple iPhone 16 Pro 512 GB titan schwarz mit congstar Allnet Flat XS mit GB+ Vertrag und Ratenzahlung
#       RATING: 4.3
#       SELLER: congstar
#       CURRENCY: € jetzt
#       DESCRIPTION: congstar
#       RATING_COUNT: 5721
#       PREVIOUS_PRICE: 46 €/Monat x 36
#       ITEMS-ITEM-2:
#       POS: 2
#       PRICE: 39,90 € jetzt
#       TITLE: iPhone 16 128GB weiß mit Vertrag inkl. All-Net-Flat neu bei 1&1
#       RATING: 4.4
#       SELLER: 1&1
#       CURRENCY: € jetzt
#       DESCRIPTION: 1&1
#       RATING_COUNT: 17657
#       PREVIOUS_PRICE: 39,99 €/Monat x 24
#       ITEMS-ITEM-3:
#       POS: 3
#       PRICE: 39,90 € jetzt
#       TITLE: iPhone 16 128GB blaugrün mit Vertrag inkl. All-Net-Flat neu bei 1&1
#       RATING: 4.4
#       SELLER: 1&1
#       CURRENCY: € jetzt
#       DESCRIPTION: 1&1
#       RATING_COUNT: 17657
#       PREVIOUS_PRICE: 39,99 €/Monat x 24
#       ITEMS-ITEM-4:
#       POS: 4
#       PRICE: 39,90 € jetzt
#       TITLE: iPhone 16 128GB schwarz mit Vertrag inkl. All-Net-Flat neu bei 1&1
#       RATING: 4.4
#       SELLER: 1&1
#       CURRENCY: € jetzt
#       DESCRIPTION: 1&1
#       RATING_COUNT: 17657
#       PREVIOUS_PRICE: 39,99 €/Monat x 24
#       ITEMS-ITEM-5:
#       POS: 5
#       PRICE: 139,98 € jetzt
#       TITLE: Apple iPhone 16 128 GB Blaugrün + yourfone Allnet Flat 50 GB Vertrag
#       RATING: 4.9
#       SELLER: yourfone.de
#       CURRENCY: € jetzt
#       DESCRIPTION: yourfone.de
#       RATING_COUNT: 90
#       PREVIOUS_PRICE: 27,99 €/Monat x 36
#       ITEMS-ITEM-6:
#       POS: 6
#       PRICE: 139,98 € jetzt
#       TITLE: Apple iPhone 16 128 GB Schwarz + yourfone Allnet Flat 50 GB Vertrag
#       RATING: 4.4
#       SELLER: yourfone.de
#       CURRENCY: € jetzt
#       DESCRIPTION: yourfone.de
#       RATING_COUNT: 17657
#       PREVIOUS_PRICE: 27,99 €/Monat x 36
#       ITEMS-ITEM-7:
#       POS: 7
#       PRICE: 39,90 € jetzt
#       TITLE: iPhone 16 128GB ultramarin mit Vertrag inkl. All-Net-Flat neu bei 1&1
#       SELLER: 1&1
#       CURRENCY: € jetzt
#       DESCRIPTION: 1&1
#       PREVIOUS_PRICE: 32,99 €/Monat x 36
#       ITEMS-ITEM-8:
#       POS: 8
#       PRICE: 159,98 € jetzt
#       TITLE: Apple iPhone 16 128 GB Ultramarin + yourfone Allnet Flat 5 GB Vertrag
#       RATING: 4.7
#       SELLER: yourfone.de
#       CURRENCY: € jetzt
#       DESCRIPTION: yourfone.de
#       RATING_COUNT: 5956
#       PREVIOUS_PRICE: 20,99 €/Monat x 36
#
#   PRODUCT LISTING ADS (PLA):
#   ITEMS ITEMS:
#     ITEMS-ITEM-1:
#     POS: 1
#     URL: https://www.congstar.de/portal/geraete/apple/apple-iphone-16-pro/?deviceVariantId=303711&planId=486&installmentPlanId=501&sp=gosh
#     PRICE: 39,00 €
#     TITLE: Apple iPhone 16 Pro 128 GB titan wüstensand mit congstar Allnet Flat L mit GB+ Vertrag und Ratenzahlung
#     SELLER: congstar
#     URL_IMAGE: https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcSNaQGyB3SFzQeiwScG5O1izivRRdeolyzuasSZwRoGJWEvoSCxAu_rOlu6rvlLkhdH2tvf358GZUSWWFmKyXA5ROKiuffT1polVUPA603_dovfN4h-W9KNrINv&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-2:
#     POS: 2
#     URL: https://www.netto-online.de/apple-iphone-16-128gb-schwarz-5g-smartphone-neu-ovp/p-2823915000?RefID=Shopping_Google_2823915000&utm_source=google&utm_medium=shopping&utm_campaign=2823915000
#     PRICE: 795,00 €
#     TITLE: Apple iPhone 16, 128GB, Schwarz, 5G, Smartphone NEU OVP
#     SELLER: Netto Online-Shop
#     URL_IMAGE: https://encrypted-tbn1.gstatic.com/shopping?q=tbn:ANd9GcQb9vPp4CxFR_10qT31dGvva568lUEtfpY6C5Z9Z8T0W0BNFLqubXzfDak4UIrIqMBV7rzH34EPGpjcBIVnF5ycbhiAndvNJW2lAzwEkGEH873JmBQ3LzEVLxS6D7ZldiRKDxlsY1o&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-3:
#     POS: 3
#     URL: https://www.blau.de/e-shop/apple/apple-iphone-16-128gb-blaugruen-details?zielgruppe=privatkunden&tarif=blau-allnet-l&ratenzahlung=24&render-schema=nein
#     PRICE: 1,00 €
#     TITLE: Apple iPhone 16 | 128 GB | Farbe: blau | 30 GB statt 25 GB Vertrag bei Blau
#     SELLER: Blau
#     URL_IMAGE: https://encrypted-tbn1.gstatic.com/shopping?q=tbn:ANd9GcR6jdmpRK-7Q2UcZMSKarK9497S7Z5QE9gpfwFBOM_VmiIMkz4B_eF042BaUJpnRk630Sm5XHJKIUTv-UyPTxb0XudjnfARhv5obiDtosx0pgSK7DBXRm0mEU2V8PFF8AoH8tTXs1ImyQ&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-4:
#     POS: 4
#     URL: https://www.cyberport.de/?DEEP=A415-1XJ
#     PRICE: 799,00 €
#     TITLE: Apple iPhone 16 128 GB Schwarz MYE73ZD/A
#     SELLER: Cyberport
#     URL_IMAGE: https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcSCR8yb-9zvRoexYD0-i0SQcQ1rK8w4KDw1jjb-mSF6VCGNKve1PzkzHMpjqdZeyWbHNRXKDVBrZ2YhWedSOQYnVhZsyFf4y5MimFxTHqBcZ26dC0kGUEWtPFrj4FhA7o0LaVXRsA&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-5:
#     POS: 5
#     URL: https://www.backmarket.de/de-de/p/gb/0ef61aea-3229-410a-9fa3-f0f992bf7b5f?shopping=gmc
#     PRICE: 765,00 €
#     TITLE: iPhone 16 256GB - Rosé - Ohne Vertrag
#     SELLER: Back Market
#     URL_IMAGE: https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcT5W_Lo5oMr6GRVp1bBgcaU6TUmmzy2u1mIoK5mHSU10RbQSzWiSFsORXJiX4SOmlmYFpSGw--tjB1rz-D_IgqxJqrL1n4pSAy5KpuseKEDujCbCVQkC0qTXFs-Gxr362Dashbbeg&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-6:
#     POS: 6
#     URL: https://www.backmarket.de/de-de/p/gb/ec59a99a-dd17-468a-b5aa-fbbddd1c87b5?shopping=gmc
#     PRICE: 730,00 €
#     TITLE: iPhone 16 128GB - Weiß - Ohne Vertrag
#     SELLER: Back Market
#     URL_IMAGE: https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcSZz97AQr0DhpqjiutcP9b3KjdUm-hiYR8ZPVvIZEvsFOsVbsv8vYVsQEtRcpP9kUMyjg-u3_AiVX99duT5rQ8tyQOcWS2eMNKObn3FgEt2mgWeGTitheX4yLK5ltjcgcT0y5V4kw&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-7:
#     POS: 7
#     URL: https://www.galaxus.de/de/s1/product/apple-iphone-16-128-gb-teal-610-sim-esim-48-mpx-5g-smartphone-49221147?utm_campaign=organicshopping&utm_source=google&utm_medium=organic&utm_content=11480124&supplier=11480124
#     PRICE: 779,00 €
#     TITLE: Apple iPhone 16 (128 GB, Teal, 6.10", SIM + eSIM, 48 Mpx, 5G), Smartphone, Grün
#     SELLER: Galaxus
#     URL_IMAGE: https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcTlXh8JFJd9WusqqrWUCAaQmBpUkV0lbImIWFtT4455KcOlBrYpI-ZkRlvZcxAbHO4U9BeVkEaKGNdqnCJknuzEczZtGmUjJdTUqFNqQDJLOHML-Krvre_Qj1BZ&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-8:
#     POS: 8
#     URL: https://www.kaufland.de/product/508045526/?utm_source=shopping&utm_medium=non-paid&utm_campaign=pricecomparison&sid=70343820
#     PRICE: 775,00 €
#     TITLE: Apple iPhone 16 15,5 cm (6.1") Dual-SIM iOS 18 5G USB Typ-C 128 GB Weiß
#     SELLER: Kaufland.de
#     URL_IMAGE: https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcRWnjwuXf0PRCIdV0PnJDvmJ-_glzqvcB8vzqBsxoJ61atdZN6d6p6BLwC76x1IgyOKjh3Ej5nV2eGSu2ZgKC2GJNzFs6o9EVG6pjPKVIjOL-c7Nuar5dqXgg&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-9:
#     POS: 9
#     URL: https://www.clevertronic.de/kaufen/handy-kaufen/apple/iphone-16/auswahl/21829/apple-iphone-16-128gb-schwarz?ok=0
#     PRICE: 784,99 €
#     TITLE: Apple iPhone 16 128GB Schwarz Neu
#     SELLER: Clevertronic.de
#     URL_IMAGE: https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcTnBwRPdbriEYoVa4ZJjEC8viM5cNAAUnJSn2EYMR6JybmqD2I2oeboCLyP2FPAOtABvln0JxjXQ6Y_8mx8ZZJPrJTrKQCoYkCIXj_SaOHzey7UuKobGIxTQU7gs0JlTARoDMzVOw&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-10:
#     POS: 10
#     URL: https://www.billiger.de/products/5048601355-apple-iphone-16-128-gb-schwarz?mc=YBvRT6skMgNx
#     PRICE: 725,00 €
#     TITLE: Apple iPhone 16 128 GB Schwarz
#     SELLER: billiger.de
#     URL_IMAGE: https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcSwEIRDnF7wJE-ehe9WpVqsRWV3AeCN_hap4usaseWOtg-J7hZNGu8DhEKLaKkR6dJ1Ba7scHV2Ny-1p13RAqSwursmSjYHOYE3LfjS_8uF7tqb-xf0mynUpZ5DITRoIA5D9PbMfbaPlVg&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-11:
#     POS: 11
#     URL: https://www.backmarket.de/de-de/p/gb/7f5bdd13-8f4b-49ee-a94a-8b578deb328d?shopping=gmc
#     PRICE: 726,00 €
#     TITLE: iPhone 16 128GB - Blaugrün - Ohne Vertrag
#     SELLER: Back Market
#     URL_IMAGE: https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcQeLvRcOGCKN_2jDXd3fYNx9g0Dsi0t8ruxUlR3MGt3H53LrZ6E0UULujz1B16gLVlYJ7z0vovc6R5AA3a5XsdJ7OaMIstoPz8kTDYKm44b6_YXKuUvBjgNxFUOKQKTO0SVdqB1BQ&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-12:
#     POS: 12
#     URL: https://www.congstar.de/portal/geraete/apple/apple-iphone-16/?deviceVariantId=303694&planId=484&installmentPlanId=501&sp=gosh
#     PRICE: 1,00 €
#     TITLE: Apple iPhone 16 128 GB ultramarin mit congstar Allnet Flat M mit GB+ Vertrag und Ratenzahlung
#     SELLER: congstar
#     URL_IMAGE: https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcRIHDvGHm-ZFQW4HlfE0BsjbcFDeGs1wNX5HasuxbMJ4e97vzyefq8OJYhHVPMZZjA3CNnA73KxUD25Q6dobE2cM-3zt4aFATmP4uNWx_N52Iu4bk8dCkhMZCXc&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-13:
#     POS: 13
#     URL: https://www.vodafone.de/privat/handys/iphone-16-pro.html?tariffId=137&atomicId=56806
#     PRICE: 1,00 €
#     TITLE: iPhone 16 Pro Titan Wüstensand (128 GB), Handy mit Vertrag (24 Ratenzahlungen), GigaMobil XL mit unbegrenzten GB bei Vodafone
#     SELLER: Vodafone
#     URL_IMAGE: https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcT57JBlQI-D4s_vn6kc5xwNJog5MBuBuU-yMHkFLrsuFs9f_a43iEiEjNcMKkb3qrAITvnHSORaqe5z5ypWO4JzK3Eo0a_eE2Z_BUUEhL2brs0VxA6Y0mijjKSUBwI2Mg&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-14:
#     POS: 14
#     URL: https://www.congstar.de/portal/geraete/apple/apple-iphone-16/?deviceVariantId=303695&planId=484&installmentPlanId=501&sp=gosh
#     PRICE: 1,00 €
#     TITLE: Apple iPhone 16 128 GB blaugrün mit congstar Allnet Flat M mit GB+ Vertrag und Ratenzahlung
#     SELLER: congstar
#     URL_IMAGE: https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcSL9IUjyJki_JKO1ha6LcCYwymePUn_BuEGRwK5z87XBdzdqXCGL4YDiuihK6i3l7KS76NtiEUk_5f7mV5BPRA9VpGAiv22APp6DKHj99jmyrobrKz_cqtpKNXn&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-15:
#     POS: 15
#     URL: https://www.backmarket.de/de-de/p/gb/ad6dc074-aa15-4f0a-bc2f-a4211fee9aec?shopping=gmc
#     PRICE: 730,00 €
#     TITLE: iPhone 16 128GB - Ultramarin - Ohne Vertrag
#     SELLER: Back Market
#     URL_IMAGE: https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcSLRzFjLA6NQnMhaobyt4b-aBqEaw9qx5OxKKq_Plj9ar-y4Y5AiqvTXYatFFBJL4PGf2G1JL2xwT1MNhWT60TSvdIaJauF1Uhl35ao-lVHDRhqe1ozyUALL8QDDJuHDXUmfLjhDw&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#     ITEMS-ITEM-16:
#     POS: 16
#     URL: https://www.kaufland.de/product/508045533/?utm_source=shopping&utm_medium=non-paid&utm_campaign=pricecomparison&sid=27587434
#     PRICE: 905,34 €
#     TITLE: Apple iPhone 16 256 GB Dual-Sim Teal Neuwertig
#     SELLER: Kaufland.de
#     URL_IMAGE: https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcSPjdN8fmQFYZ9xDQVtkNKMsrx-MHUx507N71DH89GKuBzw7Cfra3SJVACKjSDE6bB0ZFSD69KRhO0Cnk3LMsF2zUOpB1XmE82YGPYui-dQ&usqp=CAc
#     IMAGE_DATA: Redacted base64 image string...
#
#   SEARCH INFORMATION:
#   QUERY: Iphone 16
#   SHOWING_RESULTS_FOR: Iphone 16
#   TOTAL_RESULTS_COUNT: 2780000000
#
#   RELATED SEARCHES ITEMS:
#     RELATED_SEARCHES-ITEM-1:
#     RELATED_SEARCHES ITEMS:
#       RELATED_SEARCHES-ITEM-1: iPhone 16 Pro Max
#       RELATED_SEARCHES-ITEM-2: iphone 16: was ist neu
#       RELATED_SEARCHES-ITEM-3: iPhone 16 kaufen
#       RELATED_SEARCHES-ITEM-4: iPhone 16 SATURN
#       RELATED_SEARCHES-ITEM-5: iPhone 16 MediaMarkt
#
#   RELATED QUESTIONS:
#   ITEMS ITEMS:
#     ITEMS-ITEM-1:
#     POS: 1
#     ANSWER: September 2024, hat Apple den Startschuss für die iPhone 16 Vorbestellungen gegeben. Das offizielle Erscheinungsdatum war eine Woche darauf am Freitag, den 20. September 2024. Im nächsten Jahr hat Apple mit dem iPhone 16e im Februar 2025 nachgelegt.
#     QUESTION: Wann kommt das nächste iPhone 16 raus?
#     ITEMS-ITEM-2:
#     POS: 2
#     ANSWER: Apple iPhone 16 ab 737,80 € (April 2025 Preise)
#     QUESTION: Wie viel wird das iPhone 16 Kosten?
#     ITEMS-ITEM-3:
#     POS: 3
#     ANSWER: iPhone 17: ab 1.360 Euro. iPhone 17 Air: ab 1.580 Euro. iPhone 17 Pro: ab 1.715 Euro.14.04.2025
#     QUESTION: Wie viel kostet ein iPhone 17?
#     ITEMS-ITEM-4:
#     POS: 4
#     ANSWER: 16: Wichtige Unterschiede bei Akku und Performance. Ein entscheidender Vorteil des iPhone 16 gegenüber dem iPhone 15 liegt in der Performance. Während das iPhone 15 mit dem A16 Bionic Chip bereits eine starke Leistung bietet, setzt das iPhone 16 mit dem A18 Chip neue Maßstäbe beim Standardmodell​.
#     QUESTION: Was ist besser, iPhone 15 oder 16?

# %% [markdown]
# ## More examples

# %% [markdown]
# ### Amazon Product data

# %%
from llama_index.readers.oxylabs import OxylabsAmazonProductReader


amazon_product_reader = OxylabsAmazonProductReader(
    oxylabs_username, oxylabs_password
)

docs = amazon_product_reader.load_data(
    {
        "domain": "com",
        "query": "B08D9N7RJ4",
        "parse": True,
        "context": [{"key": "autoselect_variant", "value": True}],
    }
)

# %% [markdown]
# ### YouTube Transcript

# %%
from llama_index.readers.oxylabs import OxylabsYoutubeTranscriptsReader


youtube_transcript_reader = OxylabsYoutubeTranscriptsReader(
    oxylabs_username, oxylabs_password
)

docs = youtube_transcript_reader.load_data(
    {
        "query": "SLoqvcnwwN4",
        "context": [
            {"key": "language_code", "value": "en"},
            {"key": "transcript_origin", "value": "uploader_provided"},
        ],
    }
)
