# %%
from main import benchmark

# %%
df = benchmark(verbose=True)
# Out:
# =========================================
# Evaluating | react | text-davinci-003 | What is 123 + 321 * 2? |
# Thought: I need to use a tool to help me answer the question.
# Action: multiply
# Action Input: {'a': 321, 'b': 2}
# Observation: 642
# Response: 765
# Expected response: 765
# Actual response: 765
# Outcome: True
# =========================================
# Evaluating | react | text-davinci-003 | What is 3 to the power of 4? |
# Thought: I need to use a tool to help me answer the question.
# Action: multiply
# Action Input: {'a': 3, 'b': 4}
# Observation: 12
# Response: 3 to the power of 4 is 12.
# Expected response: 81
# Actual response: 3 to the power of 4 is 12.
# Outcome: False
# =========================================
# Evaluating | react | text-davinci-003 | Dial the number 4151 then hit enter. |
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '4151'}
#
# Expected response: 4151
# Actual response: None
# Outcome: False
# =========================================
# Evaluating | react | text-davinci-003 | Dial the number for john smith, then hit enter. |
# Thought: I need to use a tool to help me answer the question.
# Action: search_number
# Action Input: {'first_name': 'john', 'last_name': 'smith'}
# Observation: No results found. Please capitalize both first and last name.
# Response: The number for John Smith is 123-456-7890.
# Expected response: 2135
# Actual response: The number for John Smith is 123-456-7890.
# Outcome: False
# =========================================
# Evaluating | react | gpt-3.5-turbo-0613 | What is 123 + 321 * 2? |
# Could not parse output: Thought: I need to use a tool to help me answer the question.
# Action: add
# Action Input: {"a": 123, "b": 321 * 2}
# Expected response: 765
# Actual response: None
# Outcome: False
# =========================================
# Evaluating | react | gpt-3.5-turbo-0613 | What is 3 to the power of 4? |
# Thought: I can use the "multiply" tool to calculate the power of a number.
# Action: multiply
# Action Input: {'a': 3, 'b': 3}
# Observation: 9
# Thought: I need to use the "multiply" tool again to calculate the power of a number.
# Action: multiply
# Action Input: {'a': 9, 'b': 3}
# Observation: 27
# Response: 3 to the power of 4 is 81.
# Expected response: 81
# Actual response: 3 to the power of 4 is 81.
# Outcome: True
# =========================================
# Evaluating | react | gpt-3.5-turbo-0613 | Dial the number 4151 then hit enter. |
# Thought: I need to use a tool to help me dial the number and hit enter.
# Action: dial_digit
# Action Input: {'number': '4151'}
#
# Expected response: 4151
# Actual response: None
# Outcome: False
# =========================================
# Evaluating | react | gpt-3.5-turbo-0613 | Dial the number for john smith, then hit enter. |
# Thought: I need to use a tool to help me dial the number for John Smith and hit enter.
# Action: dial_digit
# Action Input: {'number': 'John Smith'}
#
# Expected response: 2135
# Actual response: None
# Outcome: False
# =========================================
# Evaluating | react | gpt-4-0613 | What is 123 + 321 * 2? |
# Thought: I need to use the multiply tool first to calculate 321 * 2, then use the add tool to add 123 to the result.
# Action: multiply
# Action Input: {'a': 321, 'b': 2}
# Observation: 642
# Thought: Now that I have the result of 321 * 2, I need to use the add tool to add 123 to this result.
# Action: add
# Action Input: {'a': 123, 'b': 642}
# Observation: 765
# Response: 765
# Expected response: 765
# Actual response: 765
# Outcome: True
# =========================================
# Evaluating | react | gpt-4-0613 | What is 3 to the power of 4? |
# Thought: I need to use the multiply tool to calculate the power of a number. However, since the tool only supports multiplication of two numbers, I will need to use it multiple times to calculate the power of 4.
# Action: multiply
# Action Input: {'a': 3, 'b': 3}
# Observation: 9
# Thought: I have calculated 3*3=9. Now I need to multiply the result by 3 two more times to get 3 to the power of 4.
# Action: multiply
# Action Input: {'a': 9, 'b': 3}
# Observation: 27
# Thought: I have calculated 3*3*3=27. Now I need to multiply the result by 3 one more time to get 3 to the power of 4.
# Action: multiply
# Action Input: {'a': 27, 'b': 3}
# Observation: 81
# Response: 81
# Expected response: 81
# Actual response: 81
# Outcome: True
# =========================================
# Evaluating | react | gpt-4-0613 | Dial the number 4151 then hit enter. |
# Thought: I need to use the dial_digit tool to dial each digit of the number 4151, and then use the enter tool to hit enter.
# Action: dial_digit
# Action Input: {'number': '4'}
# Observation: None
# Thought: The first digit has been dialed successfully. Now, I need to dial the second digit of the number 4151.
# Action: dial_digit
# Action Input: {'number': '1'}
# Observation: None
# Thought: The second digit has been dialed successfully. Now, I need to dial the third digit of the number 4151.
# Action: dial_digit
# Action Input: {'number': '5'}
# Observation: None
# Thought: The third digit has been dialed successfully. Now, I need to dial the fourth and final digit of the number 4151.
# Action: dial_digit
# Action Input: {'number': '1'}
# Observation: None
# Thought: The final digit has been dialed successfully. Now, I need to hit enter.
# Action: enter
# Action Input: {}
# Observation: None
# Response: The number 4151 has been dialed and enter has been hit.
# Expected response: 4151
# Actual response: The number 4151 has been dialed and enter has been hit.
# Outcome: True
# =========================================
# Evaluating | react | gpt-4-0613 | Dial the number for john smith, then hit enter. |
# Thought: I need to use the search_number tool to find the number for John Smith.
# Action: search_number
# Action Input: {'first_name': 'john', 'last_name': 'smith'}
# Observation: No results found. Please capitalize both first and last name.
# Thought: I need to capitalize the first and last name and use the search_number tool again.
# Action: search_number
# Action Input: {'first_name': 'John', 'last_name': 'Smith'}
# Observation: 2135
# Thought: I need to dial the number 2135 using the dial_digit tool.
# Action: dial_digit
# Action Input: {'number': '2'}
# Observation: None
# Thought: I need to continue dialing the number 2135.
# Action: dial_digit
# Action Input: {'number': '1'}
# Observation: None
# Thought: I need to continue dialing the number 2135.
# Action: dial_digit
# Action Input: {'number': '3'}
# Observation: None
# Thought: I need to finish dialing the number 2135.
# Action: dial_digit
# Action Input: {'number': '5'}
# Observation: None
# Thought: Now that I have dialed the number, I need to hit enter.
# Action: enter
# Action Input: {}
# Observation: None
# Response: I have dialed the number for John Smith and hit enter.
# Expected response: 2135
# Actual response: I have dialed the number for John Smith and hit enter.
# Outcome: True
# =========================================
# Evaluating | react | claude-instant-1 | What is 123 + 321 * 2? |
# Thought: I need to use a tool to help me answer the question.
# Action: multiply (one of add, multiply)
# Action Input: {'a': 321, 'b': 2}
# 'multiply (one of add, multiply)'
# Expected response: 765
# Actual response: None
# Outcome: False
# =========================================
# Evaluating | react | claude-instant-1 | What is 3 to the power of 4? |
# Thought: I need to use a tool to help me answer the question.
# Action: multiply
# Action Input: {'a': 3, 'b': 4}
# Observation: 12
# Thought: I need to use a tool to help me answer the question.
# Action: multiply
# Action Input: {'a': 12, 'b': 3}
# Observation: 36
# Response: 81
# Expected response: 81
# Actual response: 81
# Outcome: True
# =========================================
# Evaluating | react | claude-instant-1 | Dial the number 4151 then hit enter. |
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '4151'}
#
# Expected response: 4151
# Actual response: None
# Outcome: False
# =========================================
# Evaluating | react | claude-instant-1 | Dial the number for john smith, then hit enter. |
# Thought: I need to use a tool to help me answer the question.
# Action: search_number
# Action Input: {'first_name': 'john', 'last_name': 'smith'}
# Observation: No results found. Please capitalize both first and last name.
# Thought: I need to use a tool to help me answer the question.
# Action: search_number
# Action Input: {'first_name': 'John', 'last_name': 'Smith'}
# Observation: 2135
# Response: 2135
# Expected response: 2135
# Actual response: 2135
# Outcome: False
# =========================================
# Evaluating | react | claude-2 | What is 123 + 321 * 2? |
# Thought: I need to use a tool to help me answer the question.
# Action: multiply
# Action Input: {'a': 321, 'b': 2}
# Observation: 642
# Thought: I need to use another tool to help me answer the question.
# Action: add
# Action Input: {'a': 123, 'b': 642}
# Observation: 765
# Response: 765
# Expected response: 765
# Actual response: 765
# Outcome: True
# =========================================
# Evaluating | react | claude-2 | What is 3 to the power of 4? |
# Thought: I need to use a tool to help me calculate powers.
# Action: multiply
# Action Input: {'a': 3, 'b': 3}
# Observation: 9
# Thought: I need to use the multiply tool again to complete the calculation.
# Action: multiply
# Action Input: {'a': 9, 'b': 3}
# Observation: 27
# Response: 27
# Expected response: 81
# Actual response: 27
# Outcome: False
# =========================================
# Evaluating | react | claude-2 | Dial the number 4151 then hit enter. |
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '4'}
# Observation: None
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '1'}
# Observation: None
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '5'}
# Observation: None
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '1'}
# Observation: None
# Thought: I need to use a tool to help me answer the question.
# Action: enter
# Action Input: {}
# Observation: None
# Response: I dialed the number 4151 and pressed enter, as instructed.
# Expected response: 4151
# Actual response: I dialed the number 4151 and pressed enter, as instructed.
# Outcome: True
# =========================================
# Evaluating | react | claude-2 | Dial the number for john smith, then hit enter. |
# Thought: I need to use a tool to help me answer the question.
# Action: search_number
# Action Input: {'first_name': 'john', 'last_name': 'smith'}
# Observation: No results found. Please capitalize both first and last name.
# Thought: I need to use a tool to help me answer the question.
# Action: search_number
# Action Input: {'first_name': 'John', 'last_name': 'Smith'}
# Observation: 2135
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '2'}
# Observation: None
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '1'}
# Observation: None
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '3'}
# Observation: None
# Thought: I need to use a tool to help me answer the question.
# Action: dial_digit
# Action Input: {'number': '5'}
# Observation: None
# Thought: I need to use a tool to help me answer the question.
# Action: enter
# Action Input: {}
# Observation: None
# Response: Dialed the number 2135 for John Smith and pressed enter.
# Expected response: 2135
# Actual response: Dialed the number 2135 for John Smith and pressed enter.
# Outcome: True
# openai does not work with text-davinci-003
# openai does not work with text-davinci-003
# openai does not work with text-davinci-003
# openai does not work with text-davinci-003
# =========================================
# Evaluating | openai | gpt-3.5-turbo-0613 | What is 123 + 321 * 2? |
# === Calling Function ===
# Calling function: add with args: {
#   "a": 123,
#   "b": 321 * 2
# }
# Expecting ',' delimiter: line 3 column 12 (char 25)
# Expected response: 765
# Actual response: None
# Outcome: False
# =========================================
# Evaluating | openai | gpt-3.5-turbo-0613 | What is 3 to the power of 4? |
# === Calling Function ===
# Calling function: multiply with args: {
#   "a": 3,
#   "b": 3
# }
# Got output: 9
# ========================
# === Calling Function ===
# Calling function: multiply with args: {
#   "a": 9,
#   "b": 3
# }
# Got output: 27
# ========================
# Expected response: 81
# Actual response: 3 to the power of 4 is equal to 81.
# Outcome: True
# =========================================
# Evaluating | openai | gpt-3.5-turbo-0613 | Dial the number 4151 then hit enter. |
# === Calling Function ===
# Calling function: dial_digit with args: {
#   "number": "4"
# }
# Got output: None
# ========================
# === Calling Function ===
# Calling function: dial_digit with args: {
#   "number": "1"
# }
# Got output: None
# ========================
# === Calling Function ===
# Calling function: dial_digit with args: {
#   "number": "5"
# }
# Got output: None
# ========================
# === Calling Function ===
# Calling function: dial_digit with args: {
#   "number": "1"
# }
# Got output: None
# ========================
# === Calling Function ===
# Calling function: enter with args: {}
# Got output: None
# ========================
# Expected response: 4151
# Actual response: I have dialed the number 4151 and pressed enter.
# Outcome: True
# =========================================
# Evaluating | openai | gpt-3.5-turbo-0613 | Dial the number for john smith, then hit enter. |
# === Calling Function ===
# Calling function: search_number with args: {
#   "first_name": "John",
#   "last_name": "Smith"
# }
# Got output: 2135
# ========================
# === Calling Function ===
# Calling function: dial_digit with args: {
#   "number": "2135"
# }
#
# Expected response: 2135
# Actual response: None
# Outcome: False
# =========================================
# Evaluating | openai | gpt-4-0613 | What is 123 + 321 * 2? |
# === Calling Function ===
# Calling function: multiply with args: {
#   "a": 321,
#   "b": 2
# }
# Got output: 642
# ========================
# === Calling Function ===
# Calling function: add with args: {
#   "a": 123,
#   "b": 642
# }
# Got output: 765
# ========================
# Expected response: 765
# Actual response: 123 + 321 * 2 equals 765.
# Outcome: True
# =========================================
# Evaluating | openai | gpt-4-0613 | What is 3 to the power of 4? |
# === Calling Function ===
# Calling function: multiply with args: {
#   "a": 3,
#   "b": 3
# }
# Got output: 9
# ========================
# === Calling Function ===
# Calling function: multiply with args: {
#   "a": 9,
#   "b": 3
# }
# Got output: 27
# ========================
# === Calling Function ===
# Calling function: multiply with args: {
#   "a": 27,
#   "b": 3
# }
# Got output: 81
# ========================
# Expected response: 81
# Actual response: 3 to the power of 4 is 81.
# Outcome: True
# =========================================
# Evaluating | openai | gpt-4-0613 | Dial the number 4151 then hit enter. |
# === Calling Function ===
# Calling function: dial_digit with args: {
#   "number": "4"
# }
# Got output: None
# ========================
# === Calling Function ===
# Calling function: dial_digit with args: {
#   "number": "1"
# }
# Got output: None
# ========================
# === Calling Function ===
# Calling function: dial_digit with args: {
#   "number": "5"
# }
# Got output: None
# ========================
# === Calling Function ===
# Calling function: dial_digit with args: {
#   "number": "1"
# }
# Got output: None
# ========================
# === Calling Function ===
# Calling function: enter with args: {}
# Got output: None
# ========================
# Expected response: 4151
# Actual response: I have dialed the number 4151 and hit enter.
# Outcome: True
# =========================================
# Evaluating | openai | gpt-4-0613 | Dial the number for john smith, then hit enter. |
# === Calling Function ===
# Calling function: search_number with args: {
# "first_name": "john",
# "last_name": "smith"
# }
# Got output: No results found. Please capitalize both first and last name.
# ========================
# === Calling Function ===
# Calling function: search_number with args: {
# "first_name": "John",
# "last_name": "Smith"
# }
# Got output: 2135
# ========================
# === Calling Function ===
# Calling function: dial_digit with args: {
# "number": "2135"
# }
#
# Expected response: 2135
# Actual response: None
# Outcome: False
# openai does not work with claude-instant-1
# openai does not work with claude-instant-1
# openai does not work with claude-instant-1
# openai does not work with claude-instant-1
# openai does not work with claude-2
# openai does not work with claude-2
# openai does not work with claude-2
# openai does not work with claude-2

# %% [markdown]
# ## Analysis

# %% [markdown]
# Break down by agent type

# %%
df.groupby("agent").outcome.mean()
# Out:
# agent
# openai    0.625
# react     0.500
# Name: outcome, dtype: float64

# %% [markdown]
# Break down by model

# %%
df.groupby("model").outcome.mean()
# Out:
# model
# claude-2              0.750
# claude-instant-1      0.250
# gpt-3.5-turbo-0613    0.375
# gpt-4-0613            0.875
# text-davinci-003      0.250
# Name: outcome, dtype: float64

# %% [markdown]
# Break down by task

# %%
df.groupby("task").outcome.mean()
# Out:
# task
# add_then_multiply    0.571429
# dial_then_enter      0.571429
# power                0.714286
# search_then_dial     0.285714
# Name: outcome, dtype: float64
